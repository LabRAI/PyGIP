# %%
# ================================
#  Environment setup (Colab)
# ================================
# !pip -q install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu121
# !pip -q install torch-geometric torch-scatter torch-sparse torch-cluster -f https://data.pyg.org/whl/torch-2.3.0+cu121.html
print("✅ PyTorch & PyG install attempted.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 64.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 88.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 66.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.3 MB/s eta 0:00:00
# ✅ PyTorch & PyG install attempted.

# %%
# ================================
#  Imports & Utilities
# ================================
import os, random, copy
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam

from torch_geometric.datasets import Planetoid
from torch_geometric.nn import GCNConv, SAGEConv
from torch_geometric.utils import to_undirected, subgraph

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device:', device)

def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /usr/local/lib/python3.12/dist-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSs
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /usr/local/lib/python3.12/dist-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /usr/local/lib/python3.12/dist-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSs
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# /usr/local/lib/python3.12/dist-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /usr/local/lib/python3.12/dist-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSs
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# Device: cuda

# %%
# ================================
#  Load Cora + 7/1/2 split
# ================================
dataset = Planetoid(root='/content/data/Cora', name='Cora')
data = dataset[0]

def make_split(data, train_ratio=0.7, val_ratio=0.1, seed=1):
    g = torch.Generator().manual_seed(seed)
    idx = torch.randperm(data.num_nodes, generator=g)
    n = data.num_nodes
    n_tr = int(n*train_ratio); n_va = int(n*val_ratio)
    train_idx = idx[:n_tr]; val_idx = idx[n_tr:n_tr+n_va]; test_idx = idx[n_tr+n_va:]
    data.train_mask = torch.zeros(n, dtype=torch.bool); data.train_mask[train_idx]=True
    data.val_mask   = torch.zeros(n, dtype=torch.bool); data.val_mask[val_idx]=True
    data.test_mask  = torch.zeros(n, dtype=torch.bool); data.test_mask[test_idx]=True
    return data

data = make_split(data, 0.7, 0.1, seed=1)
data.edge_index = to_undirected(data.edge_index)

num_feats   = dataset.num_node_features
num_classes = dataset.num_classes
print(data)
print('Features:', num_feats, '| Classes:', num_classes)
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])
# Features: 1433 | Classes: 7
# Done!

# %%
# ================================
#  Config (paper-ish)
# ================================
CFG = dict(
    # suspect pools (train/test for the Univerifier)
    POS_TRAIN=50, POS_TEST=50,
    NEG_TRAIN=50, NEG_TEST=50,

    # which positive transforms to include
    USE_FT_LAST=True, USE_FT_ALL=True,
    USE_PR_LAST=True, USE_PR_ALL=True,
    USE_DISTILL=True,       # set False if runtime tight
    DISTILL_STEPS=250,      # paper ~1000; increase if GPU/time allows

    # fingerprints
    FP_P=64,            # number of fingerprints
    FP_NODES=32,        # nodes per fingerprint graph
    FP_SAMPLE_M=32,     # sampled nodes per fingerprint (<= FP_NODES)
    FP_EDGE_INIT_P=0.05,
    FP_EDGE_TOPK=96,
    EDGE_LOGIT_STEP=2.5,

    # training schedule
    OUTER_ITERS=20,     # OUTER_ITERS * V_STEPS ≈ 1000 verifier updates
    FP_STEPS=5,         # e1
    V_STEPS=10,         # e2

    # lrs
    LR_TARGET=0.005,
    WD_TARGET=5e-4,
    LR_V=1e-3,          # Univerifier
    LR_X=1e-3,          # feature ascent (paper 0.001)

    SEED=1,
)
print(CFG)
# Out:
# {'POS_TRAIN': 50, 'POS_TEST': 50, 'NEG_TRAIN': 50, 'NEG_TEST': 50, 'USE_FT_LAST': True, 'USE_FT_ALL': True, 'USE_PR_LAST': True, 'USE_PR_ALL': True, 'USE_DISTILL': True, 'DISTILL_STEPS': 250, 'FP_P': 64, 'FP_NODES': 32, 'FP_SAMPLE_M': 32, 'FP_EDGE_INIT_P': 0.05, 'FP_EDGE_TOPK': 96, 'EDGE_LOGIT_STEP': 2.5, 'OUTER_ITERS': 20, 'FP_STEPS': 5, 'V_STEPS': 10, 'LR_TARGET': 0.005, 'WD_TARGET': 0.0005, 'LR_V': 0.001, 'LR_X': 0.001, 'SEED': 1}

# %%
# ================================
#  Define 3-layer GNN models
# ================================
class GCN(nn.Module):
    def __init__(self, in_channels, hidden, out_channels, dropout=0.5):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden)
        self.conv2 = GCNConv(hidden, hidden)
        self.conv3 = GCNConv(hidden, out_channels)
        self.dropout = dropout
    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index); x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv2(x, edge_index); x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv3(x, edge_index)
        return x

class GraphSAGE(nn.Module):
    def __init__(self, in_channels, hidden, out_channels, dropout=0.5):
        super().__init__()
        self.conv1 = SAGEConv(in_channels, hidden)
        self.conv2 = SAGEConv(hidden, hidden)
        self.conv3 = SAGEConv(hidden, out_channels)
        self.dropout = dropout
    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index); x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv2(x, edge_index); x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv3(x, edge_index)
        return x

# %%
# ================================
#  Train helpers
# ================================
@torch.no_grad()
def evaluate(model, data):
    model.eval()
    out = model(data.x, data.edge_index)
    pred = out.argmax(dim=1)
    accs = []
    for mask in [data.train_mask, data.val_mask, data.test_mask]:
        correct = (pred[mask] == data.y[mask]).sum().item()
        accs.append(correct / int(mask.sum()))
    return accs

def train_node_classifier(model, data, epochs=20, lr=0.005, wd=5e-4):
    model = model.to(device); data = data.to(device)
    opt = Adam(model.parameters(), lr=lr, weight_decay=wd)
    best = {'val': 0.0, 'state': None}
    for ep in range(epochs):
        model.train(); opt.zero_grad()
        out = model(data.x, data.edge_index)
        loss = F.cross_entropy(out[data.train_mask], data.y[data.train_mask])
        loss.backward(); opt.step()
        tr, va, te = evaluate(model, data)
        if va > best['val']:
            best['val'] = va; best['state'] = copy.deepcopy(model.state_dict())
        if ep % 5 == 0:
            print(f"Epoch {ep:03d} | loss {loss.item():.4f} | train {tr:.3f} | val {va:.3f} | test {te:.3f}")
    if best['state'] is not None:
        model.load_state_dict(best['state'])
    tr, va, te = evaluate(model, data)
    print(f"✅ Final (best-val) | train {tr:.3f} | val {va:.3f} | test {te:.3f}")
    return model

# %%
# ================================
#  Train target model f (GCN)
# ================================
set_seed(CFG["SEED"])
model_f = GCN(num_feats, hidden=16, out_channels=num_classes, dropout=0.5)
model_f = train_node_classifier(model_f, data, epochs=200, lr=CFG["LR_TARGET"], wd=CFG["WD_TARGET"])
# Out:
# Epoch 000 | loss 1.9508 | train 0.260 | val 0.274 | test 0.249
# Epoch 005 | loss 1.8069 | train 0.404 | val 0.407 | test 0.381
# Epoch 010 | loss 1.6046 | train 0.475 | val 0.478 | test 0.455
# Epoch 015 | loss 1.3610 | train 0.597 | val 0.578 | test 0.589
# Epoch 020 | loss 1.1607 | train 0.723 | val 0.700 | test 0.692
# Epoch 025 | loss 0.9737 | train 0.825 | val 0.789 | test 0.779
# Epoch 030 | loss 0.8043 | train 0.876 | val 0.819 | test 0.843
# Epoch 035 | loss 0.6812 | train 0.893 | val 0.848 | test 0.862
# Epoch 040 | loss 0.6077 | train 0.908 | val 0.859 | test 0.867
# Epoch 045 | loss 0.5333 | train 0.916 | val 0.859 | test 0.875
# Epoch 050 | loss 0.4881 | train 0.918 | val 0.848 | test 0.877
# Epoch 055 | loss 0.4272 | train 0.923 | val 0.856 | test 0.873
# Epoch 060 | loss 0.4195 | train 0.926 | val 0.852 | test 0.877
# Epoch 065 | loss 0.3875 | train 0.929 | val 0.844 | test 0.875
# Epoch 070 | loss 0.3785 | train 0.929 | val 0.848 | test 0.867
# Epoch 075 | loss 0.3670 | train 0.935 | val 0.852 | test 0.871
# Epoch 080 | loss 0.3490 | train 0.937 | val 0.856 | test 0.867
# Epoch 085 | loss 0.3504 | train 0.938 | val 0.856 | test 0.867
# Epoch 090 | loss 0.3162 | train 0.939 | val 0.856 | test 0.866
# Epoch 095 | loss 0.3191 | train 0.945 | val 0.856 | test 0.866
# Epoch 100 | loss 0.3213 | train 0.947 | val 0.856 | test 0.871
# Epoch 105 | loss 0.2943 | train 0.948 | val 0.856 | test 0.866
# Epoch 110 | loss 0.2861 | train 0.948 | val 0.859 | test 0.866
# Epoch 115 | loss 0.2891 | train 0.948 | val 0.863 | test 0.862
# Epoch 120 | loss 0.2805 | train 0.947 | val 0.859 | test 0.869
# Epoch 125 | loss 0.2897 | train 0.949 | val 0.852 | test 0.860
# Epoch 130 | loss 0.2871 | train 0.951 | val 0.859 | test 0.864
# Epoch 135 | loss 0.2662 | train 0.954 | val 0.863 | test 0.860
# Epoch 140 | loss 0.2819 | train 0.950 | val 0.856 | test 0.866
# Epoch 145 | loss 0.2849 | train 0.951 | val 0.859 | test 0.860
# Epoch 150 | loss 0.2658 | train 0.954 | val 0.859 | test 0.856
# Epoch 155 | loss 0.2646 | train 0.955 | val 0.859 | test 0.860
# Epoch 160 | loss 0.2682 | train 0.956 | val 0.859 | test 0.856
# Epoch 165 | loss 0.2542 | train 0.954 | val 0.863 | test 0.856
# Epoch 170 | loss 0.2540 | train 0.956 | val 0.874 | test 0.855
# Epoch 175 | loss 0.2501 | train 0.956 | val 0.867 | test 0.855
# Epoch 180 | loss 0.2479 | train 0.956 | val 0.856 | test 0.856
# Epoch 185 | loss 0.2450 | train 0.959 | val 0.856 | test 0.855
# Epoch 190 | loss 0.2567 | train 0.957 | val 0.856 | test 0.856
# Epoch 195 | loss 0.2369 | train 0.958 | val 0.852 | test 0.851
# ✅ Final (best-val) | train 0.955 | val 0.874 | test 0.856

# %%
# =========================================
#  Build suspect models (F+ and F−)  [BUDGETED]
# =========================================
@torch.no_grad()
def reset_module(m):
    for layer in m.modules():
        if hasattr(layer, 'reset_parameters'):
            layer.reset_parameters()

def ft_model(base_model, data, last_only=True, epochs=10, lr=0.005, seed=123):
    set_seed(seed)
    m = copy.deepcopy(base_model).to(device)
    for p in m.parameters(): p.requires_grad_(not last_only)
    for p in m.conv3.parameters(): p.requires_grad_(True)  # last layer fine-tune
    opt = Adam(filter(lambda p: p.requires_grad, m.parameters()), lr=lr)
    for _ in range(epochs):
        m.train(); opt.zero_grad()
        out = m(data.x.to(device), data.edge_index.to(device))
        loss = F.cross_entropy(out[data.train_mask], data.y[data.train_mask])
        loss.backward(); opt.step()
    return m.eval()

def pr_model(base_model, data, last_only=True, epochs=10, lr=0.005, seed=456):
    set_seed(seed)
    m = copy.deepcopy(base_model).to(device)
    if last_only: reset_module(m.conv3)
    else:         reset_module(m)
    opt = Adam(m.parameters(), lr=lr)
    for _ in range(epochs):
        m.train(); opt.zero_grad()
        out = m(data.x.to(device), data.edge_index.to(device))
        loss = F.cross_entropy(out[data.train_mask], data.y[data.train_mask])
        loss.backward(); opt.step()
    return m.eval()

def make_student(arch='GCN', hidden=16):
    return (GCN(num_feats, hidden, num_classes, dropout=0.5).to(device)
            if arch=='GCN' else
            GraphSAGE(num_feats, hidden, num_classes, dropout=0.5).to(device))

def random_subgraph_idx(n, keep_ratio=0.6, seed=7):
    g = torch.Generator().manual_seed(seed)
    keep = int(n*keep_ratio)
    return torch.randperm(n, generator=g)[:keep]

def distill_from_teacher(teacher, data, arch='GCN', T=2.0, steps=250, lr=0.01, seed=777):
    set_seed(seed)
    student = make_student(arch, hidden=16)
    opt = Adam(student.parameters(), lr=lr)
    kl = nn.KLDivLoss(reduction='batchmean')
    x_all = data.x.to(device); ei_all = data.edge_index.to(device)
    for t in range(steps):
        keep_ratio = float(torch.empty(1).uniform_(0.5, 0.8))
        idx = random_subgraph_idx(data.num_nodes, keep_ratio=keep_ratio, seed=seed+t).to(device)
        ei_sub, _ = subgraph(idx, ei_all, relabel_nodes=True)
        x_sub = x_all[idx]
        with torch.no_grad():
            p_t = F.softmax(teacher(x_sub, ei_sub)/T, dim=-1)
        student.train(); opt.zero_grad()
        logit_s = student(x_sub, ei_sub)/T
        loss = kl(F.log_softmax(logit_s, dim=-1), p_t) * (T*T)
        loss.backward(); opt.step()
    return student.eval()

# ---- budget splitter ----
def _distribute_budget(total, keys):
    if not keys: return {}
    base = total // len(keys); rem = total - base*len(keys)
    out = {k: base for k in keys}
    for k in keys[:rem]: out[k] += 1
    return out

# ===== Positives (F+) =====
F_pos_all = []
pos_total = CFG["POS_TRAIN"] + CFG["POS_TEST"]
pos_keys = []
if CFG["USE_FT_LAST"]: pos_keys.append("FT_LAST")
if CFG["USE_FT_ALL"]:  pos_keys.append("FT_ALL")
if CFG["USE_PR_LAST"]: pos_keys.append("PR_LAST")
if CFG["USE_PR_ALL"]:  pos_keys.append("PR_ALL")
if CFG["USE_DISTILL"]: pos_keys.append("DISTILL")
pos_budget = _distribute_budget(pos_total, pos_keys)

seed_base = 10
for key in pos_keys:
    cnt = pos_budget[key]
    if key == "FT_LAST":
        for s in range(seed_base, seed_base+cnt):
            F_pos_all.append(ft_model(model_f, data, last_only=True,  epochs=10, seed=s))
        seed_base += cnt
    elif key == "FT_ALL":
        for s in range(seed_base, seed_base+cnt):
            F_pos_all.append(ft_model(model_f, data, last_only=False, epochs=10, seed=s))
        seed_base += cnt
    elif key == "PR_LAST":
        for s in range(seed_base, seed_base+cnt):
            F_pos_all.append(pr_model(model_f, data, last_only=True,  epochs=10, seed=s))
        seed_base += cnt
    elif key == "PR_ALL":
        for s in range(seed_base, seed_base+cnt):
            F_pos_all.append(pr_model(model_f, data, last_only=False, epochs=10, seed=s))
        seed_base += cnt
    elif key == "DISTILL":
        arches = (['GCN'] * (cnt//2) + ['SAGE'] * (cnt - cnt//2))
        for i, arch in enumerate(arches, 400):
            F_pos_all.append(distill_from_teacher(model_f, data, arch=arch,
                                                  T=2.0, steps=CFG["DISTILL_STEPS"], seed=1000+i))
        seed_base += cnt

assert len(F_pos_all) == pos_total, f"Expected {pos_total} positives, got {len(F_pos_all)}"

# ===== Negatives (F−) =====
F_neg_all = []
neg_total = CFG["NEG_TRAIN"] + CFG["NEG_TEST"]
neg_keys = ["GCN", "SAGE"]
neg_budget = _distribute_budget(neg_total, neg_keys)

seed_base = 500
for s in range(seed_base, seed_base+neg_budget["GCN"]):
    set_seed(s)
    m = GCN(num_feats, 16, num_classes, dropout=0.5)
    m = train_node_classifier(m, data, epochs=120, lr=CFG["LR_TARGET"], wd=CFG["WD_TARGET"])
    F_neg_all.append(m.eval())
seed_base += neg_budget["GCN"]
for s in range(seed_base, seed_base+neg_budget["SAGE"]):
    set_seed(s)
    m = GraphSAGE(num_feats, 32, num_classes, dropout=0.5)
    m = train_node_classifier(m, data, epochs=120, lr=CFG["LR_TARGET"], wd=CFG["WD_TARGET"])
    F_neg_all.append(m.eval())

# ===== Train/Test split =====
def split_pool(pool, n_train, n_test, seed=999):
    set_seed(seed)
    idx = torch.randperm(len(pool)).tolist()
    train = [pool[i] for i in idx[:n_train]]
    test  = [pool[i] for i in idx[n_train:n_train+n_test]]
    return train, test

F_pos_tr, F_pos_te = split_pool(F_pos_all, CFG["POS_TRAIN"], CFG["POS_TEST"])
F_neg_tr, F_neg_te = split_pool(F_neg_all, CFG["NEG_TRAIN"], CFG["NEG_TEST"])

print(f"F+ train/test: {len(F_pos_tr)}/{len(F_pos_te)} | F- train/test: {len(F_neg_tr)}/{len(F_neg_te)} (totals match budgets)")
# Out:
# Epoch 000 | loss 1.9441 | train 0.396 | val 0.363 | test 0.365
# Epoch 005 | loss 1.7581 | train 0.468 | val 0.474 | test 0.484
# Epoch 010 | loss 1.5190 | train 0.574 | val 0.556 | test 0.575
# Epoch 015 | loss 1.2952 | train 0.664 | val 0.652 | test 0.641
# Epoch 020 | loss 1.0907 | train 0.725 | val 0.722 | test 0.722
# Epoch 025 | loss 0.9218 | train 0.757 | val 0.752 | test 0.744
# Epoch 030 | loss 0.7933 | train 0.804 | val 0.778 | test 0.781
# Epoch 035 | loss 0.6964 | train 0.838 | val 0.819 | test 0.794
# Epoch 040 | loss 0.6094 | train 0.883 | val 0.848 | test 0.832
# Epoch 045 | loss 0.5599 | train 0.911 | val 0.881 | test 0.856
# Epoch 050 | loss 0.5101 | train 0.922 | val 0.881 | test 0.864
# Epoch 055 | loss 0.4687 | train 0.926 | val 0.870 | test 0.877
# Epoch 060 | loss 0.4421 | train 0.927 | val 0.874 | test 0.871
# Epoch 065 | loss 0.3879 | train 0.934 | val 0.867 | test 0.871
# Epoch 070 | loss 0.3642 | train 0.934 | val 0.867 | test 0.867
# Epoch 075 | loss 0.3654 | train 0.938 | val 0.867 | test 0.875
# Epoch 080 | loss 0.3581 | train 0.940 | val 0.863 | test 0.873
# Epoch 085 | loss 0.3432 | train 0.941 | val 0.856 | test 0.871
# Epoch 090 | loss 0.3138 | train 0.941 | val 0.852 | test 0.867
# Epoch 095 | loss 0.3189 | train 0.942 | val 0.859 | test 0.877
# Epoch 100 | loss 0.3166 | train 0.944 | val 0.852 | test 0.862
# Epoch 105 | loss 0.3227 | train 0.946 | val 0.852 | test 0.860
# Epoch 110 | loss 0.3085 | train 0.946 | val 0.859 | test 0.856
# Epoch 115 | loss 0.3056 | train 0.946 | val 0.856 | test 0.860
# ✅ Final (best-val) | train 0.911 | val 0.881 | test 0.856
# Epoch 000 | loss 1.9294 | train 0.153 | val 0.137 | test 0.175
# Epoch 005 | loss 1.7175 | train 0.231 | val 0.219 | test 0.227
# Epoch 010 | loss 1.4906 | train 0.583 | val 0.563 | test 0.564
# Epoch 015 | loss 1.3194 | train 0.597 | val 0.574 | test 0.584
# Epoch 020 | loss 1.1517 | train 0.637 | val 0.604 | test 0.621
# Epoch 025 | loss 0.9705 | train 0.777 | val 0.744 | test 0.764
# Epoch 030 | loss 0.8694 | train 0.855 | val 0.807 | test 0.831
# Epoch 035 | loss 0.7563 | train 0.892 | val 0.841 | test 0.858
# Epoch 040 | loss 0.6513 | train 0.913 | val 0.859 | test 0.877
# Epoch 045 | loss 0.5798 | train 0.921 | val 0.863 | test 0.869
# Epoch 050 | loss 0.5332 | train 0.923 | val 0.859 | test 0.873
# Epoch 055 | loss 0.4863 | train 0.926 | val 0.863 | test 0.875
# Epoch 060 | loss 0.4383 | train 0.928 | val 0.867 | test 0.875
# Epoch 065 | loss 0.4291 | train 0.929 | val 0.859 | test 0.871
# Epoch 070 | loss 0.3745 | train 0.932 | val 0.867 | test 0.867
# Epoch 075 | loss 0.3833 | train 0.934 | val 0.870 | test 0.869
# Epoch 080 | loss 0.3613 | train 0.936 | val 0.863 | test 0.877
# Epoch 085 | loss 0.3526 | train 0.940 | val 0.863 | test 0.871
# Epoch 090 | loss 0.3560 | train 0.939 | val 0.863 | test 0.871
# Epoch 095 | loss 0.3355 | train 0.941 | val 0.874 | test 0.867
# Epoch 100 | loss 0.3158 | train 0.944 | val 0.856 | test 0.864
# Epoch 105 | loss 0.3258 | train 0.944 | val 0.859 | test 0.862
# Epoch 110 | loss 0.3090 | train 0.946 | val 0.867 | test 0.856
# Epoch 115 | loss 0.3105 | train 0.946 | val 0.856 | test 0.856
# ✅ Final (best-val) | train 0.942 | val 0.874 | test 0.866
# Epoch 000 | loss 1.9462 | train 0.237 | val 0.196 | test 0.208
# Epoch 005 | loss 1.7884 | train 0.547 | val 0.515 | test 0.547
# Epoch 010 | loss 1.5928 | train 0.638 | val 0.615 | test 0.615
# Epoch 015 | loss 1.3231 | train 0.718 | val 0.685 | test 0.702
# Epoch 020 | loss 1.1012 | train 0.807 | val 0.770 | test 0.785
# Epoch 025 | loss 0.8937 | train 0.864 | val 0.822 | test 0.834
# Epoch 030 | loss 0.7436 | train 0.883 | val 0.856 | test 0.849
# Epoch 035 | loss 0.6046 | train 0.899 | val 0.881 | test 0.869
# Epoch 040 | loss 0.5577 | train 0.907 | val 0.878 | test 0.869
# Epoch 045 | loss 0.5008 | train 0.912 | val 0.878 | test 0.878
# Epoch 050 | loss 0.4746 | train 0.916 | val 0.878 | test 0.878
# Epoch 055 | loss 0.4304 | train 0.920 | val 0.874 | test 0.871
# Epoch 060 | loss 0.4180 | train 0.923 | val 0.863 | test 0.875
# Epoch 065 | loss 0.3795 | train 0.931 | val 0.867 | test 0.871
# Epoch 070 | loss 0.3968 | train 0.930 | val 0.870 | test 0.873
# Epoch 075 | loss 0.3587 | train 0.930 | val 0.863 | test 0.867
# Epoch 080 | loss 0.3570 | train 0.936 | val 0.863 | test 0.862
# Epoch 085 | loss 0.3460 | train 0.936 | val 0.870 | test 0.866
# Epoch 090 | loss 0.3502 | train 0.939 | val 0.867 | test 0.869
# Epoch 095 | loss 0.3329 | train 0.940 | val 0.863 | test 0.864
# Epoch 100 | loss 0.3422 | train 0.937 | val 0.870 | test 0.855
# Epoch 105 | loss 0.3264 | train 0.942 | val 0.867 | test 0.862
# Epoch 110 | loss 0.3119 | train 0.942 | val 0.878 | test 0.864
# Epoch 115 | loss 0.3240 | train 0.945 | val 0.867 | test 0.853
# ✅ Final (best-val) | train 0.890 | val 0.885 | test 0.860
# Epoch 000 | loss 1.9314 | train 0.306 | val 0.293 | test 0.302
# Epoch 005 | loss 1.7393 | train 0.304 | val 0.296 | test 0.298
# Epoch 010 | loss 1.5551 | train 0.304 | val 0.296 | test 0.298
# Epoch 015 | loss 1.3900 | train 0.428 | val 0.422 | test 0.403
# Epoch 020 | loss 1.1987 | train 0.682 | val 0.659 | test 0.654
# Epoch 025 | loss 1.0685 | train 0.795 | val 0.770 | test 0.768
# Epoch 030 | loss 0.9287 | train 0.822 | val 0.781 | test 0.799
# Epoch 035 | loss 0.8174 | train 0.840 | val 0.800 | test 0.808
# Epoch 040 | loss 0.6663 | train 0.856 | val 0.800 | test 0.825
# Epoch 045 | loss 0.5872 | train 0.894 | val 0.830 | test 0.849
# Epoch 050 | loss 0.5556 | train 0.908 | val 0.848 | test 0.862
# Epoch 055 | loss 0.4900 | train 0.920 | val 0.852 | test 0.864
# Epoch 060 | loss 0.4610 | train 0.929 | val 0.859 | test 0.864
# Epoch 065 | loss 0.4162 | train 0.929 | val 0.863 | test 0.864
# Epoch 070 | loss 0.4144 | train 0.930 | val 0.859 | test 0.866
# Epoch 075 | loss 0.3847 | train 0.937 | val 0.856 | test 0.864
# Epoch 080 | loss 0.3712 | train 0.940 | val 0.856 | test 0.866
# Epoch 085 | loss 0.3589 | train 0.940 | val 0.859 | test 0.856
# Epoch 090 | loss 0.3456 | train 0.940 | val 0.863 | test 0.856
# Epoch 095 | loss 0.3215 | train 0.943 | val 0.863 | test 0.853
# Epoch 100 | loss 0.3114 | train 0.944 | val 0.867 | test 0.862
# Epoch 105 | loss 0.3185 | train 0.945 | val 0.867 | test 0.856
# Epoch 110 | loss 0.3108 | train 0.946 | val 0.859 | test 0.856
# Epoch 115 | loss 0.2880 | train 0.946 | val 0.867 | test 0.864
# ✅ Final (best-val) | train 0.941 | val 0.867 | test 0.853
# Epoch 000 | loss 1.9379 | train 0.304 | val 0.296 | test 0.297
# Epoch 005 | loss 1.6674 | train 0.306 | val 0.296 | test 0.298
# Epoch 010 | loss 1.4370 | train 0.499 | val 0.456 | test 0.483
# Epoch 015 | loss 1.2098 | train 0.665 | val 0.652 | test 0.628
# Epoch 020 | loss 1.0606 | train 0.731 | val 0.719 | test 0.702
# Epoch 025 | loss 0.8758 | train 0.761 | val 0.748 | test 0.733
# Epoch 030 | loss 0.7615 | train 0.820 | val 0.807 | test 0.788
# Epoch 035 | loss 0.6825 | train 0.854 | val 0.844 | test 0.820
# Epoch 040 | loss 0.5926 | train 0.892 | val 0.856 | test 0.856
# Epoch 045 | loss 0.5643 | train 0.911 | val 0.852 | test 0.875
# Epoch 050 | loss 0.5004 | train 0.919 | val 0.859 | test 0.875
# Epoch 055 | loss 0.4799 | train 0.926 | val 0.863 | test 0.875
# Epoch 060 | loss 0.4222 | train 0.925 | val 0.859 | test 0.867
# Epoch 065 | loss 0.4247 | train 0.929 | val 0.863 | test 0.873
# Epoch 070 | loss 0.3673 | train 0.932 | val 0.859 | test 0.869
# Epoch 075 | loss 0.3451 | train 0.936 | val 0.856 | test 0.871
# Epoch 080 | loss 0.3295 | train 0.938 | val 0.856 | test 0.866
# Epoch 085 | loss 0.3191 | train 0.941 | val 0.859 | test 0.864
# Epoch 090 | loss 0.3104 | train 0.942 | val 0.867 | test 0.862
# Epoch 095 | loss 0.3108 | train 0.949 | val 0.859 | test 0.856
# Epoch 100 | loss 0.3143 | train 0.947 | val 0.867 | test 0.856
# Epoch 105 | loss 0.2888 | train 0.949 | val 0.859 | test 0.856
# Epoch 110 | loss 0.3023 | train 0.949 | val 0.856 | test 0.858
# Epoch 115 | loss 0.2672 | train 0.948 | val 0.856 | test 0.860
# ✅ Final (best-val) | train 0.941 | val 0.867 | test 0.866
# Epoch 000 | loss 1.9388 | train 0.291 | val 0.281 | test 0.280
# Epoch 005 | loss 1.7479 | train 0.385 | val 0.359 | test 0.354
# Epoch 010 | loss 1.4990 | train 0.539 | val 0.530 | test 0.519
# Epoch 015 | loss 1.2772 | train 0.678 | val 0.633 | test 0.672
# Epoch 020 | loss 1.1190 | train 0.788 | val 0.733 | test 0.757
# Epoch 025 | loss 0.9281 | train 0.829 | val 0.789 | test 0.805
# Epoch 030 | loss 0.7872 | train 0.863 | val 0.811 | test 0.836
# Epoch 035 | loss 0.7174 | train 0.884 | val 0.844 | test 0.842
# Epoch 040 | loss 0.6349 | train 0.909 | val 0.863 | test 0.856
# Epoch 045 | loss 0.5523 | train 0.911 | val 0.874 | test 0.869
# Epoch 050 | loss 0.5267 | train 0.920 | val 0.870 | test 0.869
# Epoch 055 | loss 0.4739 | train 0.922 | val 0.863 | test 0.869
# Epoch 060 | loss 0.4568 | train 0.928 | val 0.859 | test 0.877
# Epoch 065 | loss 0.4241 | train 0.931 | val 0.856 | test 0.873
# Epoch 070 | loss 0.4240 | train 0.932 | val 0.863 | test 0.871
# Epoch 075 | loss 0.3788 | train 0.937 | val 0.856 | test 0.875
# Epoch 080 | loss 0.3558 | train 0.938 | val 0.863 | test 0.878
# Epoch 085 | loss 0.3413 | train 0.936 | val 0.859 | test 0.878
# Epoch 090 | loss 0.3420 | train 0.938 | val 0.856 | test 0.878
# Epoch 095 | loss 0.3130 | train 0.940 | val 0.859 | test 0.871
# Epoch 100 | loss 0.3286 | train 0.942 | val 0.856 | test 0.871
# Epoch 105 | loss 0.3194 | train 0.941 | val 0.856 | test 0.867
# Epoch 110 | loss 0.3244 | train 0.946 | val 0.856 | test 0.869
# Epoch 115 | loss 0.2985 | train 0.944 | val 0.867 | test 0.869
# ✅ Final (best-val) | train 0.909 | val 0.874 | test 0.864
# Epoch 000 | loss 1.9495 | train 0.310 | val 0.307 | test 0.315
# Epoch 005 | loss 1.7859 | train 0.380 | val 0.374 | test 0.361
# Epoch 010 | loss 1.5869 | train 0.556 | val 0.552 | test 0.506
# Epoch 015 | loss 1.3697 | train 0.649 | val 0.604 | test 0.617
# Epoch 020 | loss 1.1487 | train 0.735 | val 0.704 | test 0.707
# Epoch 025 | loss 0.9910 | train 0.751 | val 0.707 | test 0.738
# Epoch 030 | loss 0.8404 | train 0.788 | val 0.730 | test 0.753
# Epoch 035 | loss 0.7508 | train 0.881 | val 0.822 | test 0.821
# Epoch 040 | loss 0.6496 | train 0.902 | val 0.841 | test 0.851
# Epoch 045 | loss 0.5786 | train 0.912 | val 0.844 | test 0.866
# Epoch 050 | loss 0.5211 | train 0.916 | val 0.867 | test 0.869
# Epoch 055 | loss 0.4742 | train 0.923 | val 0.870 | test 0.873
# Epoch 060 | loss 0.4524 | train 0.925 | val 0.863 | test 0.871
# Epoch 065 | loss 0.3942 | train 0.929 | val 0.856 | test 0.882
# Epoch 070 | loss 0.3872 | train 0.929 | val 0.863 | test 0.869
# Epoch 075 | loss 0.3874 | train 0.928 | val 0.863 | test 0.867
# Epoch 080 | loss 0.3662 | train 0.930 | val 0.852 | test 0.869
# Epoch 085 | loss 0.3565 | train 0.932 | val 0.852 | test 0.867
# Epoch 090 | loss 0.3382 | train 0.938 | val 0.852 | test 0.860
# Epoch 095 | loss 0.3464 | train 0.935 | val 0.852 | test 0.866
# Epoch 100 | loss 0.3203 | train 0.944 | val 0.844 | test 0.858
# Epoch 105 | loss 0.3116 | train 0.941 | val 0.856 | test 0.860
# Epoch 110 | loss 0.3062 | train 0.945 | val 0.863 | test 0.858
# Epoch 115 | loss 0.3245 | train 0.945 | val 0.859 | test 0.856
# ✅ Final (best-val) | train 0.920 | val 0.870 | test 0.871
# Epoch 000 | loss 1.9475 | train 0.374 | val 0.304 | test 0.350
# Epoch 005 | loss 1.8020 | train 0.523 | val 0.504 | test 0.521
# Epoch 010 | loss 1.5635 | train 0.557 | val 0.559 | test 0.547
# Epoch 015 | loss 1.3733 | train 0.653 | val 0.637 | test 0.634
# Epoch 020 | loss 1.1562 | train 0.731 | val 0.715 | test 0.705
# Epoch 025 | loss 0.9495 | train 0.836 | val 0.815 | test 0.803
# Epoch 030 | loss 0.7704 | train 0.877 | val 0.844 | test 0.838
# Epoch 035 | loss 0.6865 | train 0.901 | val 0.863 | test 0.867
# Epoch 040 | loss 0.5979 | train 0.912 | val 0.863 | test 0.867
# Epoch 045 | loss 0.5240 | train 0.922 | val 0.867 | test 0.880
# Epoch 050 | loss 0.4840 | train 0.922 | val 0.870 | test 0.873
# Epoch 055 | loss 0.4595 | train 0.927 | val 0.870 | test 0.878
# Epoch 060 | loss 0.3992 | train 0.929 | val 0.870 | test 0.880
# Epoch 065 | loss 0.3822 | train 0.932 | val 0.859 | test 0.882
# Epoch 070 | loss 0.3535 | train 0.932 | val 0.863 | test 0.886
# Epoch 075 | loss 0.3544 | train 0.938 | val 0.863 | test 0.878
# Epoch 080 | loss 0.3566 | train 0.936 | val 0.852 | test 0.877
# Epoch 085 | loss 0.3311 | train 0.939 | val 0.859 | test 0.871
# Epoch 090 | loss 0.3399 | train 0.941 | val 0.867 | test 0.867
# Epoch 095 | loss 0.3094 | train 0.945 | val 0.863 | test 0.871
# Epoch 100 | loss 0.3053 | train 0.944 | val 0.863 | test 0.869
# Epoch 105 | loss 0.2855 | train 0.948 | val 0.867 | test 0.875
# Epoch 110 | loss 0.2849 | train 0.948 | val 0.863 | test 0.869
# Epoch 115 | loss 0.2798 | train 0.948 | val 0.859 | test 0.866
# ✅ Final (best-val) | train 0.927 | val 0.874 | test 0.877
# Epoch 000 | loss 1.9487 | train 0.411 | val 0.378 | test 0.398
# Epoch 005 | loss 1.7708 | train 0.487 | val 0.511 | test 0.455
# Epoch 010 | loss 1.5359 | train 0.630 | val 0.585 | test 0.584
# Epoch 015 | loss 1.2515 | train 0.798 | val 0.752 | test 0.759
# Epoch 020 | loss 1.0540 | train 0.853 | val 0.826 | test 0.831
# Epoch 025 | loss 0.8700 | train 0.873 | val 0.863 | test 0.851
# Epoch 030 | loss 0.7408 | train 0.890 | val 0.870 | test 0.862
# Epoch 035 | loss 0.6523 | train 0.902 | val 0.867 | test 0.864
# Epoch 040 | loss 0.5898 | train 0.913 | val 0.867 | test 0.878
# Epoch 045 | loss 0.5398 | train 0.920 | val 0.867 | test 0.869
# Epoch 050 | loss 0.4964 | train 0.929 | val 0.863 | test 0.873
# Epoch 055 | loss 0.4298 | train 0.929 | val 0.859 | test 0.875
# Epoch 060 | loss 0.4095 | train 0.931 | val 0.863 | test 0.873
# Epoch 065 | loss 0.3901 | train 0.932 | val 0.859 | test 0.873
# Epoch 070 | loss 0.3676 | train 0.936 | val 0.859 | test 0.875
# Epoch 075 | loss 0.3667 | train 0.936 | val 0.863 | test 0.869
# Epoch 080 | loss 0.3643 | train 0.940 | val 0.856 | test 0.873
# Epoch 085 | loss 0.3581 | train 0.941 | val 0.856 | test 0.867
# Epoch 090 | loss 0.3432 | train 0.944 | val 0.856 | test 0.871
# Epoch 095 | loss 0.3359 | train 0.948 | val 0.859 | test 0.855
# Epoch 100 | loss 0.3235 | train 0.947 | val 0.859 | test 0.860
# Epoch 105 | loss 0.3146 | train 0.947 | val 0.856 | test 0.862
# Epoch 110 | loss 0.3043 | train 0.946 | val 0.856 | test 0.867
# Epoch 115 | loss 0.2931 | train 0.948 | val 0.856 | test 0.855
# ✅ Final (best-val) | train 0.897 | val 0.878 | test 0.862
# Epoch 000 | loss 1.9364 | train 0.303 | val 0.296 | test 0.297
# Epoch 005 | loss 1.7018 | train 0.306 | val 0.296 | test 0.298
# Epoch 010 | loss 1.5089 | train 0.539 | val 0.533 | test 0.512
# Epoch 015 | loss 1.2910 | train 0.665 | val 0.626 | test 0.652
# Epoch 020 | loss 1.0979 | train 0.812 | val 0.752 | test 0.796
# Epoch 025 | loss 0.9194 | train 0.865 | val 0.811 | test 0.836
# Epoch 030 | loss 0.7898 | train 0.884 | val 0.859 | test 0.855
# Epoch 035 | loss 0.6927 | train 0.901 | val 0.878 | test 0.862
# Epoch 040 | loss 0.5896 | train 0.907 | val 0.881 | test 0.866
# Epoch 045 | loss 0.5178 | train 0.918 | val 0.874 | test 0.866
# Epoch 050 | loss 0.4906 | train 0.921 | val 0.867 | test 0.871
# Epoch 055 | loss 0.4142 | train 0.924 | val 0.878 | test 0.871
# Epoch 060 | loss 0.3953 | train 0.927 | val 0.867 | test 0.875
# Epoch 065 | loss 0.3605 | train 0.930 | val 0.874 | test 0.864
# Epoch 070 | loss 0.3665 | train 0.936 | val 0.870 | test 0.871
# Epoch 075 | loss 0.3670 | train 0.934 | val 0.856 | test 0.866
# Epoch 080 | loss 0.3365 | train 0.937 | val 0.856 | test 0.860
# Epoch 085 | loss 0.3225 | train 0.939 | val 0.863 | test 0.864
# Epoch 090 | loss 0.3325 | train 0.940 | val 0.874 | test 0.864
# Epoch 095 | loss 0.3108 | train 0.940 | val 0.874 | test 0.871
# Epoch 100 | loss 0.3144 | train 0.944 | val 0.870 | test 0.867
# Epoch 105 | loss 0.3108 | train 0.947 | val 0.874 | test 0.864
# Epoch 110 | loss 0.3044 | train 0.951 | val 0.870 | test 0.862
# Epoch 115 | loss 0.3047 | train 0.951 | val 0.856 | test 0.864
# ✅ Final (best-val) | train 0.907 | val 0.881 | test 0.866
# Epoch 000 | loss 1.9487 | train 0.387 | val 0.422 | test 0.372
# Epoch 005 | loss 1.7976 | train 0.406 | val 0.415 | test 0.392
# Epoch 010 | loss 1.5641 | train 0.452 | val 0.437 | test 0.429
# Epoch 015 | loss 1.3744 | train 0.493 | val 0.467 | test 0.459
# Epoch 020 | loss 1.1835 | train 0.639 | val 0.589 | test 0.637
# Epoch 025 | loss 1.0158 | train 0.811 | val 0.752 | test 0.803
# Epoch 030 | loss 0.8306 | train 0.871 | val 0.811 | test 0.831
# Epoch 035 | loss 0.7386 | train 0.896 | val 0.837 | test 0.855
# Epoch 040 | loss 0.6582 | train 0.908 | val 0.863 | test 0.860
# Epoch 045 | loss 0.5547 | train 0.916 | val 0.852 | test 0.875
# Epoch 050 | loss 0.5046 | train 0.927 | val 0.859 | test 0.886
# Epoch 055 | loss 0.4643 | train 0.926 | val 0.856 | test 0.882
# Epoch 060 | loss 0.4222 | train 0.928 | val 0.859 | test 0.878
# Epoch 065 | loss 0.4042 | train 0.930 | val 0.856 | test 0.886
# Epoch 070 | loss 0.3943 | train 0.930 | val 0.863 | test 0.878
# Epoch 075 | loss 0.3827 | train 0.931 | val 0.859 | test 0.878
# Epoch 080 | loss 0.3564 | train 0.934 | val 0.859 | test 0.871
# Epoch 085 | loss 0.3508 | train 0.937 | val 0.867 | test 0.873
# Epoch 090 | loss 0.3366 | train 0.940 | val 0.856 | test 0.873
# Epoch 095 | loss 0.3356 | train 0.940 | val 0.856 | test 0.873
# Epoch 100 | loss 0.3192 | train 0.943 | val 0.856 | test 0.871
# Epoch 105 | loss 0.3245 | train 0.944 | val 0.856 | test 0.869
# Epoch 110 | loss 0.3149 | train 0.946 | val 0.856 | test 0.867
# Epoch 115 | loss 0.3138 | train 0.944 | val 0.852 | test 0.864
# ✅ Final (best-val) | train 0.937 | val 0.867 | test 0.873
# Epoch 000 | loss 1.9467 | train 0.327 | val 0.300 | test 0.320
# Epoch 005 | loss 1.7719 | train 0.430 | val 0.400 | test 0.401
# Epoch 010 | loss 1.5397 | train 0.587 | val 0.567 | test 0.569
# Epoch 015 | loss 1.3480 | train 0.643 | val 0.648 | test 0.615
# Epoch 020 | loss 1.1595 | train 0.719 | val 0.711 | test 0.700
# Epoch 025 | loss 0.9948 | train 0.763 | val 0.752 | test 0.751
# Epoch 030 | loss 0.8525 | train 0.837 | val 0.804 | test 0.818
# Epoch 035 | loss 0.7522 | train 0.877 | val 0.822 | test 0.855
# Epoch 040 | loss 0.6470 | train 0.902 | val 0.848 | test 0.862
# Epoch 045 | loss 0.5895 | train 0.912 | val 0.859 | test 0.875
# Epoch 050 | loss 0.5402 | train 0.917 | val 0.863 | test 0.878
# Epoch 055 | loss 0.4862 | train 0.922 | val 0.874 | test 0.880
# Epoch 060 | loss 0.4267 | train 0.925 | val 0.863 | test 0.877
# Epoch 065 | loss 0.4071 | train 0.929 | val 0.859 | test 0.877
# Epoch 070 | loss 0.3725 | train 0.936 | val 0.867 | test 0.871
# Epoch 075 | loss 0.3799 | train 0.937 | val 0.863 | test 0.877
# Epoch 080 | loss 0.3741 | train 0.936 | val 0.863 | test 0.877
# Epoch 085 | loss 0.3634 | train 0.939 | val 0.863 | test 0.875
# Epoch 090 | loss 0.3397 | train 0.944 | val 0.863 | test 0.869
# Epoch 095 | loss 0.3378 | train 0.941 | val 0.863 | test 0.867
# Epoch 100 | loss 0.3071 | train 0.945 | val 0.856 | test 0.867
# Epoch 105 | loss 0.3205 | train 0.945 | val 0.859 | test 0.867
# Epoch 110 | loss 0.3179 | train 0.947 | val 0.856 | test 0.869
# Epoch 115 | loss 0.3226 | train 0.944 | val 0.856 | test 0.858
# ✅ Final (best-val) | train 0.920 | val 0.874 | test 0.880
# Epoch 000 | loss 1.9490 | train 0.318 | val 0.330 | test 0.337
# Epoch 005 | loss 1.7706 | train 0.329 | val 0.333 | test 0.326
# Epoch 010 | loss 1.5862 | train 0.496 | val 0.511 | test 0.494
# Epoch 015 | loss 1.3969 | train 0.677 | val 0.674 | test 0.663
# Epoch 020 | loss 1.1977 | train 0.750 | val 0.737 | test 0.738
# Epoch 025 | loss 1.0357 | train 0.764 | val 0.748 | test 0.748
# Epoch 030 | loss 0.8949 | train 0.851 | val 0.789 | test 0.816
# Epoch 035 | loss 0.7700 | train 0.889 | val 0.852 | test 0.866
# Epoch 040 | loss 0.6283 | train 0.914 | val 0.878 | test 0.871
# Epoch 045 | loss 0.5343 | train 0.918 | val 0.881 | test 0.884
# Epoch 050 | loss 0.4797 | train 0.922 | val 0.878 | test 0.878
# Epoch 055 | loss 0.4370 | train 0.927 | val 0.867 | test 0.880
# Epoch 060 | loss 0.4365 | train 0.927 | val 0.859 | test 0.877
# Epoch 065 | loss 0.3803 | train 0.930 | val 0.867 | test 0.873
# Epoch 070 | loss 0.3785 | train 0.930 | val 0.870 | test 0.873
# Epoch 075 | loss 0.3599 | train 0.934 | val 0.874 | test 0.871
# Epoch 080 | loss 0.3415 | train 0.935 | val 0.859 | test 0.867
# Epoch 085 | loss 0.3194 | train 0.937 | val 0.867 | test 0.864
# Epoch 090 | loss 0.3191 | train 0.942 | val 0.867 | test 0.862
# Epoch 095 | loss 0.3064 | train 0.942 | val 0.863 | test 0.862
# Epoch 100 | loss 0.3102 | train 0.945 | val 0.859 | test 0.862
# Epoch 105 | loss 0.3038 | train 0.946 | val 0.859 | test 0.864
# Epoch 110 | loss 0.3012 | train 0.948 | val 0.870 | test 0.862
# Epoch 115 | loss 0.2888 | train 0.945 | val 0.856 | test 0.860
# ✅ Final (best-val) | train 0.921 | val 0.885 | test 0.882
# Epoch 000 | loss 1.9527 | train 0.294 | val 0.296 | test 0.276
# Epoch 005 | loss 1.8106 | train 0.319 | val 0.322 | test 0.313
# Epoch 010 | loss 1.6099 | train 0.455 | val 0.441 | test 0.455
# Epoch 015 | loss 1.3833 | train 0.620 | val 0.604 | test 0.595
# Epoch 020 | loss 1.2315 | train 0.668 | val 0.656 | test 0.639
# Epoch 025 | loss 1.0461 | train 0.742 | val 0.730 | test 0.716
# Epoch 030 | loss 0.8781 | train 0.775 | val 0.767 | test 0.750
# Epoch 035 | loss 0.7546 | train 0.843 | val 0.807 | test 0.810
# Epoch 040 | loss 0.6601 | train 0.899 | val 0.856 | test 0.860
# Epoch 045 | loss 0.6121 | train 0.910 | val 0.870 | test 0.866
# Epoch 050 | loss 0.5109 | train 0.922 | val 0.870 | test 0.871
# Epoch 055 | loss 0.4998 | train 0.923 | val 0.874 | test 0.871
# Epoch 060 | loss 0.4519 | train 0.928 | val 0.870 | test 0.871
# Epoch 065 | loss 0.4484 | train 0.929 | val 0.874 | test 0.866
# Epoch 070 | loss 0.4070 | train 0.929 | val 0.867 | test 0.866
# Epoch 075 | loss 0.3890 | train 0.934 | val 0.870 | test 0.873
# Epoch 080 | loss 0.3672 | train 0.934 | val 0.870 | test 0.867
# Epoch 085 | loss 0.3856 | train 0.938 | val 0.870 | test 0.871
# Epoch 090 | loss 0.3614 | train 0.937 | val 0.870 | test 0.869
# Epoch 095 | loss 0.3405 | train 0.940 | val 0.870 | test 0.871
# Epoch 100 | loss 0.3348 | train 0.939 | val 0.874 | test 0.867
# Epoch 105 | loss 0.3327 | train 0.941 | val 0.874 | test 0.866
# Epoch 110 | loss 0.3045 | train 0.945 | val 0.863 | test 0.856
# Epoch 115 | loss 0.2867 | train 0.947 | val 0.874 | test 0.869
# ✅ Final (best-val) | train 0.907 | val 0.878 | test 0.867
# Epoch 000 | loss 1.9358 | train 0.304 | val 0.296 | test 0.300
# Epoch 005 | loss 1.7051 | train 0.309 | val 0.300 | test 0.302
# Epoch 010 | loss 1.4371 | train 0.546 | val 0.556 | test 0.505
# Epoch 015 | loss 1.2009 | train 0.735 | val 0.715 | test 0.672
# Epoch 020 | loss 1.0144 | train 0.826 | val 0.830 | test 0.796
# Epoch 025 | loss 0.8024 | train 0.871 | val 0.863 | test 0.840
# Epoch 030 | loss 0.7004 | train 0.898 | val 0.870 | test 0.853
# Epoch 035 | loss 0.5877 | train 0.908 | val 0.870 | test 0.860
# Epoch 040 | loss 0.5588 | train 0.917 | val 0.874 | test 0.860
# Epoch 045 | loss 0.4867 | train 0.919 | val 0.867 | test 0.862
# Epoch 050 | loss 0.4477 | train 0.919 | val 0.870 | test 0.864
# Epoch 055 | loss 0.4147 | train 0.925 | val 0.859 | test 0.871
# Epoch 060 | loss 0.3961 | train 0.929 | val 0.859 | test 0.871
# Epoch 065 | loss 0.3940 | train 0.932 | val 0.863 | test 0.871
# Epoch 070 | loss 0.3722 | train 0.934 | val 0.859 | test 0.875
# Epoch 075 | loss 0.3519 | train 0.936 | val 0.863 | test 0.869
# Epoch 080 | loss 0.3411 | train 0.936 | val 0.867 | test 0.867
# Epoch 085 | loss 0.3275 | train 0.938 | val 0.859 | test 0.871
# Epoch 090 | loss 0.3459 | train 0.941 | val 0.867 | test 0.864
# Epoch 095 | loss 0.3109 | train 0.943 | val 0.867 | test 0.869
# Epoch 100 | loss 0.2969 | train 0.944 | val 0.863 | test 0.873
# Epoch 105 | loss 0.3239 | train 0.942 | val 0.859 | test 0.866
# Epoch 110 | loss 0.3185 | train 0.943 | val 0.863 | test 0.869
# Epoch 115 | loss 0.2946 | train 0.945 | val 0.856 | test 0.867
# ✅ Final (best-val) | train 0.912 | val 0.878 | test 0.864
# Epoch 000 | loss 1.9435 | train 0.303 | val 0.293 | test 0.297
# Epoch 005 | loss 1.7398 | train 0.327 | val 0.333 | test 0.324
# Epoch 010 | loss 1.4805 | train 0.484 | val 0.493 | test 0.468
# Epoch 015 | loss 1.2890 | train 0.538 | val 0.533 | test 0.512
# Epoch 020 | loss 1.1102 | train 0.778 | val 0.763 | test 0.746
# Epoch 025 | loss 0.9934 | train 0.840 | val 0.807 | test 0.803
# Epoch 030 | loss 0.8320 | train 0.882 | val 0.837 | test 0.840
# Epoch 035 | loss 0.7349 | train 0.901 | val 0.837 | test 0.849
# Epoch 040 | loss 0.6194 | train 0.911 | val 0.844 | test 0.858
# Epoch 045 | loss 0.5620 | train 0.918 | val 0.852 | test 0.867
# Epoch 050 | loss 0.5002 | train 0.919 | val 0.859 | test 0.871
# Epoch 055 | loss 0.4766 | train 0.927 | val 0.870 | test 0.871
# Epoch 060 | loss 0.4401 | train 0.930 | val 0.867 | test 0.873
# Epoch 065 | loss 0.4250 | train 0.932 | val 0.867 | test 0.875
# Epoch 070 | loss 0.3825 | train 0.934 | val 0.856 | test 0.871
# Epoch 075 | loss 0.3696 | train 0.935 | val 0.863 | test 0.871
# Epoch 080 | loss 0.3687 | train 0.939 | val 0.863 | test 0.867
# Epoch 085 | loss 0.3676 | train 0.940 | val 0.863 | test 0.864
# Epoch 090 | loss 0.3342 | train 0.941 | val 0.859 | test 0.856
# Epoch 095 | loss 0.3210 | train 0.943 | val 0.863 | test 0.855
# Epoch 100 | loss 0.3043 | train 0.944 | val 0.863 | test 0.853
# Epoch 105 | loss 0.3086 | train 0.947 | val 0.848 | test 0.853
# Epoch 110 | loss 0.2871 | train 0.949 | val 0.852 | test 0.855
# Epoch 115 | loss 0.2938 | train 0.948 | val 0.859 | test 0.856
# ✅ Final (best-val) | train 0.925 | val 0.870 | test 0.867
# Epoch 000 | loss 1.9599 | train 0.273 | val 0.259 | test 0.284
# Epoch 005 | loss 1.8286 | train 0.697 | val 0.663 | test 0.678
# Epoch 010 | loss 1.5991 | train 0.721 | val 0.693 | test 0.703
# Epoch 015 | loss 1.3408 | train 0.733 | val 0.704 | test 0.720
# Epoch 020 | loss 1.1312 | train 0.811 | val 0.767 | test 0.792
# Epoch 025 | loss 0.9210 | train 0.828 | val 0.774 | test 0.810
# Epoch 030 | loss 0.7654 | train 0.869 | val 0.811 | test 0.845
# Epoch 035 | loss 0.6820 | train 0.900 | val 0.819 | test 0.862
# Epoch 040 | loss 0.5921 | train 0.904 | val 0.841 | test 0.866
# Epoch 045 | loss 0.5378 | train 0.917 | val 0.852 | test 0.869
# Epoch 050 | loss 0.4916 | train 0.922 | val 0.852 | test 0.866
# Epoch 055 | loss 0.4681 | train 0.923 | val 0.852 | test 0.866
# Epoch 060 | loss 0.4568 | train 0.929 | val 0.856 | test 0.864
# Epoch 065 | loss 0.4087 | train 0.931 | val 0.859 | test 0.869
# Epoch 070 | loss 0.4123 | train 0.936 | val 0.852 | test 0.867
# Epoch 075 | loss 0.3751 | train 0.936 | val 0.852 | test 0.869
# Epoch 080 | loss 0.3805 | train 0.939 | val 0.859 | test 0.860
# Epoch 085 | loss 0.3633 | train 0.938 | val 0.852 | test 0.860
# Epoch 090 | loss 0.3431 | train 0.942 | val 0.856 | test 0.866
# Epoch 095 | loss 0.3494 | train 0.943 | val 0.867 | test 0.866
# Epoch 100 | loss 0.3280 | train 0.944 | val 0.856 | test 0.862
# Epoch 105 | loss 0.3272 | train 0.944 | val 0.856 | test 0.864
# Epoch 110 | loss 0.3158 | train 0.945 | val 0.856 | test 0.858
# Epoch 115 | loss 0.3237 | train 0.949 | val 0.848 | test 0.853
# ✅ Final (best-val) | train 0.941 | val 0.867 | test 0.864
# Epoch 000 | loss 1.9526 | train 0.414 | val 0.381 | test 0.429
# Epoch 005 | loss 1.7473 | train 0.595 | val 0.585 | test 0.578
# Epoch 010 | loss 1.4903 | train 0.729 | val 0.737 | test 0.738
# Epoch 015 | loss 1.2663 | train 0.737 | val 0.733 | test 0.731
# Epoch 020 | loss 1.0713 | train 0.768 | val 0.767 | test 0.755
# Epoch 025 | loss 0.9090 | train 0.790 | val 0.774 | test 0.764
# Epoch 030 | loss 0.7825 | train 0.847 | val 0.844 | test 0.808
# Epoch 035 | loss 0.6588 | train 0.889 | val 0.859 | test 0.829
# Epoch 040 | loss 0.6054 | train 0.915 | val 0.870 | test 0.856
# Epoch 045 | loss 0.5548 | train 0.923 | val 0.870 | test 0.869
# Epoch 050 | loss 0.5078 | train 0.922 | val 0.863 | test 0.864
# Epoch 055 | loss 0.4721 | train 0.929 | val 0.859 | test 0.871
# Epoch 060 | loss 0.4119 | train 0.928 | val 0.863 | test 0.862
# Epoch 065 | loss 0.4065 | train 0.932 | val 0.859 | test 0.860
# Epoch 070 | loss 0.3652 | train 0.937 | val 0.867 | test 0.871
# Epoch 075 | loss 0.3798 | train 0.937 | val 0.870 | test 0.866
# Epoch 080 | loss 0.3469 | train 0.937 | val 0.863 | test 0.866
# Epoch 085 | loss 0.3389 | train 0.941 | val 0.867 | test 0.867
# Epoch 090 | loss 0.3311 | train 0.938 | val 0.867 | test 0.869
# Epoch 095 | loss 0.3120 | train 0.942 | val 0.867 | test 0.858
# Epoch 100 | loss 0.3024 | train 0.942 | val 0.867 | test 0.860
# Epoch 105 | loss 0.3066 | train 0.944 | val 0.870 | test 0.864
# Epoch 110 | loss 0.2966 | train 0.948 | val 0.878 | test 0.866
# Epoch 115 | loss 0.2928 | train 0.949 | val 0.867 | test 0.871
# ✅ Final (best-val) | train 0.915 | val 0.878 | test 0.855
# Epoch 000 | loss 1.9478 | train 0.245 | val 0.241 | test 0.262
# Epoch 005 | loss 1.7655 | train 0.253 | val 0.267 | test 0.265
# Epoch 010 | loss 1.5160 | train 0.556 | val 0.548 | test 0.567
# Epoch 015 | loss 1.2958 | train 0.642 | val 0.622 | test 0.632
# Epoch 020 | loss 1.0760 | train 0.784 | val 0.770 | test 0.751
# Epoch 025 | loss 0.9199 | train 0.853 | val 0.830 | test 0.810
# Epoch 030 | loss 0.8161 | train 0.882 | val 0.848 | test 0.851
# Epoch 035 | loss 0.6504 | train 0.910 | val 0.874 | test 0.864
# Epoch 040 | loss 0.5983 | train 0.912 | val 0.870 | test 0.867
# Epoch 045 | loss 0.5484 | train 0.917 | val 0.856 | test 0.866
# Epoch 050 | loss 0.4890 | train 0.917 | val 0.859 | test 0.875
# Epoch 055 | loss 0.4324 | train 0.919 | val 0.856 | test 0.867
# Epoch 060 | loss 0.4498 | train 0.924 | val 0.859 | test 0.869
# Epoch 065 | loss 0.3931 | train 0.927 | val 0.852 | test 0.871
# Epoch 070 | loss 0.3877 | train 0.928 | val 0.856 | test 0.869
# Epoch 075 | loss 0.3926 | train 0.930 | val 0.856 | test 0.871
# Epoch 080 | loss 0.3561 | train 0.934 | val 0.856 | test 0.871
# Epoch 085 | loss 0.3435 | train 0.938 | val 0.852 | test 0.869
# Epoch 090 | loss 0.3375 | train 0.938 | val 0.859 | test 0.871
# Epoch 095 | loss 0.3330 | train 0.940 | val 0.856 | test 0.866
# Epoch 100 | loss 0.3086 | train 0.942 | val 0.852 | test 0.862
# Epoch 105 | loss 0.3267 | train 0.944 | val 0.859 | test 0.862
# Epoch 110 | loss 0.2809 | train 0.947 | val 0.863 | test 0.862
# Epoch 115 | loss 0.2891 | train 0.945 | val 0.859 | test 0.862
# ✅ Final (best-val) | train 0.907 | val 0.878 | test 0.864
# Epoch 000 | loss 1.9305 | train 0.305 | val 0.296 | test 0.300
# Epoch 005 | loss 1.7104 | train 0.314 | val 0.307 | test 0.308
# Epoch 010 | loss 1.4833 | train 0.491 | val 0.459 | test 0.490
# Epoch 015 | loss 1.2863 | train 0.611 | val 0.570 | test 0.611
# Epoch 020 | loss 1.0879 | train 0.731 | val 0.704 | test 0.709
# Epoch 025 | loss 0.9240 | train 0.822 | val 0.785 | test 0.773
# Epoch 030 | loss 0.7572 | train 0.871 | val 0.822 | test 0.823
# Epoch 035 | loss 0.6622 | train 0.889 | val 0.852 | test 0.856
# Epoch 040 | loss 0.5770 | train 0.908 | val 0.863 | test 0.866
# Epoch 045 | loss 0.5134 | train 0.920 | val 0.867 | test 0.869
# Epoch 050 | loss 0.4793 | train 0.923 | val 0.867 | test 0.871
# Epoch 055 | loss 0.4372 | train 0.924 | val 0.867 | test 0.873
# Epoch 060 | loss 0.4154 | train 0.927 | val 0.863 | test 0.875
# Epoch 065 | loss 0.4124 | train 0.929 | val 0.863 | test 0.873
# Epoch 070 | loss 0.3699 | train 0.931 | val 0.856 | test 0.864
# Epoch 075 | loss 0.3740 | train 0.936 | val 0.856 | test 0.867
# Epoch 080 | loss 0.3437 | train 0.936 | val 0.856 | test 0.860
# Epoch 085 | loss 0.3462 | train 0.936 | val 0.856 | test 0.860
# Epoch 090 | loss 0.3459 | train 0.938 | val 0.856 | test 0.866
# Epoch 095 | loss 0.3076 | train 0.942 | val 0.856 | test 0.867
# Epoch 100 | loss 0.3183 | train 0.937 | val 0.856 | test 0.867
# Epoch 105 | loss 0.3186 | train 0.942 | val 0.859 | test 0.867
# Epoch 110 | loss 0.2956 | train 0.944 | val 0.863 | test 0.864
# Epoch 115 | loss 0.2752 | train 0.947 | val 0.859 | test 0.855
# ✅ Final (best-val) | train 0.918 | val 0.874 | test 0.867
# Epoch 000 | loss 1.9289 | train 0.322 | val 0.333 | test 0.309
# Epoch 005 | loss 1.6688 | train 0.336 | val 0.337 | test 0.326
# Epoch 010 | loss 1.4607 | train 0.544 | val 0.526 | test 0.514
# Epoch 015 | loss 1.2555 | train 0.683 | val 0.644 | test 0.657
# Epoch 020 | loss 1.0882 | train 0.728 | val 0.700 | test 0.709
# Epoch 025 | loss 0.9308 | train 0.778 | val 0.763 | test 0.766
# Epoch 030 | loss 0.8181 | train 0.822 | val 0.781 | test 0.799
# Epoch 035 | loss 0.7021 | train 0.840 | val 0.800 | test 0.810
# Epoch 040 | loss 0.6133 | train 0.880 | val 0.837 | test 0.836
# Epoch 045 | loss 0.5495 | train 0.907 | val 0.863 | test 0.862
# Epoch 050 | loss 0.4866 | train 0.915 | val 0.874 | test 0.869
# Epoch 055 | loss 0.4602 | train 0.923 | val 0.881 | test 0.869
# Epoch 060 | loss 0.4245 | train 0.926 | val 0.870 | test 0.867
# Epoch 065 | loss 0.4183 | train 0.929 | val 0.870 | test 0.871
# Epoch 070 | loss 0.3873 | train 0.929 | val 0.859 | test 0.866
# Epoch 075 | loss 0.3648 | train 0.931 | val 0.870 | test 0.862
# Epoch 080 | loss 0.3624 | train 0.935 | val 0.863 | test 0.864
# Epoch 085 | loss 0.3345 | train 0.939 | val 0.870 | test 0.866
# Epoch 090 | loss 0.3253 | train 0.936 | val 0.863 | test 0.864
# Epoch 095 | loss 0.3347 | train 0.943 | val 0.867 | test 0.866
# Epoch 100 | loss 0.3145 | train 0.944 | val 0.870 | test 0.866
# Epoch 105 | loss 0.3078 | train 0.945 | val 0.856 | test 0.860
# Epoch 110 | loss 0.3001 | train 0.948 | val 0.867 | test 0.862
# Epoch 115 | loss 0.2962 | train 0.946 | val 0.856 | test 0.864
# ✅ Final (best-val) | train 0.919 | val 0.881 | test 0.869
# Epoch 000 | loss 1.9353 | train 0.315 | val 0.289 | test 0.302
# Epoch 005 | loss 1.6806 | train 0.439 | val 0.426 | test 0.429
# Epoch 010 | loss 1.4293 | train 0.530 | val 0.526 | test 0.505
# Epoch 015 | loss 1.2049 | train 0.705 | val 0.704 | test 0.689
# Epoch 020 | loss 0.9949 | train 0.855 | val 0.826 | test 0.808
# Epoch 025 | loss 0.8222 | train 0.897 | val 0.859 | test 0.856
# Epoch 030 | loss 0.6777 | train 0.906 | val 0.870 | test 0.864
# Epoch 035 | loss 0.5792 | train 0.912 | val 0.870 | test 0.864
# Epoch 040 | loss 0.5285 | train 0.917 | val 0.878 | test 0.875
# Epoch 045 | loss 0.4770 | train 0.926 | val 0.874 | test 0.873
# Epoch 050 | loss 0.4300 | train 0.928 | val 0.867 | test 0.877
# Epoch 055 | loss 0.4305 | train 0.929 | val 0.867 | test 0.878
# Epoch 060 | loss 0.3887 | train 0.931 | val 0.859 | test 0.873
# Epoch 065 | loss 0.3807 | train 0.935 | val 0.863 | test 0.867
# Epoch 070 | loss 0.3592 | train 0.936 | val 0.863 | test 0.867
# Epoch 075 | loss 0.3327 | train 0.939 | val 0.867 | test 0.871
# Epoch 080 | loss 0.3257 | train 0.938 | val 0.859 | test 0.867
# Epoch 085 | loss 0.3264 | train 0.940 | val 0.870 | test 0.875
# Epoch 090 | loss 0.3040 | train 0.941 | val 0.867 | test 0.867
# Epoch 095 | loss 0.3143 | train 0.944 | val 0.870 | test 0.869
# Epoch 100 | loss 0.3169 | train 0.946 | val 0.867 | test 0.866
# Epoch 105 | loss 0.2942 | train 0.946 | val 0.867 | test 0.867
# Epoch 110 | loss 0.3040 | train 0.948 | val 0.867 | test 0.860
# Epoch 115 | loss 0.2853 | train 0.949 | val 0.863 | test 0.858
# ✅ Final (best-val) | train 0.917 | val 0.878 | test 0.875
# Epoch 000 | loss 1.9557 | train 0.357 | val 0.333 | test 0.335
# Epoch 005 | loss 1.7918 | train 0.518 | val 0.507 | test 0.494
# Epoch 010 | loss 1.5657 | train 0.652 | val 0.641 | test 0.648
# Epoch 015 | loss 1.3649 | train 0.665 | val 0.652 | test 0.654
# Epoch 020 | loss 1.1579 | train 0.702 | val 0.678 | test 0.692
# Epoch 025 | loss 0.9815 | train 0.764 | val 0.733 | test 0.753
# Epoch 030 | loss 0.8332 | train 0.835 | val 0.785 | test 0.808
# Epoch 035 | loss 0.7526 | train 0.886 | val 0.837 | test 0.847
# Epoch 040 | loss 0.6352 | train 0.906 | val 0.874 | test 0.862
# Epoch 045 | loss 0.5868 | train 0.911 | val 0.863 | test 0.862
# Epoch 050 | loss 0.5169 | train 0.916 | val 0.867 | test 0.871
# Epoch 055 | loss 0.4920 | train 0.921 | val 0.863 | test 0.869
# Epoch 060 | loss 0.4733 | train 0.925 | val 0.863 | test 0.875
# Epoch 065 | loss 0.4099 | train 0.926 | val 0.867 | test 0.869
# Epoch 070 | loss 0.4124 | train 0.929 | val 0.870 | test 0.867
# Epoch 075 | loss 0.3829 | train 0.934 | val 0.856 | test 0.871
# Epoch 080 | loss 0.3619 | train 0.935 | val 0.856 | test 0.867
# Epoch 085 | loss 0.3383 | train 0.935 | val 0.856 | test 0.855
# Epoch 090 | loss 0.3404 | train 0.937 | val 0.852 | test 0.862
# Epoch 095 | loss 0.3438 | train 0.939 | val 0.856 | test 0.855
# Epoch 100 | loss 0.3437 | train 0.943 | val 0.852 | test 0.864
# Epoch 105 | loss 0.3021 | train 0.941 | val 0.844 | test 0.864
# Epoch 110 | loss 0.3180 | train 0.942 | val 0.856 | test 0.866
# Epoch 115 | loss 0.3090 | train 0.945 | val 0.852 | test 0.858
# ✅ Final (best-val) | train 0.906 | val 0.874 | test 0.862
# Epoch 000 | loss 1.9595 | train 0.198 | val 0.174 | test 0.186
# Epoch 005 | loss 1.8378 | train 0.579 | val 0.574 | test 0.569
# Epoch 010 | loss 1.6498 | train 0.770 | val 0.774 | test 0.748
# Epoch 015 | loss 1.4065 | train 0.817 | val 0.804 | test 0.799
# Epoch 020 | loss 1.1729 | train 0.831 | val 0.811 | test 0.805
# Epoch 025 | loss 0.9870 | train 0.854 | val 0.826 | test 0.827
# Epoch 030 | loss 0.8514 | train 0.884 | val 0.852 | test 0.851
# Epoch 035 | loss 0.6836 | train 0.901 | val 0.863 | test 0.867
# Epoch 040 | loss 0.5870 | train 0.910 | val 0.863 | test 0.867
# Epoch 045 | loss 0.5049 | train 0.916 | val 0.856 | test 0.862
# Epoch 050 | loss 0.4743 | train 0.917 | val 0.867 | test 0.867
# Epoch 055 | loss 0.4437 | train 0.921 | val 0.870 | test 0.858
# Epoch 060 | loss 0.4182 | train 0.926 | val 0.867 | test 0.866
# Epoch 065 | loss 0.3876 | train 0.931 | val 0.859 | test 0.864
# Epoch 070 | loss 0.3681 | train 0.932 | val 0.863 | test 0.869
# Epoch 075 | loss 0.3521 | train 0.934 | val 0.867 | test 0.867
# Epoch 080 | loss 0.3478 | train 0.936 | val 0.867 | test 0.867
# Epoch 085 | loss 0.3306 | train 0.937 | val 0.859 | test 0.864
# Epoch 090 | loss 0.3204 | train 0.941 | val 0.863 | test 0.864
# Epoch 095 | loss 0.3256 | train 0.941 | val 0.867 | test 0.864
# Epoch 100 | loss 0.3062 | train 0.944 | val 0.867 | test 0.864
# Epoch 105 | loss 0.3082 | train 0.946 | val 0.867 | test 0.866
# Epoch 110 | loss 0.3172 | train 0.946 | val 0.863 | test 0.862
# Epoch 115 | loss 0.2918 | train 0.947 | val 0.859 | test 0.860
# ✅ Final (best-val) | train 0.923 | val 0.874 | test 0.858
# Epoch 000 | loss 1.9790 | train 0.182 | val 0.174 | test 0.182
# Epoch 005 | loss 1.8708 | train 0.281 | val 0.270 | test 0.295
# Epoch 010 | loss 1.7392 | train 0.367 | val 0.348 | test 0.361
# Epoch 015 | loss 1.5722 | train 0.480 | val 0.444 | test 0.468
# Epoch 020 | loss 1.4056 | train 0.593 | val 0.559 | test 0.567
# Epoch 025 | loss 1.2568 | train 0.727 | val 0.674 | test 0.696
# Epoch 030 | loss 1.0794 | train 0.827 | val 0.793 | test 0.799
# Epoch 035 | loss 0.9604 | train 0.891 | val 0.841 | test 0.842
# Epoch 040 | loss 0.8197 | train 0.902 | val 0.856 | test 0.853
# Epoch 045 | loss 0.6966 | train 0.912 | val 0.859 | test 0.869
# Epoch 050 | loss 0.6202 | train 0.916 | val 0.856 | test 0.871
# Epoch 055 | loss 0.5214 | train 0.924 | val 0.870 | test 0.886
# Epoch 060 | loss 0.4991 | train 0.925 | val 0.874 | test 0.877
# Epoch 065 | loss 0.4207 | train 0.928 | val 0.870 | test 0.882
# Epoch 070 | loss 0.4265 | train 0.928 | val 0.859 | test 0.877
# Epoch 075 | loss 0.3940 | train 0.931 | val 0.859 | test 0.877
# Epoch 080 | loss 0.3614 | train 0.934 | val 0.859 | test 0.878
# Epoch 085 | loss 0.3432 | train 0.939 | val 0.859 | test 0.871
# Epoch 090 | loss 0.3176 | train 0.937 | val 0.856 | test 0.869
# Epoch 095 | loss 0.3348 | train 0.941 | val 0.859 | test 0.866
# Epoch 100 | loss 0.3371 | train 0.940 | val 0.859 | test 0.867
# Epoch 105 | loss 0.3079 | train 0.944 | val 0.859 | test 0.866
# Epoch 110 | loss 0.3251 | train 0.943 | val 0.859 | test 0.864
# Epoch 115 | loss 0.2945 | train 0.945 | val 0.856 | test 0.867
# ✅ Final (best-val) | train 0.924 | val 0.874 | test 0.877
# Epoch 000 | loss 1.9462 | train 0.317 | val 0.322 | test 0.326
# Epoch 005 | loss 1.7869 | train 0.346 | val 0.352 | test 0.348
# Epoch 010 | loss 1.5557 | train 0.469 | val 0.481 | test 0.449
# Epoch 015 | loss 1.3077 | train 0.713 | val 0.670 | test 0.685
# Epoch 020 | loss 1.0804 | train 0.791 | val 0.733 | test 0.766
# Epoch 025 | loss 0.9105 | train 0.817 | val 0.770 | test 0.807
# Epoch 030 | loss 0.7756 | train 0.837 | val 0.789 | test 0.818
# Epoch 035 | loss 0.6572 | train 0.860 | val 0.819 | test 0.836
# Epoch 040 | loss 0.5578 | train 0.912 | val 0.852 | test 0.869
# Epoch 045 | loss 0.5320 | train 0.922 | val 0.863 | test 0.866
# Epoch 050 | loss 0.4768 | train 0.920 | val 0.863 | test 0.873
# Epoch 055 | loss 0.4384 | train 0.925 | val 0.867 | test 0.875
# Epoch 060 | loss 0.4560 | train 0.925 | val 0.874 | test 0.869
# Epoch 065 | loss 0.3878 | train 0.928 | val 0.863 | test 0.875
# Epoch 070 | loss 0.4043 | train 0.929 | val 0.867 | test 0.873
# Epoch 075 | loss 0.3647 | train 0.930 | val 0.859 | test 0.866
# Epoch 080 | loss 0.3538 | train 0.937 | val 0.863 | test 0.866
# Epoch 085 | loss 0.3366 | train 0.941 | val 0.863 | test 0.873
# Epoch 090 | loss 0.3189 | train 0.941 | val 0.859 | test 0.855
# Epoch 095 | loss 0.3171 | train 0.945 | val 0.859 | test 0.862
# Epoch 100 | loss 0.3126 | train 0.944 | val 0.856 | test 0.858
# Epoch 105 | loss 0.3131 | train 0.948 | val 0.863 | test 0.866
# Epoch 110 | loss 0.2992 | train 0.946 | val 0.856 | test 0.862
# Epoch 115 | loss 0.2939 | train 0.947 | val 0.856 | test 0.856
# ✅ Final (best-val) | train 0.921 | val 0.874 | test 0.866
# Epoch 000 | loss 1.9493 | train 0.307 | val 0.307 | test 0.302
# Epoch 005 | loss 1.7847 | train 0.304 | val 0.296 | test 0.297
# Epoch 010 | loss 1.5891 | train 0.344 | val 0.322 | test 0.322
# Epoch 015 | loss 1.4033 | train 0.530 | val 0.507 | test 0.521
# Epoch 020 | loss 1.2116 | train 0.726 | val 0.689 | test 0.711
# Epoch 025 | loss 1.0358 | train 0.820 | val 0.789 | test 0.794
# Epoch 030 | loss 0.8714 | train 0.881 | val 0.833 | test 0.836
# Epoch 035 | loss 0.7059 | train 0.903 | val 0.852 | test 0.858
# Epoch 040 | loss 0.6230 | train 0.908 | val 0.874 | test 0.867
# Epoch 045 | loss 0.5729 | train 0.911 | val 0.863 | test 0.864
# Epoch 050 | loss 0.4934 | train 0.916 | val 0.863 | test 0.867
# Epoch 055 | loss 0.4471 | train 0.917 | val 0.863 | test 0.866
# Epoch 060 | loss 0.4171 | train 0.924 | val 0.863 | test 0.873
# Epoch 065 | loss 0.4212 | train 0.927 | val 0.859 | test 0.873
# Epoch 070 | loss 0.3775 | train 0.927 | val 0.859 | test 0.867
# Epoch 075 | loss 0.3816 | train 0.931 | val 0.856 | test 0.869
# Epoch 080 | loss 0.3392 | train 0.935 | val 0.856 | test 0.866
# Epoch 085 | loss 0.3367 | train 0.937 | val 0.856 | test 0.867
# Epoch 090 | loss 0.3219 | train 0.941 | val 0.852 | test 0.867
# Epoch 095 | loss 0.3097 | train 0.942 | val 0.852 | test 0.869
# Epoch 100 | loss 0.3157 | train 0.943 | val 0.856 | test 0.864
# Epoch 105 | loss 0.3075 | train 0.942 | val 0.856 | test 0.855
# Epoch 110 | loss 0.3008 | train 0.946 | val 0.856 | test 0.862
# Epoch 115 | loss 0.2972 | train 0.947 | val 0.852 | test 0.862
# ✅ Final (best-val) | train 0.908 | val 0.874 | test 0.867
# Epoch 000 | loss 1.9479 | train 0.388 | val 0.404 | test 0.379
# Epoch 005 | loss 1.7786 | train 0.519 | val 0.541 | test 0.506
# Epoch 010 | loss 1.5500 | train 0.607 | val 0.619 | test 0.591
# Epoch 015 | loss 1.2944 | train 0.725 | val 0.730 | test 0.718
# Epoch 020 | loss 1.0782 | train 0.791 | val 0.744 | test 0.781
# Epoch 025 | loss 0.9218 | train 0.861 | val 0.833 | test 0.832
# Epoch 030 | loss 0.7324 | train 0.885 | val 0.856 | test 0.853
# Epoch 035 | loss 0.6739 | train 0.903 | val 0.859 | test 0.847
# Epoch 040 | loss 0.5720 | train 0.910 | val 0.867 | test 0.862
# Epoch 045 | loss 0.4893 | train 0.916 | val 0.867 | test 0.869
# Epoch 050 | loss 0.4896 | train 0.920 | val 0.867 | test 0.873
# Epoch 055 | loss 0.4309 | train 0.926 | val 0.870 | test 0.873
# Epoch 060 | loss 0.4447 | train 0.928 | val 0.863 | test 0.871
# Epoch 065 | loss 0.3837 | train 0.929 | val 0.859 | test 0.867
# Epoch 070 | loss 0.3792 | train 0.933 | val 0.867 | test 0.871
# Epoch 075 | loss 0.3663 | train 0.934 | val 0.863 | test 0.871
# Epoch 080 | loss 0.3411 | train 0.933 | val 0.863 | test 0.873
# Epoch 085 | loss 0.3233 | train 0.936 | val 0.867 | test 0.867
# Epoch 090 | loss 0.3433 | train 0.936 | val 0.863 | test 0.867
# Epoch 095 | loss 0.3397 | train 0.940 | val 0.870 | test 0.866
# Epoch 100 | loss 0.3123 | train 0.940 | val 0.863 | test 0.862
# Epoch 105 | loss 0.2993 | train 0.942 | val 0.859 | test 0.864
# Epoch 110 | loss 0.2801 | train 0.944 | val 0.870 | test 0.862
# Epoch 115 | loss 0.3081 | train 0.945 | val 0.859 | test 0.860
# ✅ Final (best-val) | train 0.939 | val 0.874 | test 0.864
# Epoch 000 | loss 1.9388 | train 0.322 | val 0.304 | test 0.298
# Epoch 005 | loss 1.7071 | train 0.332 | val 0.326 | test 0.320
# Epoch 010 | loss 1.4703 | train 0.496 | val 0.496 | test 0.471
# Epoch 015 | loss 1.2705 | train 0.576 | val 0.567 | test 0.582
# Epoch 020 | loss 1.0749 | train 0.674 | val 0.644 | test 0.672
# Epoch 025 | loss 0.9277 | train 0.784 | val 0.726 | test 0.775
# Epoch 030 | loss 0.8188 | train 0.868 | val 0.793 | test 0.832
# Epoch 035 | loss 0.7147 | train 0.894 | val 0.830 | test 0.862
# Epoch 040 | loss 0.6114 | train 0.906 | val 0.841 | test 0.856
# Epoch 045 | loss 0.5381 | train 0.917 | val 0.859 | test 0.856
# Epoch 050 | loss 0.4887 | train 0.919 | val 0.859 | test 0.858
# Epoch 055 | loss 0.4611 | train 0.922 | val 0.859 | test 0.866
# Epoch 060 | loss 0.4193 | train 0.927 | val 0.856 | test 0.871
# Epoch 065 | loss 0.3860 | train 0.928 | val 0.856 | test 0.869
# Epoch 070 | loss 0.3791 | train 0.933 | val 0.859 | test 0.867
# Epoch 075 | loss 0.3650 | train 0.935 | val 0.859 | test 0.866
# Epoch 080 | loss 0.3613 | train 0.935 | val 0.863 | test 0.864
# Epoch 085 | loss 0.3297 | train 0.940 | val 0.867 | test 0.866
# Epoch 090 | loss 0.3483 | train 0.940 | val 0.863 | test 0.862
# Epoch 095 | loss 0.3400 | train 0.941 | val 0.863 | test 0.862
# Epoch 100 | loss 0.3269 | train 0.941 | val 0.859 | test 0.856
# Epoch 105 | loss 0.3281 | train 0.944 | val 0.856 | test 0.860
# Epoch 110 | loss 0.3032 | train 0.946 | val 0.856 | test 0.856
# Epoch 115 | loss 0.3058 | train 0.946 | val 0.852 | test 0.853
# ✅ Final (best-val) | train 0.926 | val 0.867 | test 0.871
# Epoch 000 | loss 1.9555 | train 0.235 | val 0.207 | test 0.243
# Epoch 005 | loss 1.8084 | train 0.324 | val 0.304 | test 0.326
# Epoch 010 | loss 1.6137 | train 0.548 | val 0.507 | test 0.560
# Epoch 015 | loss 1.4326 | train 0.707 | val 0.685 | test 0.709
# Epoch 020 | loss 1.2180 | train 0.777 | val 0.767 | test 0.766
# Epoch 025 | loss 1.0092 | train 0.813 | val 0.793 | test 0.783
# Epoch 030 | loss 0.9047 | train 0.822 | val 0.815 | test 0.797
# Epoch 035 | loss 0.8136 | train 0.844 | val 0.833 | test 0.808
# Epoch 040 | loss 0.7095 | train 0.884 | val 0.833 | test 0.840
# Epoch 045 | loss 0.6607 | train 0.907 | val 0.859 | test 0.858
# Epoch 050 | loss 0.5491 | train 0.918 | val 0.878 | test 0.871
# Epoch 055 | loss 0.5085 | train 0.924 | val 0.878 | test 0.869
# Epoch 060 | loss 0.4905 | train 0.927 | val 0.870 | test 0.875
# Epoch 065 | loss 0.4536 | train 0.928 | val 0.867 | test 0.873
# Epoch 070 | loss 0.4303 | train 0.929 | val 0.867 | test 0.867
# Epoch 075 | loss 0.4050 | train 0.932 | val 0.870 | test 0.869
# Epoch 080 | loss 0.3815 | train 0.934 | val 0.863 | test 0.869
# Epoch 085 | loss 0.3617 | train 0.936 | val 0.867 | test 0.864
# Epoch 090 | loss 0.3478 | train 0.939 | val 0.867 | test 0.867
# Epoch 095 | loss 0.3429 | train 0.936 | val 0.863 | test 0.866
# Epoch 100 | loss 0.3318 | train 0.942 | val 0.867 | test 0.866
# Epoch 105 | loss 0.3186 | train 0.940 | val 0.870 | test 0.864
# Epoch 110 | loss 0.3189 | train 0.944 | val 0.867 | test 0.867
# Epoch 115 | loss 0.2972 | train 0.947 | val 0.863 | test 0.867
# ✅ Final (best-val) | train 0.925 | val 0.881 | test 0.871
# Epoch 000 | loss 1.9423 | train 0.240 | val 0.263 | test 0.241
# Epoch 005 | loss 1.7674 | train 0.412 | val 0.400 | test 0.392
# Epoch 010 | loss 1.5398 | train 0.566 | val 0.563 | test 0.569
# Epoch 015 | loss 1.3270 | train 0.614 | val 0.615 | test 0.613
# Epoch 020 | loss 1.1627 | train 0.697 | val 0.674 | test 0.680
# Epoch 025 | loss 1.0050 | train 0.782 | val 0.774 | test 0.773
# Epoch 030 | loss 0.8450 | train 0.846 | val 0.815 | test 0.807
# Epoch 035 | loss 0.7328 | train 0.878 | val 0.856 | test 0.829
# Epoch 040 | loss 0.6491 | train 0.903 | val 0.870 | test 0.864
# Epoch 045 | loss 0.5806 | train 0.919 | val 0.870 | test 0.866
# Epoch 050 | loss 0.5596 | train 0.921 | val 0.874 | test 0.873
# Epoch 055 | loss 0.5104 | train 0.927 | val 0.870 | test 0.878
# Epoch 060 | loss 0.4389 | train 0.926 | val 0.859 | test 0.882
# Epoch 065 | loss 0.4357 | train 0.928 | val 0.867 | test 0.882
# ...
# Epoch 110 | loss 0.0681 | train 0.997 | val 0.870 | test 0.866
# Epoch 115 | loss 0.0750 | train 0.997 | val 0.863 | test 0.858
# ✅ Final (best-val) | train 0.930 | val 0.881 | test 0.867
# Epoch 000 | loss 1.9098 | train 0.304 | val 0.296 | test 0.298
# Epoch 005 | loss 1.5694 | train 0.317 | val 0.307 | test 0.308
# Epoch 010 | loss 1.0773 | train 0.818 | val 0.811 | test 0.781
# Epoch 015 | loss 0.6336 | train 0.903 | val 0.878 | test 0.864
# Epoch 020 | loss 0.4112 | train 0.923 | val 0.885 | test 0.875
# Epoch 025 | loss 0.3040 | train 0.939 | val 0.885 | test 0.877
# Epoch 030 | loss 0.2538 | train 0.948 | val 0.874 | test 0.875
# Epoch 035 | loss 0.2126 | train 0.963 | val 0.863 | test 0.882
# Epoch 040 | loss 0.1780 | train 0.969 | val 0.852 | test 0.873
# Epoch 045 | loss 0.1550 | train 0.973 | val 0.867 | test 0.869
# Epoch 050 | loss 0.1525 | train 0.980 | val 0.859 | test 0.873
# Epoch 055 | loss 0.1277 | train 0.986 | val 0.867 | test 0.871
# Epoch 060 | loss 0.1156 | train 0.989 | val 0.848 | test 0.871
# Epoch 065 | loss 0.1019 | train 0.992 | val 0.867 | test 0.871
# Epoch 070 | loss 0.1042 | train 0.992 | val 0.863 | test 0.869
# Epoch 075 | loss 0.0959 | train 0.993 | val 0.863 | test 0.867
# Epoch 080 | loss 0.0835 | train 0.997 | val 0.856 | test 0.862
# Epoch 085 | loss 0.0872 | train 0.995 | val 0.856 | test 0.856
# Epoch 090 | loss 0.0818 | train 0.995 | val 0.856 | test 0.862
# Epoch 095 | loss 0.0751 | train 0.995 | val 0.859 | test 0.860
# Epoch 100 | loss 0.0710 | train 0.995 | val 0.867 | test 0.864
# Epoch 105 | loss 0.0701 | train 0.996 | val 0.867 | test 0.858
# Epoch 110 | loss 0.0726 | train 0.999 | val 0.863 | test 0.860
# Epoch 115 | loss 0.0590 | train 0.999 | val 0.870 | test 0.860
# ✅ Final (best-val) | train 0.923 | val 0.885 | test 0.875
# Epoch 000 | loss 1.9357 | train 0.316 | val 0.307 | test 0.311
# Epoch 005 | loss 1.6075 | train 0.529 | val 0.485 | test 0.473
# Epoch 010 | loss 1.0760 | train 0.773 | val 0.752 | test 0.746
# Epoch 015 | loss 0.7116 | train 0.870 | val 0.819 | test 0.829
# Epoch 020 | loss 0.4979 | train 0.928 | val 0.885 | test 0.858
# Epoch 025 | loss 0.3744 | train 0.941 | val 0.893 | test 0.871
# Epoch 030 | loss 0.2714 | train 0.946 | val 0.863 | test 0.873
# Epoch 035 | loss 0.2199 | train 0.957 | val 0.856 | test 0.880
# Epoch 040 | loss 0.1868 | train 0.968 | val 0.867 | test 0.867
# Epoch 045 | loss 0.1731 | train 0.970 | val 0.867 | test 0.878
# Epoch 050 | loss 0.1509 | train 0.976 | val 0.870 | test 0.867
# Epoch 055 | loss 0.1276 | train 0.982 | val 0.863 | test 0.864
# Epoch 060 | loss 0.1161 | train 0.986 | val 0.863 | test 0.864
# Epoch 065 | loss 0.1026 | train 0.987 | val 0.867 | test 0.862
# Epoch 070 | loss 0.1103 | train 0.988 | val 0.859 | test 0.860
# Epoch 075 | loss 0.0972 | train 0.990 | val 0.852 | test 0.856
# Epoch 080 | loss 0.0955 | train 0.994 | val 0.859 | test 0.856
# Epoch 085 | loss 0.0835 | train 0.992 | val 0.867 | test 0.858
# Epoch 090 | loss 0.0893 | train 0.996 | val 0.848 | test 0.849
# Epoch 095 | loss 0.0872 | train 0.996 | val 0.859 | test 0.862
# Epoch 100 | loss 0.0812 | train 0.996 | val 0.867 | test 0.860
# Epoch 105 | loss 0.0898 | train 0.995 | val 0.867 | test 0.864
# Epoch 110 | loss 0.0686 | train 0.996 | val 0.863 | test 0.856
# Epoch 115 | loss 0.0725 | train 0.998 | val 0.859 | test 0.855
# ✅ Final (best-val) | train 0.934 | val 0.896 | test 0.867
# Epoch 000 | loss 1.9576 | train 0.409 | val 0.396 | test 0.387
# Epoch 005 | loss 1.6177 | train 0.357 | val 0.330 | test 0.335
# Epoch 010 | loss 1.1161 | train 0.855 | val 0.781 | test 0.807
# Epoch 015 | loss 0.6546 | train 0.910 | val 0.856 | test 0.851
# Epoch 020 | loss 0.4263 | train 0.921 | val 0.870 | test 0.873
# Epoch 025 | loss 0.3435 | train 0.934 | val 0.874 | test 0.878
# Epoch 030 | loss 0.2828 | train 0.938 | val 0.870 | test 0.880
# Epoch 035 | loss 0.2332 | train 0.950 | val 0.870 | test 0.875
# Epoch 040 | loss 0.2033 | train 0.959 | val 0.870 | test 0.866
# Epoch 045 | loss 0.1593 | train 0.973 | val 0.859 | test 0.871
# Epoch 050 | loss 0.1447 | train 0.980 | val 0.856 | test 0.866
# Epoch 055 | loss 0.1405 | train 0.984 | val 0.863 | test 0.864
# Epoch 060 | loss 0.1149 | train 0.987 | val 0.863 | test 0.866
# Epoch 065 | loss 0.1277 | train 0.986 | val 0.870 | test 0.866
# Epoch 070 | loss 0.1094 | train 0.990 | val 0.863 | test 0.858
# Epoch 075 | loss 0.0992 | train 0.991 | val 0.874 | test 0.867
# Epoch 080 | loss 0.0920 | train 0.993 | val 0.867 | test 0.864
# Epoch 085 | loss 0.0948 | train 0.995 | val 0.874 | test 0.860
# Epoch 090 | loss 0.0836 | train 0.996 | val 0.874 | test 0.858
# Epoch 095 | loss 0.0889 | train 0.996 | val 0.874 | test 0.853
# Epoch 100 | loss 0.0722 | train 0.996 | val 0.870 | test 0.851
# Epoch 105 | loss 0.0844 | train 0.997 | val 0.874 | test 0.853
# Epoch 110 | loss 0.0720 | train 0.996 | val 0.874 | test 0.856
# Epoch 115 | loss 0.0748 | train 0.998 | val 0.874 | test 0.855
# ✅ Final (best-val) | train 0.998 | val 0.885 | test 0.858
# Epoch 000 | loss 1.9574 | train 0.130 | val 0.144 | test 0.129
# Epoch 005 | loss 1.5941 | train 0.471 | val 0.441 | test 0.468
# Epoch 010 | loss 1.1282 | train 0.730 | val 0.707 | test 0.707
# Epoch 015 | loss 0.7067 | train 0.849 | val 0.830 | test 0.799
# Epoch 020 | loss 0.4854 | train 0.916 | val 0.867 | test 0.866
# Epoch 025 | loss 0.3769 | train 0.927 | val 0.867 | test 0.878
# Epoch 030 | loss 0.3014 | train 0.937 | val 0.878 | test 0.882
# Epoch 035 | loss 0.2376 | train 0.951 | val 0.878 | test 0.880
# Epoch 040 | loss 0.1925 | train 0.965 | val 0.863 | test 0.873
# Epoch 045 | loss 0.1836 | train 0.972 | val 0.863 | test 0.862
# Epoch 050 | loss 0.1510 | train 0.981 | val 0.859 | test 0.862
# Epoch 055 | loss 0.1429 | train 0.981 | val 0.859 | test 0.860
# Epoch 060 | loss 0.1367 | train 0.986 | val 0.863 | test 0.860
# Epoch 065 | loss 0.1237 | train 0.985 | val 0.867 | test 0.862
# Epoch 070 | loss 0.1081 | train 0.989 | val 0.867 | test 0.860
# Epoch 075 | loss 0.0967 | train 0.991 | val 0.878 | test 0.864
# Epoch 080 | loss 0.0963 | train 0.994 | val 0.863 | test 0.860
# Epoch 085 | loss 0.0858 | train 0.994 | val 0.856 | test 0.858
# Epoch 090 | loss 0.0861 | train 0.996 | val 0.867 | test 0.855
# Epoch 095 | loss 0.0828 | train 0.995 | val 0.859 | test 0.853
# Epoch 100 | loss 0.0769 | train 0.995 | val 0.867 | test 0.847
# Epoch 105 | loss 0.0870 | train 0.997 | val 0.863 | test 0.849
# Epoch 110 | loss 0.0753 | train 0.997 | val 0.867 | test 0.855
# Epoch 115 | loss 0.0701 | train 0.996 | val 0.863 | test 0.856
# ✅ Final (best-val) | train 0.950 | val 0.881 | test 0.884
# Epoch 000 | loss 1.9492 | train 0.321 | val 0.304 | test 0.315
# Epoch 005 | loss 1.5231 | train 0.474 | val 0.448 | test 0.481
# Epoch 010 | loss 1.0345 | train 0.772 | val 0.756 | test 0.735
# Epoch 015 | loss 0.6819 | train 0.848 | val 0.841 | test 0.803
# Epoch 020 | loss 0.4809 | train 0.887 | val 0.848 | test 0.834
# Epoch 025 | loss 0.3657 | train 0.935 | val 0.874 | test 0.873
# Epoch 030 | loss 0.2971 | train 0.941 | val 0.878 | test 0.871
# Epoch 035 | loss 0.2407 | train 0.957 | val 0.878 | test 0.875
# Epoch 040 | loss 0.1903 | train 0.965 | val 0.867 | test 0.864
# Epoch 045 | loss 0.1869 | train 0.975 | val 0.863 | test 0.856
# Epoch 050 | loss 0.1530 | train 0.977 | val 0.863 | test 0.858
# Epoch 055 | loss 0.1389 | train 0.986 | val 0.863 | test 0.864
# Epoch 060 | loss 0.1220 | train 0.987 | val 0.867 | test 0.858
# Epoch 065 | loss 0.1137 | train 0.993 | val 0.852 | test 0.862
# Epoch 070 | loss 0.1080 | train 0.991 | val 0.856 | test 0.860
# Epoch 075 | loss 0.1024 | train 0.996 | val 0.863 | test 0.855
# Epoch 080 | loss 0.0843 | train 0.995 | val 0.863 | test 0.860
# Epoch 085 | loss 0.0891 | train 0.996 | val 0.859 | test 0.847
# Epoch 090 | loss 0.0885 | train 0.995 | val 0.870 | test 0.860
# Epoch 095 | loss 0.0780 | train 0.997 | val 0.878 | test 0.853
# Epoch 100 | loss 0.0721 | train 0.996 | val 0.867 | test 0.853
# Epoch 105 | loss 0.0788 | train 0.996 | val 0.863 | test 0.855
# Epoch 110 | loss 0.0741 | train 0.998 | val 0.867 | test 0.855
# Epoch 115 | loss 0.0751 | train 0.999 | val 0.867 | test 0.847
# ✅ Final (best-val) | train 0.936 | val 0.881 | test 0.871
# Epoch 000 | loss 1.9735 | train 0.257 | val 0.263 | test 0.245
# Epoch 005 | loss 1.5891 | train 0.520 | val 0.500 | test 0.494
# Epoch 010 | loss 1.0658 | train 0.684 | val 0.644 | test 0.670
# Epoch 015 | loss 0.6960 | train 0.893 | val 0.811 | test 0.842
# Epoch 020 | loss 0.4373 | train 0.930 | val 0.867 | test 0.871
# Epoch 025 | loss 0.3481 | train 0.938 | val 0.881 | test 0.873
# Epoch 030 | loss 0.2413 | train 0.948 | val 0.874 | test 0.880
# Epoch 035 | loss 0.2168 | train 0.958 | val 0.867 | test 0.873
# Epoch 040 | loss 0.1756 | train 0.966 | val 0.863 | test 0.875
# Epoch 045 | loss 0.1573 | train 0.977 | val 0.859 | test 0.882
# Epoch 050 | loss 0.1312 | train 0.981 | val 0.856 | test 0.873
# Epoch 055 | loss 0.1327 | train 0.986 | val 0.859 | test 0.878
# Epoch 060 | loss 0.1058 | train 0.989 | val 0.863 | test 0.873
# Epoch 065 | loss 0.1002 | train 0.991 | val 0.859 | test 0.873
# Epoch 070 | loss 0.0963 | train 0.993 | val 0.856 | test 0.862
# Epoch 075 | loss 0.0910 | train 0.995 | val 0.863 | test 0.871
# Epoch 080 | loss 0.0829 | train 0.996 | val 0.859 | test 0.858
# Epoch 085 | loss 0.0826 | train 0.995 | val 0.856 | test 0.867
# Epoch 090 | loss 0.0771 | train 0.997 | val 0.859 | test 0.869
# Epoch 095 | loss 0.0800 | train 0.998 | val 0.863 | test 0.858
# Epoch 100 | loss 0.0784 | train 0.998 | val 0.863 | test 0.862
# Epoch 105 | loss 0.0775 | train 0.999 | val 0.863 | test 0.860
# Epoch 110 | loss 0.0693 | train 0.998 | val 0.863 | test 0.858
# Epoch 115 | loss 0.0694 | train 0.999 | val 0.859 | test 0.860
# ✅ Final (best-val) | train 0.938 | val 0.881 | test 0.873
# Epoch 000 | loss 1.9707 | train 0.314 | val 0.241 | test 0.287
# Epoch 005 | loss 1.6333 | train 0.349 | val 0.356 | test 0.333
# Epoch 010 | loss 1.1830 | train 0.697 | val 0.667 | test 0.663
# Epoch 015 | loss 0.8033 | train 0.868 | val 0.774 | test 0.816
# Epoch 020 | loss 0.5127 | train 0.923 | val 0.870 | test 0.873
# Epoch 025 | loss 0.4013 | train 0.939 | val 0.878 | test 0.884
# Epoch 030 | loss 0.3062 | train 0.943 | val 0.874 | test 0.878
# Epoch 035 | loss 0.2389 | train 0.954 | val 0.870 | test 0.877
# Epoch 040 | loss 0.1947 | train 0.962 | val 0.863 | test 0.875
# Epoch 045 | loss 0.1566 | train 0.969 | val 0.863 | test 0.877
# Epoch 050 | loss 0.1455 | train 0.979 | val 0.867 | test 0.871
# Epoch 055 | loss 0.1379 | train 0.982 | val 0.867 | test 0.869
# Epoch 060 | loss 0.1140 | train 0.988 | val 0.859 | test 0.866
# Epoch 065 | loss 0.1168 | train 0.990 | val 0.859 | test 0.866
# Epoch 070 | loss 0.1095 | train 0.993 | val 0.856 | test 0.866
# Epoch 075 | loss 0.1002 | train 0.994 | val 0.863 | test 0.866
# Epoch 080 | loss 0.0924 | train 0.994 | val 0.856 | test 0.867
# Epoch 085 | loss 0.0827 | train 0.998 | val 0.856 | test 0.862
# Epoch 090 | loss 0.0816 | train 0.998 | val 0.856 | test 0.869
# Epoch 095 | loss 0.0655 | train 0.998 | val 0.863 | test 0.871
# Epoch 100 | loss 0.0710 | train 0.998 | val 0.848 | test 0.871
# Epoch 105 | loss 0.0715 | train 0.998 | val 0.856 | test 0.866
# Epoch 110 | loss 0.0642 | train 0.999 | val 0.863 | test 0.864
# Epoch 115 | loss 0.0624 | train 0.999 | val 0.859 | test 0.862
# ✅ Final (best-val) | train 0.930 | val 0.881 | test 0.877
# Epoch 000 | loss 1.9430 | train 0.380 | val 0.348 | test 0.366
# Epoch 005 | loss 1.6103 | train 0.343 | val 0.315 | test 0.330
# Epoch 010 | loss 1.1569 | train 0.765 | val 0.707 | test 0.735
# Epoch 015 | loss 0.7451 | train 0.872 | val 0.819 | test 0.810
# Epoch 020 | loss 0.5203 | train 0.922 | val 0.874 | test 0.866
# Epoch 025 | loss 0.3835 | train 0.934 | val 0.881 | test 0.880
# Epoch 030 | loss 0.2788 | train 0.943 | val 0.870 | test 0.878
# Epoch 035 | loss 0.2224 | train 0.958 | val 0.863 | test 0.877
# Epoch 040 | loss 0.1873 | train 0.971 | val 0.859 | test 0.873
# Epoch 045 | loss 0.1642 | train 0.976 | val 0.874 | test 0.869
# Epoch 050 | loss 0.1535 | train 0.982 | val 0.870 | test 0.867
# Epoch 055 | loss 0.1291 | train 0.986 | val 0.867 | test 0.866
# Epoch 060 | loss 0.1079 | train 0.990 | val 0.856 | test 0.862
# Epoch 065 | loss 0.0948 | train 0.993 | val 0.852 | test 0.860
# Epoch 070 | loss 0.1016 | train 0.994 | val 0.859 | test 0.853
# Epoch 075 | loss 0.0916 | train 0.995 | val 0.870 | test 0.866
# Epoch 080 | loss 0.0795 | train 0.996 | val 0.870 | test 0.866
# Epoch 085 | loss 0.0900 | train 0.995 | val 0.870 | test 0.858
# Epoch 090 | loss 0.0833 | train 0.998 | val 0.863 | test 0.860
# Epoch 095 | loss 0.0777 | train 0.999 | val 0.856 | test 0.860
# Epoch 100 | loss 0.0737 | train 0.999 | val 0.867 | test 0.858
# Epoch 105 | loss 0.0728 | train 0.999 | val 0.859 | test 0.862
# Epoch 110 | loss 0.0691 | train 0.999 | val 0.870 | test 0.860
# Epoch 115 | loss 0.0623 | train 0.999 | val 0.863 | test 0.856
# ✅ Final (best-val) | train 0.925 | val 0.893 | test 0.864
# Epoch 000 | loss 1.9370 | train 0.360 | val 0.344 | test 0.339
# Epoch 005 | loss 1.5062 | train 0.582 | val 0.567 | test 0.569
# Epoch 010 | loss 1.0088 | train 0.811 | val 0.748 | test 0.764
# Epoch 015 | loss 0.6774 | train 0.878 | val 0.844 | test 0.831
# Epoch 020 | loss 0.4658 | train 0.924 | val 0.870 | test 0.869
# Epoch 025 | loss 0.3563 | train 0.938 | val 0.874 | test 0.878
# Epoch 030 | loss 0.2782 | train 0.947 | val 0.889 | test 0.875
# Epoch 035 | loss 0.2139 | train 0.959 | val 0.856 | test 0.877
# Epoch 040 | loss 0.1819 | train 0.967 | val 0.870 | test 0.871
# Epoch 045 | loss 0.1695 | train 0.977 | val 0.870 | test 0.867
# Epoch 050 | loss 0.1438 | train 0.983 | val 0.867 | test 0.864
# Epoch 055 | loss 0.1410 | train 0.987 | val 0.859 | test 0.860
# Epoch 060 | loss 0.1301 | train 0.989 | val 0.863 | test 0.869
# Epoch 065 | loss 0.1260 | train 0.992 | val 0.867 | test 0.867
# Epoch 070 | loss 0.1094 | train 0.992 | val 0.863 | test 0.860
# Epoch 075 | loss 0.0961 | train 0.993 | val 0.863 | test 0.858
# Epoch 080 | loss 0.0970 | train 0.996 | val 0.856 | test 0.860
# Epoch 085 | loss 0.0885 | train 0.996 | val 0.859 | test 0.869
# Epoch 090 | loss 0.0806 | train 0.995 | val 0.870 | test 0.860
# Epoch 095 | loss 0.0752 | train 0.997 | val 0.863 | test 0.858
# Epoch 100 | loss 0.0829 | train 0.997 | val 0.867 | test 0.864
# Epoch 105 | loss 0.0723 | train 0.998 | val 0.863 | test 0.856
# Epoch 110 | loss 0.0753 | train 0.997 | val 0.867 | test 0.855
# Epoch 115 | loss 0.0698 | train 0.998 | val 0.867 | test 0.845
# ✅ Final (best-val) | train 0.947 | val 0.889 | test 0.875
# Epoch 000 | loss 2.0091 | train 0.183 | val 0.174 | test 0.201
# Epoch 005 | loss 1.6574 | train 0.328 | val 0.315 | test 0.311
# Epoch 010 | loss 1.1886 | train 0.796 | val 0.770 | test 0.759
# Epoch 015 | loss 0.7436 | train 0.878 | val 0.837 | test 0.820
# Epoch 020 | loss 0.4801 | train 0.922 | val 0.844 | test 0.866
# Epoch 025 | loss 0.3656 | train 0.935 | val 0.881 | test 0.880
# Epoch 030 | loss 0.2859 | train 0.942 | val 0.874 | test 0.880
# Epoch 035 | loss 0.2304 | train 0.954 | val 0.881 | test 0.882
# Epoch 040 | loss 0.1921 | train 0.966 | val 0.878 | test 0.877
# Epoch 045 | loss 0.1556 | train 0.978 | val 0.870 | test 0.873
# Epoch 050 | loss 0.1377 | train 0.982 | val 0.870 | test 0.869
# Epoch 055 | loss 0.1204 | train 0.986 | val 0.859 | test 0.867
# Epoch 060 | loss 0.1208 | train 0.991 | val 0.859 | test 0.867
# Epoch 065 | loss 0.1188 | train 0.992 | val 0.863 | test 0.871
# Epoch 070 | loss 0.0939 | train 0.994 | val 0.870 | test 0.858
# Epoch 075 | loss 0.0985 | train 0.995 | val 0.867 | test 0.860
# Epoch 080 | loss 0.0891 | train 0.995 | val 0.863 | test 0.864
# Epoch 085 | loss 0.0935 | train 0.998 | val 0.856 | test 0.853
# Epoch 090 | loss 0.0873 | train 0.997 | val 0.859 | test 0.864
# Epoch 095 | loss 0.0673 | train 0.997 | val 0.863 | test 0.855
# Epoch 100 | loss 0.0606 | train 0.997 | val 0.859 | test 0.858
# Epoch 105 | loss 0.0715 | train 0.997 | val 0.856 | test 0.858
# Epoch 110 | loss 0.0640 | train 0.998 | val 0.856 | test 0.858
# Epoch 115 | loss 0.0712 | train 0.998 | val 0.870 | test 0.855
# ✅ Final (best-val) | train 0.935 | val 0.889 | test 0.873
# F+ train/test: 50/50 | F- train/test: 50/50 (totals match budgets)

# %%
# =======================================================
#  Fingerprint set for node-level (P fingerprints)
# =======================================================
class FingerprintGraph(nn.Module):
    def __init__(self, n_nodes, feat_dim, sample_m, edge_init_p=0.05):
        super().__init__()
        self.n = n_nodes
        self.d = feat_dim
        self.m = min(sample_m, n_nodes)

        X = torch.empty(self.n, self.d).uniform_(-0.5, 0.5)
        self.X = nn.Parameter(X.to(device))

        A0 = (torch.rand(self.n, self.n, device=device) < edge_init_p).float()
        A0.fill_diagonal_(0.0)
        A0 = torch.maximum(A0, A0.T)
        self.A_logits = nn.Parameter(torch.logit(torch.clamp(A0, 1e-4, 1-1e-4)))

        self.sample_idx = torch.randperm(self.n, device=device)[:self.m]

    @torch.no_grad()
    def edge_index(self):
        A_prob = torch.sigmoid(self.A_logits)
        A_bin = (A_prob > 0.5).float()
        A_bin.fill_diagonal_(0.0)
        A_bin = torch.maximum(A_bin, A_bin.T)
        idx = A_bin.nonzero(as_tuple=False)
        if idx.numel() == 0:
            return torch.empty(2, 0, dtype=torch.long, device=device)
        return idx.t().contiguous()

    @torch.no_grad()
    def flip_topk_by_grad(self, gradA, topk=64, step=2.5):
        g = gradA.abs()
        triu = torch.triu(torch.ones_like(g), diagonal=1)
        scores = (g * triu).flatten()
        k = min(topk, scores.numel())
        if k == 0: return
        _, idxs = torch.topk(scores, k=k)
        r = self.n
        pairs = torch.stack((idxs // r, idxs % r), dim=1)
        A_prob = torch.sigmoid(self.A_logits).detach()
        for (u, v) in pairs.tolist():
            guv = gradA[u, v].item()
            exist = A_prob[u, v] > 0.5
            if exist and guv <= 0:
                self.A_logits.data[u, v] -= step
                self.A_logits.data[v, u] -= step
            elif (not exist) and guv >= 0:
                self.A_logits.data[u, v] += step
                self.A_logits.data[v, u] += step
        self.A_logits.data.fill_diagonal_(-10.0)

class FingerprintSet(nn.Module):
    def __init__(self, P, n_nodes, feat_dim, sample_m, edge_init_p=0.05, topk_edges=64, edge_step=2.5):
        super().__init__()
        self.P = P
        self.fps = nn.ModuleList([FingerprintGraph(n_nodes, feat_dim, sample_m, edge_init_p) for _ in range(P)]).to(device)
        self.topk_edges = topk_edges
        self.edge_step = edge_step

    def concat_outputs(self, model, *, require_grad: bool = False):
        outs = []
        model.eval()
        ctx = torch.enable_grad() if require_grad else torch.no_grad()
        with ctx:
            for fp in self.fps:
                ei = fp.edge_index()
                logits = model(fp.X, ei)
                probs  = F.softmax(logits, dim=-1)[fp.sample_idx].flatten()
                outs.append(probs)
        return torch.cat(outs, dim=0)

    def flip_adj_by_grad(self, surrogate_grad_list):
        for fp, g in zip(self.fps, surrogate_grad_list):
            fp.flip_topk_by_grad(g, topk=self.topk_edges, step=self.edge_step)

fp_set = FingerprintSet(
    P=CFG["FP_P"],
    n_nodes=CFG["FP_NODES"],
    feat_dim=num_feats,
    sample_m=CFG["FP_SAMPLE_M"],
    edge_init_p=CFG["FP_EDGE_INIT_P"],
    topk_edges=CFG["FP_EDGE_TOPK"],
    edge_step=CFG["EDGE_LOGIT_STEP"],
)

INPUT_DIM = CFG["FP_P"] * min(CFG["FP_SAMPLE_M"], CFG["FP_NODES"]) * num_classes
print("Univerifier input dim =", INPUT_DIM)
# Out:
# Univerifier input dim = 14336

# %%
# ========================================
#  Univerifier (binary classifier)
# ========================================
class Univerifier(nn.Module):
    def __init__(self, input_dim: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 128), nn.LeakyReLU(0.01),
            nn.Linear(128, 64),       nn.LeakyReLU(0.01),
            nn.Linear(64, 32),        nn.LeakyReLU(0.01),
            nn.Linear(32, 2),
        )
    def forward(self, x):
        return self.net(x)

V = Univerifier(INPUT_DIM).to(device)
opt_V = Adam(V.parameters(), lr=CFG["LR_V"])

# %%
# =====================================================
#  Joint learning (Algorithm-1 for node-level)
# =====================================================
models_pos_tr = [model_f.to(device)] + [m.to(device) for m in F_pos_tr]
models_neg_tr = [m.to(device) for m in F_neg_tr]
print(f"Train pools -> Pos: {len(models_pos_tr)} | Neg: {len(models_neg_tr)}")

def batch_from_pool(fp_set, pos_models, neg_models, *, require_grad: bool):
    X = []; y = []
    for m in pos_models:
        X.append(fp_set.concat_outputs(m, require_grad=require_grad)); y.append(1)
    for m in neg_models:
        X.append(fp_set.concat_outputs(m, require_grad=require_grad)); y.append(0)
    return torch.stack(X, dim=0), torch.tensor(y, device=device)

def surrogate_grad_A_for_fp(fp, model):
    # cosine-sim surrogate gradient from target model's first layer
    with torch.no_grad():
        ei = fp.edge_index()
        h  = model.conv1(fp.X, ei)
        h  = F.relu(h)
        hn = F.normalize(h, dim=-1)
        sim = hn @ hn.t()
        gradA = sim - 0.5
        return gradA.detach().cpu()

def update_features(fp_set, V, pos_models, neg_models, steps, lr_x):
    # freeze model params
    for m in pos_models + neg_models:
        for p in m.parameters(): p.requires_grad_(False)
    # turn on grad for X before building batch
    for fp in fp_set.fps:
        fp.X.requires_grad_(True)

    for _ in range(steps):
        Xb, yb = batch_from_pool(fp_set, pos_models, neg_models, require_grad=True)
        V.eval()
        for p in V.parameters(): p.requires_grad_(False)

        logits = V(Xb.to(device))
        loss = F.cross_entropy(logits, yb)

        for fp in fp_set.fps:
            if fp.X.grad is not None: fp.X.grad.zero_()
        loss.backward()

        with torch.no_grad():
            for fp in fp_set.fps:
                fp.X.add_(lr_x * fp.X.grad)
                fp.X.grad.zero_()

        for p in V.parameters(): p.requires_grad_(True)

    grads = [surrogate_grad_A_for_fp(fp, pos_models[0]) for fp in fp_set.fps]
    fp_set.flip_adj_by_grad(grads)

def update_verifier(fp_set, V, pos_models, neg_models, steps):
    for _ in range(steps):
        V.train()
        Xb, yb = batch_from_pool(fp_set, pos_models, neg_models, require_grad=False)
        logits = V(Xb.to(device))
        loss = F.cross_entropy(logits, yb)
        opt_V.zero_grad(); loss.backward(); opt_V.step()

for it in range(1, CFG["OUTER_ITERS"] + 1):
    update_features(fp_set, V, models_pos_tr, models_neg_tr, steps=CFG["FP_STEPS"], lr_x=CFG["LR_X"])
    update_verifier(fp_set, V, models_pos_tr, models_neg_tr, steps=CFG["V_STEPS"])

    V.eval()
    Xb, yb = batch_from_pool(fp_set, models_pos_tr, models_neg_tr, require_grad=False)
    with torch.no_grad():
        pred = V(Xb).argmax(dim=1)
        acc = (pred.cpu() == yb.cpu()).float().mean().item()
        pos_acc = (pred[:len(models_pos_tr)].cpu() == 1).float().mean().item()
        neg_acc = (pred[len(models_pos_tr):].cpu() == 0).float().mean().item()
    print(f"Iter {it:02d}/{CFG['OUTER_ITERS']} | train all {acc:.3f} | pos {pos_acc:.3f} | neg {neg_acc:.3f}")
# Out:
# Train pools -> Pos: 51 | Neg: 50
# Iter 01/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 02/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 03/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 04/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 05/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 06/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 07/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 08/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 09/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 10/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 11/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 12/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 13/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 14/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 15/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 16/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 17/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 18/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 19/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 20/20 | train all 1.000 | pos 1.000 | neg 1.000

# %%
# ==========================================================
#  Held-out verification (Robustness/Uniqueness/ARUC)
# ==========================================================
models_pos_te = [model_f.to(device)] + [m.to(device) for m in F_pos_te]
models_neg_te = [m.to(device) for m in F_neg_te]

@torch.no_grad()
def verify_scores(V, fp_set, models):
    Xs = [fp_set.concat_outputs(m, require_grad=False) for m in models]
    logits = V(torch.stack(Xs, dim=0).to(device))
    probs = F.softmax(logits, dim=-1)[:, 1]  # p(positive)
    return probs.detach().cpu().numpy()

p_pos = verify_scores(V, fp_set, models_pos_te)
p_neg = verify_scores(V, fp_set, models_neg_te)

def sweep_threshold(p_pos, p_neg, num=301):
    ths = np.linspace(0.0, 1.0, num=num)
    R = []; U = []; A = []
    for t in ths:
        tp = (p_pos >= t).mean()    # robustness
        tn = (p_neg <  t).mean()    # uniqueness
        R.append(tp); U.append(tn)
        A.append((tp + tn) / 2.0)   # balanced acc (pos/neg equal)
    return ths, np.array(R), np.array(U), np.array(A)

ths, R, U, A = sweep_threshold(p_pos, p_neg, num=301)
best_idx = A.argmax()
mean_acc = A.mean()

# numpy>=2.0 has trapezoid; fallback to trapz if unavailable
ARUC = np.trapezoid(np.minimum(R, U), ths) if hasattr(np, "trapezoid") else np.trapz(np.minimum(R, U), ths)

print(f"Best @ λ={ths[best_idx]:.3f} | Robustness={R[best_idx]:.3f} | Uniqueness={U[best_idx]:.3f} | MeanAcc*={A[best_idx]:.3f}")
print(f"Mean Test Accuracy (avg over λ): {mean_acc:.3f}")
print(f"ARUC (approx): {ARUC:.3f}")
# Out:
# Best @ λ=0.013 | Robustness=1.000 | Uniqueness=1.000 | MeanAcc*=1.000
# Mean Test Accuracy (avg over λ): 0.997
# ARUC (approx): 0.997

# %%
# ================================
#  ARUC Visualization (Plotting)
# ================================
import matplotlib.pyplot as plt

# Plot ARUC curve
plt.figure(figsize=(4, 3))

# Plot Robustness
plt.plot(ths, R, label="Robustness", color='b', linestyle='-', linewidth=2)

# Plot Uniqueness
plt.plot(ths, U, label="Uniqueness", color='g', linestyle='--', linewidth=2)

# Plot ARUC (area under curve of the minimum of robustness and uniqueness)
plt.plot(ths, np.minimum(R, U), label="ARUC", color='r', linestyle='-.', linewidth=2)

# Plot Formatting
plt.xlabel('Threshold λ', fontsize=12)
plt.ylabel('Metric Value', fontsize=12)
plt.title('ARUC Visualization', fontsize=14)
plt.legend(loc='best')

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# Print ARUC value for reference
print(f"Best @ λ={ths[best_idx]:.3f} | Robustness={R[best_idx]:.3f} | Uniqueness={U[best_idx]:.3f} | MeanAcc*={A[best_idx]:.3f}")
print(f"Mean Test Accuracy (avg over λ): {mean_acc:.3f}")
print(f"ARUC (approx): {ARUC:.3f}")
# Out:
# Best @ λ=0.013 | Robustness=1.000 | Uniqueness=1.000 | MeanAcc*=1.000
# Mean Test Accuracy (avg over λ): 0.997
# ARUC (approx): 0.997

# %%
# ================================
#  Plot All Curves Together
# ================================
plt.figure(figsize=(4, 3))

# Plot Robustness
plt.plot(ths, R, label="Robustness", color='b', linestyle='-', linewidth=2)

# Plot Uniqueness
plt.plot(ths, U, label="Uniqueness", color='g', linestyle='--', linewidth=2)

# Plot ARUC
plt.plot(ths, np.minimum(R, U), label="ARUC", color='r', linestyle='-.', linewidth=2)

# Plot Formatting
plt.xlabel('Threshold λ', fontsize=12)
plt.ylabel('Metric Value', fontsize=12)
plt.title('ARUC Visualization (All Curves)', fontsize=14)
plt.legend(loc='best')

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# Print corresponding values
print(f"Best @ λ={ths[best_idx]:.3f} | Robustness={R[best_idx]:.3f} | Uniqueness={U[best_idx]:.3f} | ARUC={np.minimum(R, U)[best_idx]:.3f}")
# Out:
# Best @ λ=0.013 | Robustness=1.000 | Uniqueness=1.000 | ARUC=1.000

# %%
# ================================
#  Plot Robustness Curve
# ================================
plt.figure(figsize=(4, 3))

# Plot Robustness
plt.plot(ths, R, label="Robustness", color='b', linestyle='-', linewidth=2)

# Plot Formatting
plt.xlabel('Threshold λ', fontsize=12)
plt.ylabel('Robustness', fontsize=12)
plt.title('Robustness Curve', fontsize=14)
plt.legend(loc='best')

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# Print corresponding values
print(f"Best @ λ={ths[best_idx]:.3f} | Robustness={R[best_idx]:.3f}")
# Out:
# Best @ λ=0.013 | Robustness=1.000

# %%
# ================================
#  Plot Uniqueness Curve
# ================================
plt.figure(figsize=(4, 3))

# Plot Uniqueness
plt.plot(ths, U, label="Uniqueness", color='g', linestyle='--', linewidth=2)

# Plot Formatting
plt.xlabel('Threshold λ', fontsize=12)
plt.ylabel('Uniqueness', fontsize=12)
plt.title('Uniqueness Curve', fontsize=14)
plt.legend(loc='best')

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# Print corresponding values
print(f"Best @ λ={ths[best_idx]:.3f} | Uniqueness={U[best_idx]:.3f}")
# Out:
# Best @ λ=0.013 | Uniqueness=1.000

# %%
# ================================
#  Plot ARUC Curve
# ================================
plt.figure(figsize=(4, 3))

# Plot ARUC (minimum of robustness and uniqueness)
plt.plot(ths, np.minimum(R, U), label="ARUC", color='r', linestyle='-.', linewidth=2)

# Plot Formatting
plt.xlabel('Threshold λ', fontsize=12)
plt.ylabel('ARUC', fontsize=12)
plt.title('ARUC Curve', fontsize=14)
plt.legend(loc='best')

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# Print corresponding values
print(f"Best @ λ={ths[best_idx]:.3f} | ARUC={np.minimum(R, U)[best_idx]:.3f}")
# Out:
# Best @ λ=0.013 | ARUC=1.000
