# %%
# ================================
#  Environment setup (Colab)
# ================================
# !pip -q install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu121
# !pip -q install torch-geometric torch-scatter torch-sparse torch-cluster -f https://data.pyg.org/whl/torch-2.3.0+cu121.html
print("✅ PyTorch & PyG install attempted.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 131.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 113.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 76.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 64.6 MB/s eta 0:00:00
# ✅ PyTorch & PyG install attempted.

# %%
# ================================
#  Imports & Utilities
# ================================
import os, random, copy
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam

from torch_geometric.datasets import Planetoid
from torch_geometric.nn import GCNConv, SAGEConv
from torch_geometric.utils import to_undirected, subgraph

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device:', device)

def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /usr/local/lib/python3.12/dist-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSs
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /usr/local/lib/python3.12/dist-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /usr/local/lib/python3.12/dist-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSs
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# /usr/local/lib/python3.12/dist-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /usr/local/lib/python3.12/dist-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSs
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# Device: cuda

# %%
# ================================
#  Load Citeseer + 7/1/2 split
# ================================
dataset = Planetoid(root='/content/data/Citeseer', name='Citeseer')
data = dataset[0]

def make_split(data, train_ratio=0.7, val_ratio=0.1, seed=1):
    g = torch.Generator().manual_seed(seed)
    idx = torch.randperm(data.num_nodes, generator=g)
    n = data.num_nodes
    n_tr = int(n*train_ratio); n_va = int(n*val_ratio)
    train_idx = idx[:n_tr]; val_idx = idx[n_tr:n_tr+n_va]; test_idx = idx[n_tr+n_va:]
    data.train_mask = torch.zeros(n, dtype=torch.bool); data.train_mask[train_idx]=True
    data.val_mask   = torch.zeros(n, dtype=torch.bool); data.val_mask[val_idx]=True
    data.test_mask  = torch.zeros(n, dtype=torch.bool); data.test_mask[test_idx]=True
    return data

data = make_split(data, 0.7, 0.1, seed=1)
data.edge_index = to_undirected(data.edge_index)

num_feats   = dataset.num_node_features
num_classes = dataset.num_classes
print(data)
print('Features:', num_feats, '| Classes:', num_classes)
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.test.index
# Processing...
# Data(x=[3327, 3703], edge_index=[2, 9104], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])
# Features: 3703 | Classes: 6
# Done!

# %%
# ================================
#  Config (paper-ish, Citeseer)
# ================================
CFG = dict(
    POS_TRAIN=50, POS_TEST=50,
    NEG_TRAIN=50, NEG_TEST=50,

    USE_FT_LAST=True, USE_FT_ALL=True,
    USE_PR_LAST=True, USE_PR_ALL=True,
    USE_DISTILL=True,
    DISTILL_STEPS=250,   # paper ~1000; adjust if GPU/time allows

    FP_P=64,
    FP_NODES=32,
    FP_SAMPLE_M=32,
    FP_EDGE_INIT_P=0.05,
    FP_EDGE_TOPK=96,
    EDGE_LOGIT_STEP=2.5,

    OUTER_ITERS=20,
    FP_STEPS=5,
    V_STEPS=10,

    LR_TARGET=0.005,
    WD_TARGET=5e-4,
    LR_V=1e-3,
    LR_X=1e-3,

    SEED=1,
)
print(CFG)
# Out:
# {'POS_TRAIN': 50, 'POS_TEST': 50, 'NEG_TRAIN': 50, 'NEG_TEST': 50, 'USE_FT_LAST': True, 'USE_FT_ALL': True, 'USE_PR_LAST': True, 'USE_PR_ALL': True, 'USE_DISTILL': True, 'DISTILL_STEPS': 250, 'FP_P': 64, 'FP_NODES': 32, 'FP_SAMPLE_M': 32, 'FP_EDGE_INIT_P': 0.05, 'FP_EDGE_TOPK': 96, 'EDGE_LOGIT_STEP': 2.5, 'OUTER_ITERS': 20, 'FP_STEPS': 5, 'V_STEPS': 10, 'LR_TARGET': 0.005, 'WD_TARGET': 0.0005, 'LR_V': 0.001, 'LR_X': 0.001, 'SEED': 1}

# %%
# ================================
#  Define 3-layer GNN models
# ================================
class GCN(nn.Module):
    def __init__(self, in_channels, hidden, out_channels, dropout=0.5):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden)
        self.conv2 = GCNConv(hidden, hidden)
        self.conv3 = GCNConv(hidden, out_channels)
        self.dropout = dropout
    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index); x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv2(x, edge_index); x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv3(x, edge_index)
        return x

class GraphSAGE(nn.Module):
    def __init__(self, in_channels, hidden, out_channels, dropout=0.5):
        super().__init__()
        self.conv1 = SAGEConv(in_channels, hidden)
        self.conv2 = SAGEConv(hidden, hidden)
        self.conv3 = SAGEConv(hidden, out_channels)
        self.dropout = dropout
    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index); x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv2(x, edge_index); x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv3(x, edge_index)
        return x

# %%
# ================================
# Cell 5: Train helpers
# ================================
@torch.no_grad()
def evaluate(model, data):
    model.eval()
    out = model(data.x, data.edge_index)
    pred = out.argmax(dim=1)
    accs = []
    for mask in [data.train_mask, data.val_mask, data.test_mask]:
        correct = (pred[mask] == data.y[mask]).sum().item()
        accs.append(correct / int(mask.sum()))
    return accs

def train_node_classifier(model, data, epochs=20, lr=0.005, wd=5e-4):
    model = model.to(device); data = data.to(device)
    opt = Adam(model.parameters(), lr=lr, weight_decay=wd)
    best = {'val': 0.0, 'state': None}
    for ep in range(epochs):
        model.train(); opt.zero_grad()
        out = model(data.x, data.edge_index)
        loss = F.cross_entropy(out[data.train_mask], data.y[data.train_mask])
        loss.backward(); opt.step()
        tr, va, te = evaluate(model, data)
        if va > best['val']:
            best['val'] = va; best['state'] = copy.deepcopy(model.state_dict())
        if ep % 5 == 0:
            print(f"Epoch {ep:03d} | loss {loss.item():.4f} | train {tr:.3f} | val {va:.3f} | test {te:.3f}")
    if best['state'] is not None:
        model.load_state_dict(best['state'])
    tr, va, te = evaluate(model, data)
    print(f"✅ Final (best-val) | train {tr:.3f} | val {va:.3f} | test {te:.3f}")
    return model

# %%
# ================================
# Cell 6: Train target model f (GCN)
# ================================
set_seed(CFG["SEED"])
model_f = GCN(num_feats, hidden=16, out_channels=num_classes, dropout=0.5)
model_f = train_node_classifier(model_f, data, epochs=200, lr=CFG["LR_TARGET"], wd=CFG["WD_TARGET"])
# Out:
# Epoch 000 | loss 1.7912 | train 0.360 | val 0.367 | test 0.331
# Epoch 005 | loss 1.5446 | train 0.720 | val 0.714 | test 0.685
# Epoch 010 | loss 1.2553 | train 0.768 | val 0.759 | test 0.736
# Epoch 015 | loss 1.0408 | train 0.790 | val 0.756 | test 0.744
# Epoch 020 | loss 0.8922 | train 0.805 | val 0.762 | test 0.757
# Epoch 025 | loss 0.7887 | train 0.827 | val 0.765 | test 0.766
# Epoch 030 | loss 0.7104 | train 0.838 | val 0.774 | test 0.763
# Epoch 035 | loss 0.6653 | train 0.848 | val 0.762 | test 0.768
# Epoch 040 | loss 0.6091 | train 0.854 | val 0.756 | test 0.769
# Epoch 045 | loss 0.5703 | train 0.865 | val 0.738 | test 0.769
# Epoch 050 | loss 0.5386 | train 0.867 | val 0.741 | test 0.771
# Epoch 055 | loss 0.5308 | train 0.876 | val 0.726 | test 0.766
# Epoch 060 | loss 0.5325 | train 0.877 | val 0.729 | test 0.768
# Epoch 065 | loss 0.4943 | train 0.882 | val 0.720 | test 0.766
# Epoch 070 | loss 0.4809 | train 0.884 | val 0.720 | test 0.763
# Epoch 075 | loss 0.4787 | train 0.890 | val 0.720 | test 0.762
# Epoch 080 | loss 0.4601 | train 0.889 | val 0.711 | test 0.766
# Epoch 085 | loss 0.4765 | train 0.888 | val 0.705 | test 0.763
# Epoch 090 | loss 0.4426 | train 0.892 | val 0.720 | test 0.756
# Epoch 095 | loss 0.4358 | train 0.893 | val 0.717 | test 0.753
# Epoch 100 | loss 0.4236 | train 0.892 | val 0.720 | test 0.754
# Epoch 105 | loss 0.4223 | train 0.892 | val 0.714 | test 0.760
# Epoch 110 | loss 0.4260 | train 0.893 | val 0.714 | test 0.760
# Epoch 115 | loss 0.4053 | train 0.898 | val 0.705 | test 0.760
# Epoch 120 | loss 0.4132 | train 0.904 | val 0.711 | test 0.747
# Epoch 125 | loss 0.4051 | train 0.905 | val 0.708 | test 0.756
# Epoch 130 | loss 0.3903 | train 0.902 | val 0.699 | test 0.754
# Epoch 135 | loss 0.3898 | train 0.905 | val 0.702 | test 0.750
# Epoch 140 | loss 0.3912 | train 0.903 | val 0.717 | test 0.744
# Epoch 145 | loss 0.3769 | train 0.909 | val 0.714 | test 0.747
# Epoch 150 | loss 0.3818 | train 0.909 | val 0.705 | test 0.747
# Epoch 155 | loss 0.3865 | train 0.910 | val 0.708 | test 0.747
# Epoch 160 | loss 0.3797 | train 0.909 | val 0.693 | test 0.751
# Epoch 165 | loss 0.3691 | train 0.910 | val 0.696 | test 0.745
# Epoch 170 | loss 0.3672 | train 0.907 | val 0.702 | test 0.747
# Epoch 175 | loss 0.3592 | train 0.911 | val 0.699 | test 0.745
# Epoch 180 | loss 0.3677 | train 0.911 | val 0.702 | test 0.744
# Epoch 185 | loss 0.3794 | train 0.908 | val 0.705 | test 0.742
# Epoch 190 | loss 0.3577 | train 0.917 | val 0.693 | test 0.739
# Epoch 195 | loss 0.3515 | train 0.917 | val 0.693 | test 0.735
# ✅ Final (best-val) | train 0.839 | val 0.777 | test 0.763

# %%
# =========================================
#  Build suspect models (F+ and F−)  [BUDGETED]
# =========================================
@torch.no_grad()
def reset_module(m):
    for layer in m.modules():
        if hasattr(layer, 'reset_parameters'):
            layer.reset_parameters()

def ft_model(base_model, data, last_only=True, epochs=10, lr=0.005, seed=123):
    set_seed(seed)
    m = copy.deepcopy(base_model).to(device)
    for p in m.parameters(): p.requires_grad_(not last_only)
    for p in m.conv3.parameters(): p.requires_grad_(True)  # last layer fine-tune
    opt = Adam(filter(lambda p: p.requires_grad, m.parameters()), lr=lr)
    for _ in range(epochs):
        m.train(); opt.zero_grad()
        out = m(data.x.to(device), data.edge_index.to(device))
        loss = F.cross_entropy(out[data.train_mask], data.y[data.train_mask])
        loss.backward(); opt.step()
    return m.eval()

def pr_model(base_model, data, last_only=True, epochs=10, lr=0.005, seed=456):
    set_seed(seed)
    m = copy.deepcopy(base_model).to(device)
    if last_only: reset_module(m.conv3)
    else:         reset_module(m)
    opt = Adam(m.parameters(), lr=lr)
    for _ in range(epochs):
        m.train(); opt.zero_grad()
        out = m(data.x.to(device), data.edge_index.to(device))
        loss = F.cross_entropy(out[data.train_mask], data.y[data.train_mask])
        loss.backward(); opt.step()
    return m.eval()

def make_student(arch='GCN', hidden=16):
    return (GCN(num_feats, hidden, num_classes, dropout=0.5).to(device)
            if arch=='GCN' else
            GraphSAGE(num_feats, hidden, num_classes, dropout=0.5).to(device))

def random_subgraph_idx(n, keep_ratio=0.6, seed=7):
    g = torch.Generator().manual_seed(seed)
    keep = int(n*keep_ratio)
    return torch.randperm(n, generator=g)[:keep]

def distill_from_teacher(teacher, data, arch='GCN', T=2.0, steps=250, lr=0.01, seed=777):
    set_seed(seed)
    student = make_student(arch, hidden=16)
    opt = Adam(student.parameters(), lr=lr)
    kl = nn.KLDivLoss(reduction='batchmean')
    x_all = data.x.to(device); ei_all = data.edge_index.to(device)
    for t in range(steps):
        keep_ratio = float(torch.empty(1).uniform_(0.5, 0.8))
        idx = random_subgraph_idx(data.num_nodes, keep_ratio=keep_ratio, seed=seed+t).to(device)
        ei_sub, _ = subgraph(idx, ei_all, relabel_nodes=True)
        x_sub = x_all[idx]
        with torch.no_grad():
            p_t = F.softmax(teacher(x_sub, ei_sub)/T, dim=-1)
        student.train(); opt.zero_grad()
        logit_s = student(x_sub, ei_sub)/T
        loss = kl(F.log_softmax(logit_s, dim=-1), p_t) * (T*T)
        loss.backward(); opt.step()
    return student.eval()

# ---- budget splitter ----
def _distribute_budget(total, keys):
    if not keys: return {}
    base = total // len(keys); rem = total - base*len(keys)
    out = {k: base for k in keys}
    for k in keys[:rem]: out[k] += 1
    return out

# ===== Positives (F+) =====
F_pos_all = []
pos_total = CFG["POS_TRAIN"] + CFG["POS_TEST"]
pos_keys = []
if CFG["USE_FT_LAST"]: pos_keys.append("FT_LAST")
if CFG["USE_FT_ALL"]:  pos_keys.append("FT_ALL")
if CFG["USE_PR_LAST"]: pos_keys.append("PR_LAST")
if CFG["USE_PR_ALL"]:  pos_keys.append("PR_ALL")
if CFG["USE_DISTILL"]: pos_keys.append("DISTILL")
pos_budget = _distribute_budget(pos_total, pos_keys)

seed_base = 10
for key in pos_keys:
    cnt = pos_budget[key]
    if key == "FT_LAST":
        for s in range(seed_base, seed_base+cnt):
            F_pos_all.append(ft_model(model_f, data, last_only=True,  epochs=10, seed=s))
        seed_base += cnt
    elif key == "FT_ALL":
        for s in range(seed_base, seed_base+cnt):
            F_pos_all.append(ft_model(model_f, data, last_only=False, epochs=10, seed=s))
        seed_base += cnt
    elif key == "PR_LAST":
        for s in range(seed_base, seed_base+cnt):
            F_pos_all.append(pr_model(model_f, data, last_only=True,  epochs=10, seed=s))
        seed_base += cnt
    elif key == "PR_ALL":
        for s in range(seed_base, seed_base+cnt):
            F_pos_all.append(pr_model(model_f, data, last_only=False, epochs=10, seed=s))
        seed_base += cnt
    elif key == "DISTILL":
        arches = (['GCN'] * (cnt//2) + ['SAGE'] * (cnt - cnt//2))
        for i, arch in enumerate(arches, 400):
            F_pos_all.append(distill_from_teacher(model_f, data, arch=arch,
                                                  T=2.0, steps=CFG["DISTILL_STEPS"], seed=1000+i))
        seed_base += cnt

assert len(F_pos_all) == pos_total, f"Expected {pos_total} positives, got {len(F_pos_all)}"

# ===== Negatives (F−) =====
F_neg_all = []
neg_total = CFG["NEG_TRAIN"] + CFG["NEG_TEST"]
neg_keys = ["GCN", "SAGE"]
neg_budget = _distribute_budget(neg_total, neg_keys)

seed_base = 500
for s in range(seed_base, seed_base+neg_budget["GCN"]):
    set_seed(s)
    m = GCN(num_feats, 16, num_classes, dropout=0.5)
    m = train_node_classifier(m, data, epochs=120, lr=CFG["LR_TARGET"], wd=CFG["WD_TARGET"])
    F_neg_all.append(m.eval())
seed_base += neg_budget["GCN"]
for s in range(seed_base, seed_base+neg_budget["SAGE"]):
    set_seed(s)
    m = GraphSAGE(num_feats, 32, num_classes, dropout=0.5)
    m = train_node_classifier(m, data, epochs=120, lr=CFG["LR_TARGET"], wd=CFG["WD_TARGET"])
    F_neg_all.append(m.eval())

# ===== Train/Test split =====
def split_pool(pool, n_train, n_test, seed=999):
    set_seed(seed)
    idx = torch.randperm(len(pool)).tolist()
    train = [pool[i] for i in idx[:n_train]]
    test  = [pool[i] for i in idx[n_train:n_train+n_test]]
    return train, test

F_pos_tr, F_pos_te = split_pool(F_pos_all, CFG["POS_TRAIN"], CFG["POS_TEST"])
F_neg_tr, F_neg_te = split_pool(F_neg_all, CFG["NEG_TRAIN"], CFG["NEG_TEST"])

print(f"F+ train/test: {len(F_pos_tr)}/{len(F_pos_te)} | F- train/test: {len(F_neg_tr)}/{len(F_neg_te)} (totals match budgets)")
# Out:
# Epoch 000 | loss 1.7936 | train 0.222 | val 0.223 | test 0.231
# Epoch 005 | loss 1.6162 | train 0.451 | val 0.401 | test 0.427
# Epoch 010 | loss 1.4141 | train 0.655 | val 0.593 | test 0.607
# Epoch 015 | loss 1.2149 | train 0.723 | val 0.657 | test 0.666
# Epoch 020 | loss 1.0191 | train 0.806 | val 0.726 | test 0.744
# Epoch 025 | loss 0.8580 | train 0.828 | val 0.741 | test 0.768
# Epoch 030 | loss 0.7909 | train 0.843 | val 0.747 | test 0.775
# Epoch 035 | loss 0.7048 | train 0.851 | val 0.738 | test 0.775
# Epoch 040 | loss 0.6545 | train 0.857 | val 0.738 | test 0.769
# Epoch 045 | loss 0.6302 | train 0.866 | val 0.729 | test 0.766
# Epoch 050 | loss 0.5910 | train 0.869 | val 0.726 | test 0.775
# Epoch 055 | loss 0.5610 | train 0.872 | val 0.711 | test 0.774
# Epoch 060 | loss 0.5442 | train 0.876 | val 0.714 | test 0.760
# Epoch 065 | loss 0.5242 | train 0.877 | val 0.714 | test 0.762
# Epoch 070 | loss 0.5106 | train 0.881 | val 0.717 | test 0.759
# Epoch 075 | loss 0.5089 | train 0.883 | val 0.711 | test 0.762
# Epoch 080 | loss 0.4635 | train 0.887 | val 0.708 | test 0.771
# Epoch 085 | loss 0.4556 | train 0.892 | val 0.705 | test 0.757
# Epoch 090 | loss 0.4584 | train 0.890 | val 0.699 | test 0.756
# Epoch 095 | loss 0.4479 | train 0.893 | val 0.693 | test 0.756
# Epoch 100 | loss 0.4442 | train 0.890 | val 0.699 | test 0.745
# Epoch 105 | loss 0.4365 | train 0.893 | val 0.705 | test 0.745
# Epoch 110 | loss 0.4270 | train 0.893 | val 0.702 | test 0.747
# Epoch 115 | loss 0.4310 | train 0.895 | val 0.693 | test 0.753
# ✅ Final (best-val) | train 0.839 | val 0.753 | test 0.772
# Epoch 000 | loss 1.7859 | train 0.299 | val 0.262 | test 0.267
# Epoch 005 | loss 1.5117 | train 0.419 | val 0.373 | test 0.361
# Epoch 010 | loss 1.2552 | train 0.738 | val 0.654 | test 0.681
# Epoch 015 | loss 1.0708 | train 0.787 | val 0.723 | test 0.738
# Epoch 020 | loss 0.9255 | train 0.817 | val 0.744 | test 0.765
# Epoch 025 | loss 0.8323 | train 0.831 | val 0.750 | test 0.766
# Epoch 030 | loss 0.7289 | train 0.840 | val 0.735 | test 0.757
# Epoch 035 | loss 0.7048 | train 0.848 | val 0.744 | test 0.760
# Epoch 040 | loss 0.6342 | train 0.858 | val 0.735 | test 0.756
# Epoch 045 | loss 0.6321 | train 0.861 | val 0.729 | test 0.754
# Epoch 050 | loss 0.5915 | train 0.868 | val 0.714 | test 0.757
# Epoch 055 | loss 0.5530 | train 0.867 | val 0.723 | test 0.763
# Epoch 060 | loss 0.5406 | train 0.873 | val 0.717 | test 0.756
# Epoch 065 | loss 0.5368 | train 0.877 | val 0.717 | test 0.763
# Epoch 070 | loss 0.5055 | train 0.880 | val 0.702 | test 0.757
# Epoch 075 | loss 0.5112 | train 0.881 | val 0.705 | test 0.757
# Epoch 080 | loss 0.4936 | train 0.882 | val 0.699 | test 0.751
# Epoch 085 | loss 0.5031 | train 0.884 | val 0.705 | test 0.745
# Epoch 090 | loss 0.4882 | train 0.890 | val 0.708 | test 0.744
# Epoch 095 | loss 0.4562 | train 0.889 | val 0.699 | test 0.747
# Epoch 100 | loss 0.4572 | train 0.893 | val 0.699 | test 0.751
# Epoch 105 | loss 0.4537 | train 0.890 | val 0.705 | test 0.751
# Epoch 110 | loss 0.4575 | train 0.892 | val 0.705 | test 0.750
# Epoch 115 | loss 0.4484 | train 0.895 | val 0.711 | test 0.756
# ✅ Final (best-val) | train 0.826 | val 0.759 | test 0.771
# Epoch 000 | loss 1.8018 | train 0.229 | val 0.190 | test 0.201
# Epoch 005 | loss 1.5663 | train 0.399 | val 0.340 | test 0.367
# Epoch 010 | loss 1.3358 | train 0.643 | val 0.578 | test 0.594
# Epoch 015 | loss 1.1337 | train 0.763 | val 0.693 | test 0.714
# Epoch 020 | loss 0.9674 | train 0.799 | val 0.732 | test 0.757
# Epoch 025 | loss 0.8650 | train 0.806 | val 0.738 | test 0.760
# Epoch 030 | loss 0.7551 | train 0.818 | val 0.738 | test 0.763
# Epoch 035 | loss 0.6980 | train 0.827 | val 0.747 | test 0.768
# Epoch 040 | loss 0.6690 | train 0.839 | val 0.747 | test 0.777
# Epoch 045 | loss 0.6088 | train 0.848 | val 0.729 | test 0.771
# Epoch 050 | loss 0.6172 | train 0.860 | val 0.717 | test 0.771
# Epoch 055 | loss 0.5565 | train 0.872 | val 0.726 | test 0.772
# Epoch 060 | loss 0.5416 | train 0.875 | val 0.720 | test 0.771
# Epoch 065 | loss 0.5123 | train 0.878 | val 0.720 | test 0.768
# Epoch 070 | loss 0.5061 | train 0.879 | val 0.714 | test 0.763
# Epoch 075 | loss 0.4976 | train 0.885 | val 0.714 | test 0.757
# Epoch 080 | loss 0.4670 | train 0.890 | val 0.717 | test 0.754
# Epoch 085 | loss 0.4649 | train 0.887 | val 0.708 | test 0.756
# Epoch 090 | loss 0.4520 | train 0.893 | val 0.699 | test 0.759
# Epoch 095 | loss 0.4455 | train 0.893 | val 0.702 | test 0.757
# Epoch 100 | loss 0.4396 | train 0.894 | val 0.699 | test 0.753
# Epoch 105 | loss 0.4237 | train 0.899 | val 0.699 | test 0.756
# Epoch 110 | loss 0.4206 | train 0.896 | val 0.711 | test 0.765
# Epoch 115 | loss 0.4185 | train 0.901 | val 0.699 | test 0.757
# ✅ Final (best-val) | train 0.821 | val 0.753 | test 0.763
# Epoch 000 | loss 1.7940 | train 0.289 | val 0.313 | test 0.274
# Epoch 005 | loss 1.5854 | train 0.556 | val 0.572 | test 0.520
# Epoch 010 | loss 1.3618 | train 0.646 | val 0.590 | test 0.577
# Epoch 015 | loss 1.1385 | train 0.787 | val 0.720 | test 0.715
# Epoch 020 | loss 0.9833 | train 0.812 | val 0.750 | test 0.753
# Epoch 025 | loss 0.8653 | train 0.819 | val 0.747 | test 0.766
# Epoch 030 | loss 0.7629 | train 0.837 | val 0.753 | test 0.774
# Epoch 035 | loss 0.7027 | train 0.844 | val 0.759 | test 0.774
# Epoch 040 | loss 0.6479 | train 0.853 | val 0.756 | test 0.769
# Epoch 045 | loss 0.6092 | train 0.860 | val 0.744 | test 0.765
# Epoch 050 | loss 0.5785 | train 0.866 | val 0.738 | test 0.759
# Epoch 055 | loss 0.5444 | train 0.870 | val 0.726 | test 0.759
# Epoch 060 | loss 0.5332 | train 0.874 | val 0.726 | test 0.763
# Epoch 065 | loss 0.5147 | train 0.875 | val 0.717 | test 0.766
# Epoch 070 | loss 0.5067 | train 0.878 | val 0.711 | test 0.768
# Epoch 075 | loss 0.4682 | train 0.881 | val 0.717 | test 0.759
# Epoch 080 | loss 0.4683 | train 0.884 | val 0.711 | test 0.759
# Epoch 085 | loss 0.4659 | train 0.884 | val 0.723 | test 0.753
# Epoch 090 | loss 0.4432 | train 0.887 | val 0.696 | test 0.751
# Epoch 095 | loss 0.4464 | train 0.891 | val 0.702 | test 0.751
# Epoch 100 | loss 0.4268 | train 0.893 | val 0.702 | test 0.748
# Epoch 105 | loss 0.4240 | train 0.896 | val 0.696 | test 0.739
# Epoch 110 | loss 0.4398 | train 0.896 | val 0.702 | test 0.748
# Epoch 115 | loss 0.4295 | train 0.896 | val 0.696 | test 0.748
# ✅ Final (best-val) | train 0.841 | val 0.765 | test 0.774
# Epoch 000 | loss 1.7858 | train 0.304 | val 0.274 | test 0.285
# Epoch 005 | loss 1.5032 | train 0.418 | val 0.355 | test 0.376
# Epoch 010 | loss 1.2897 | train 0.754 | val 0.648 | test 0.699
# Epoch 015 | loss 1.1223 | train 0.793 | val 0.717 | test 0.736
# Epoch 020 | loss 0.9384 | train 0.799 | val 0.732 | test 0.747
# Epoch 025 | loss 0.8293 | train 0.808 | val 0.732 | test 0.759
# Epoch 030 | loss 0.7478 | train 0.816 | val 0.726 | test 0.759
# Epoch 035 | loss 0.6812 | train 0.825 | val 0.726 | test 0.763
# Epoch 040 | loss 0.6604 | train 0.838 | val 0.723 | test 0.768
# Epoch 045 | loss 0.6177 | train 0.854 | val 0.720 | test 0.771
# Epoch 050 | loss 0.5750 | train 0.863 | val 0.717 | test 0.760
# Epoch 055 | loss 0.5564 | train 0.867 | val 0.714 | test 0.757
# Epoch 060 | loss 0.5367 | train 0.874 | val 0.708 | test 0.757
# Epoch 065 | loss 0.5282 | train 0.877 | val 0.702 | test 0.763
# Epoch 070 | loss 0.5128 | train 0.879 | val 0.702 | test 0.765
# Epoch 075 | loss 0.4735 | train 0.883 | val 0.705 | test 0.765
# Epoch 080 | loss 0.4805 | train 0.891 | val 0.702 | test 0.760
# Epoch 085 | loss 0.4653 | train 0.889 | val 0.708 | test 0.765
# Epoch 090 | loss 0.4457 | train 0.888 | val 0.699 | test 0.756
# Epoch 095 | loss 0.4595 | train 0.889 | val 0.702 | test 0.759
# Epoch 100 | loss 0.4540 | train 0.893 | val 0.702 | test 0.759
# Epoch 105 | loss 0.4266 | train 0.891 | val 0.708 | test 0.762
# Epoch 110 | loss 0.4341 | train 0.899 | val 0.708 | test 0.760
# Epoch 115 | loss 0.4042 | train 0.897 | val 0.705 | test 0.759
# ✅ Final (best-val) | train 0.798 | val 0.732 | test 0.745
# Epoch 000 | loss 1.7899 | train 0.274 | val 0.247 | test 0.261
# Epoch 005 | loss 1.5623 | train 0.485 | val 0.410 | test 0.432
# Epoch 010 | loss 1.3439 | train 0.698 | val 0.633 | test 0.646
# Epoch 015 | loss 1.1485 | train 0.784 | val 0.702 | test 0.726
# Epoch 020 | loss 0.9957 | train 0.797 | val 0.717 | test 0.742
# Epoch 025 | loss 0.8800 | train 0.808 | val 0.717 | test 0.745
# Epoch 030 | loss 0.7959 | train 0.817 | val 0.726 | test 0.756
# Epoch 035 | loss 0.7156 | train 0.827 | val 0.732 | test 0.757
# Epoch 040 | loss 0.6879 | train 0.845 | val 0.729 | test 0.756
# Epoch 045 | loss 0.6364 | train 0.859 | val 0.729 | test 0.769
# Epoch 050 | loss 0.5912 | train 0.865 | val 0.720 | test 0.766
# Epoch 055 | loss 0.5645 | train 0.872 | val 0.714 | test 0.769
# Epoch 060 | loss 0.5480 | train 0.873 | val 0.714 | test 0.769
# Epoch 065 | loss 0.5203 | train 0.878 | val 0.705 | test 0.762
# Epoch 070 | loss 0.4959 | train 0.882 | val 0.714 | test 0.762
# Epoch 075 | loss 0.4771 | train 0.885 | val 0.705 | test 0.753
# Epoch 080 | loss 0.4715 | train 0.887 | val 0.702 | test 0.759
# Epoch 085 | loss 0.4598 | train 0.892 | val 0.699 | test 0.759
# Epoch 090 | loss 0.4601 | train 0.896 | val 0.699 | test 0.757
# Epoch 095 | loss 0.4566 | train 0.894 | val 0.699 | test 0.762
# Epoch 100 | loss 0.4372 | train 0.896 | val 0.705 | test 0.759
# Epoch 105 | loss 0.4317 | train 0.896 | val 0.714 | test 0.750
# Epoch 110 | loss 0.4077 | train 0.899 | val 0.699 | test 0.753
# Epoch 115 | loss 0.4216 | train 0.902 | val 0.705 | test 0.745
# ✅ Final (best-val) | train 0.837 | val 0.747 | test 0.751
# Epoch 000 | loss 1.7898 | train 0.351 | val 0.322 | test 0.313
# Epoch 005 | loss 1.5179 | train 0.553 | val 0.488 | test 0.489
# Epoch 010 | loss 1.2521 | train 0.770 | val 0.714 | test 0.712
# Epoch 015 | loss 1.0436 | train 0.794 | val 0.729 | test 0.736
# Epoch 020 | loss 0.9359 | train 0.813 | val 0.744 | test 0.757
# Epoch 025 | loss 0.8207 | train 0.829 | val 0.750 | test 0.768
# Epoch 030 | loss 0.7467 | train 0.845 | val 0.735 | test 0.765
# Epoch 035 | loss 0.6683 | train 0.849 | val 0.729 | test 0.756
# Epoch 040 | loss 0.6289 | train 0.862 | val 0.732 | test 0.759
# Epoch 045 | loss 0.5897 | train 0.869 | val 0.735 | test 0.759
# Epoch 050 | loss 0.5504 | train 0.866 | val 0.732 | test 0.760
# Epoch 055 | loss 0.5328 | train 0.872 | val 0.729 | test 0.757
# Epoch 060 | loss 0.5165 | train 0.874 | val 0.720 | test 0.757
# Epoch 065 | loss 0.5088 | train 0.881 | val 0.705 | test 0.766
# Epoch 070 | loss 0.4724 | train 0.884 | val 0.705 | test 0.754
# Epoch 075 | loss 0.4766 | train 0.885 | val 0.699 | test 0.760
# Epoch 080 | loss 0.4486 | train 0.887 | val 0.699 | test 0.769
# Epoch 085 | loss 0.4595 | train 0.886 | val 0.711 | test 0.756
# Epoch 090 | loss 0.4573 | train 0.891 | val 0.702 | test 0.762
# Epoch 095 | loss 0.4315 | train 0.892 | val 0.702 | test 0.759
# Epoch 100 | loss 0.4385 | train 0.899 | val 0.702 | test 0.756
# Epoch 105 | loss 0.4149 | train 0.896 | val 0.705 | test 0.748
# Epoch 110 | loss 0.4167 | train 0.900 | val 0.702 | test 0.750
# Epoch 115 | loss 0.4220 | train 0.901 | val 0.705 | test 0.756
# ✅ Final (best-val) | train 0.823 | val 0.750 | test 0.768
# Epoch 000 | loss 1.8043 | train 0.249 | val 0.283 | test 0.219
# Epoch 005 | loss 1.7060 | train 0.423 | val 0.373 | test 0.379
# Epoch 010 | loss 1.5487 | train 0.623 | val 0.515 | test 0.568
# Epoch 015 | loss 1.3328 | train 0.741 | val 0.633 | test 0.691
# Epoch 020 | loss 1.1445 | train 0.797 | val 0.735 | test 0.745
# Epoch 025 | loss 0.9733 | train 0.818 | val 0.753 | test 0.768
# Epoch 030 | loss 0.8481 | train 0.829 | val 0.756 | test 0.780
# Epoch 035 | loss 0.7581 | train 0.841 | val 0.762 | test 0.780
# Epoch 040 | loss 0.7158 | train 0.844 | val 0.759 | test 0.781
# Epoch 045 | loss 0.6755 | train 0.852 | val 0.756 | test 0.774
# Epoch 050 | loss 0.6207 | train 0.858 | val 0.744 | test 0.769
# Epoch 055 | loss 0.5861 | train 0.866 | val 0.732 | test 0.760
# Epoch 060 | loss 0.5580 | train 0.868 | val 0.720 | test 0.762
# Epoch 065 | loss 0.5157 | train 0.874 | val 0.708 | test 0.763
# Epoch 070 | loss 0.5503 | train 0.874 | val 0.708 | test 0.759
# Epoch 075 | loss 0.5290 | train 0.873 | val 0.711 | test 0.763
# Epoch 080 | loss 0.4947 | train 0.880 | val 0.711 | test 0.765
# Epoch 085 | loss 0.4721 | train 0.886 | val 0.714 | test 0.762
# Epoch 090 | loss 0.4733 | train 0.884 | val 0.723 | test 0.756
# Epoch 095 | loss 0.4590 | train 0.887 | val 0.705 | test 0.750
# Epoch 100 | loss 0.4478 | train 0.889 | val 0.705 | test 0.747
# Epoch 105 | loss 0.4394 | train 0.891 | val 0.699 | test 0.757
# Epoch 110 | loss 0.4311 | train 0.892 | val 0.714 | test 0.750
# Epoch 115 | loss 0.4198 | train 0.898 | val 0.711 | test 0.751
# ✅ Final (best-val) | train 0.842 | val 0.765 | test 0.778
# Epoch 000 | loss 1.7891 | train 0.364 | val 0.343 | test 0.313
# Epoch 005 | loss 1.4847 | train 0.632 | val 0.575 | test 0.585
# Epoch 010 | loss 1.2190 | train 0.757 | val 0.705 | test 0.723
# Epoch 015 | loss 1.0555 | train 0.790 | val 0.729 | test 0.739
# Epoch 020 | loss 0.8918 | train 0.804 | val 0.741 | test 0.750
# Epoch 025 | loss 0.7991 | train 0.820 | val 0.735 | test 0.762
# Epoch 030 | loss 0.7182 | train 0.839 | val 0.747 | test 0.777
# Epoch 035 | loss 0.6775 | train 0.846 | val 0.753 | test 0.769
# Epoch 040 | loss 0.6328 | train 0.853 | val 0.741 | test 0.772
# Epoch 045 | loss 0.5956 | train 0.860 | val 0.738 | test 0.774
# Epoch 050 | loss 0.5668 | train 0.869 | val 0.726 | test 0.769
# Epoch 055 | loss 0.5384 | train 0.869 | val 0.714 | test 0.760
# Epoch 060 | loss 0.5241 | train 0.873 | val 0.720 | test 0.765
# Epoch 065 | loss 0.4982 | train 0.877 | val 0.717 | test 0.759
# Epoch 070 | loss 0.4856 | train 0.882 | val 0.702 | test 0.748
# Epoch 075 | loss 0.4765 | train 0.886 | val 0.720 | test 0.756
# Epoch 080 | loss 0.4597 | train 0.888 | val 0.714 | test 0.759
# Epoch 085 | loss 0.4472 | train 0.892 | val 0.717 | test 0.760
# Epoch 090 | loss 0.4449 | train 0.895 | val 0.708 | test 0.751
# Epoch 095 | loss 0.4321 | train 0.894 | val 0.708 | test 0.753
# Epoch 100 | loss 0.4421 | train 0.899 | val 0.708 | test 0.753
# Epoch 105 | loss 0.4161 | train 0.899 | val 0.711 | test 0.751
# Epoch 110 | loss 0.4034 | train 0.898 | val 0.699 | test 0.744
# Epoch 115 | loss 0.4085 | train 0.899 | val 0.702 | test 0.756
# ✅ Final (best-val) | train 0.842 | val 0.753 | test 0.775
# Epoch 000 | loss 1.7980 | train 0.257 | val 0.241 | test 0.268
# Epoch 005 | loss 1.6189 | train 0.524 | val 0.491 | test 0.520
# Epoch 010 | loss 1.3815 | train 0.761 | val 0.702 | test 0.724
# Epoch 015 | loss 1.1784 | train 0.811 | val 0.750 | test 0.759
# Epoch 020 | loss 1.0051 | train 0.817 | val 0.756 | test 0.768
# Epoch 025 | loss 0.8997 | train 0.828 | val 0.744 | test 0.760
# Epoch 030 | loss 0.8325 | train 0.834 | val 0.741 | test 0.771
# Epoch 035 | loss 0.7459 | train 0.847 | val 0.753 | test 0.766
# Epoch 040 | loss 0.6711 | train 0.854 | val 0.762 | test 0.763
# Epoch 045 | loss 0.6518 | train 0.861 | val 0.741 | test 0.762
# Epoch 050 | loss 0.6130 | train 0.867 | val 0.738 | test 0.754
# Epoch 055 | loss 0.5763 | train 0.874 | val 0.741 | test 0.751
# Epoch 060 | loss 0.5603 | train 0.877 | val 0.732 | test 0.756
# Epoch 065 | loss 0.5247 | train 0.875 | val 0.720 | test 0.756
# Epoch 070 | loss 0.5137 | train 0.878 | val 0.717 | test 0.753
# Epoch 075 | loss 0.4907 | train 0.878 | val 0.717 | test 0.751
# Epoch 080 | loss 0.4742 | train 0.884 | val 0.705 | test 0.745
# Epoch 085 | loss 0.4694 | train 0.888 | val 0.708 | test 0.753
# Epoch 090 | loss 0.4648 | train 0.887 | val 0.702 | test 0.747
# Epoch 095 | loss 0.4465 | train 0.896 | val 0.705 | test 0.753
# Epoch 100 | loss 0.4397 | train 0.893 | val 0.702 | test 0.753
# Epoch 105 | loss 0.4279 | train 0.890 | val 0.702 | test 0.742
# Epoch 110 | loss 0.4179 | train 0.891 | val 0.699 | test 0.747
# Epoch 115 | loss 0.4173 | train 0.896 | val 0.696 | test 0.750
# ✅ Final (best-val) | train 0.853 | val 0.762 | test 0.765
# Epoch 000 | loss 1.8007 | train 0.308 | val 0.280 | test 0.298
# Epoch 005 | loss 1.6207 | train 0.581 | val 0.512 | test 0.552
# Epoch 010 | loss 1.3914 | train 0.631 | val 0.572 | test 0.610
# Epoch 015 | loss 1.1830 | train 0.667 | val 0.596 | test 0.636
# Epoch 020 | loss 1.0668 | train 0.723 | val 0.636 | test 0.684
# Epoch 025 | loss 0.9586 | train 0.821 | val 0.723 | test 0.754
# Epoch 030 | loss 0.8199 | train 0.836 | val 0.747 | test 0.769
# Epoch 035 | loss 0.7436 | train 0.847 | val 0.741 | test 0.777
# Epoch 040 | loss 0.6696 | train 0.852 | val 0.741 | test 0.771
# Epoch 045 | loss 0.6403 | train 0.859 | val 0.732 | test 0.772
# Epoch 050 | loss 0.6057 | train 0.861 | val 0.723 | test 0.762
# Epoch 055 | loss 0.5735 | train 0.869 | val 0.717 | test 0.763
# Epoch 060 | loss 0.5537 | train 0.873 | val 0.714 | test 0.766
# Epoch 065 | loss 0.5203 | train 0.872 | val 0.711 | test 0.763
# Epoch 070 | loss 0.5120 | train 0.880 | val 0.711 | test 0.768
# Epoch 075 | loss 0.5045 | train 0.884 | val 0.711 | test 0.763
# Epoch 080 | loss 0.4796 | train 0.885 | val 0.705 | test 0.754
# Epoch 085 | loss 0.4727 | train 0.887 | val 0.705 | test 0.754
# Epoch 090 | loss 0.4452 | train 0.886 | val 0.717 | test 0.756
# Epoch 095 | loss 0.4564 | train 0.890 | val 0.708 | test 0.753
# Epoch 100 | loss 0.4378 | train 0.889 | val 0.711 | test 0.745
# Epoch 105 | loss 0.4335 | train 0.895 | val 0.708 | test 0.751
# Epoch 110 | loss 0.4242 | train 0.900 | val 0.708 | test 0.748
# Epoch 115 | loss 0.4114 | train 0.899 | val 0.702 | test 0.753
# ✅ Final (best-val) | train 0.836 | val 0.747 | test 0.769
# Epoch 000 | loss 1.7934 | train 0.391 | val 0.349 | test 0.387
# Epoch 005 | loss 1.5283 | train 0.485 | val 0.428 | test 0.456
# Epoch 010 | loss 1.2921 | train 0.579 | val 0.527 | test 0.534
# Epoch 015 | loss 1.1235 | train 0.737 | val 0.672 | test 0.705
# Epoch 020 | loss 0.9729 | train 0.794 | val 0.738 | test 0.748
# Epoch 025 | loss 0.8571 | train 0.805 | val 0.747 | test 0.763
# Epoch 030 | loss 0.7726 | train 0.823 | val 0.744 | test 0.778
# Epoch 035 | loss 0.6989 | train 0.841 | val 0.759 | test 0.772
# Epoch 040 | loss 0.6618 | train 0.850 | val 0.753 | test 0.768
# Epoch 045 | loss 0.6121 | train 0.853 | val 0.738 | test 0.775
# Epoch 050 | loss 0.5751 | train 0.862 | val 0.735 | test 0.766
# Epoch 055 | loss 0.5576 | train 0.868 | val 0.726 | test 0.766
# Epoch 060 | loss 0.5155 | train 0.873 | val 0.705 | test 0.765
# Epoch 065 | loss 0.5135 | train 0.876 | val 0.705 | test 0.759
# Epoch 070 | loss 0.4835 | train 0.879 | val 0.702 | test 0.754
# Epoch 075 | loss 0.4842 | train 0.879 | val 0.729 | test 0.760
# Epoch 080 | loss 0.4666 | train 0.885 | val 0.708 | test 0.754
# Epoch 085 | loss 0.4503 | train 0.881 | val 0.714 | test 0.766
# Epoch 090 | loss 0.4479 | train 0.897 | val 0.705 | test 0.757
# Epoch 095 | loss 0.4282 | train 0.893 | val 0.717 | test 0.753
# Epoch 100 | loss 0.4311 | train 0.893 | val 0.699 | test 0.754
# Epoch 105 | loss 0.4094 | train 0.895 | val 0.699 | test 0.757
# Epoch 110 | loss 0.4240 | train 0.899 | val 0.705 | test 0.756
# Epoch 115 | loss 0.3998 | train 0.897 | val 0.708 | test 0.750
# ✅ Final (best-val) | train 0.845 | val 0.765 | test 0.768
# Epoch 000 | loss 1.7987 | train 0.395 | val 0.364 | test 0.354
# Epoch 005 | loss 1.5524 | train 0.604 | val 0.539 | test 0.558
# Epoch 010 | loss 1.2725 | train 0.784 | val 0.720 | test 0.747
# Epoch 015 | loss 1.0357 | train 0.796 | val 0.726 | test 0.747
# Epoch 020 | loss 0.8693 | train 0.801 | val 0.741 | test 0.753
# Epoch 025 | loss 0.7738 | train 0.813 | val 0.744 | test 0.765
# Epoch 030 | loss 0.7086 | train 0.834 | val 0.756 | test 0.763
# Epoch 035 | loss 0.6747 | train 0.842 | val 0.765 | test 0.777
# Epoch 040 | loss 0.6281 | train 0.853 | val 0.762 | test 0.781
# Epoch 045 | loss 0.5863 | train 0.859 | val 0.744 | test 0.769
# Epoch 050 | loss 0.5715 | train 0.868 | val 0.735 | test 0.768
# Epoch 055 | loss 0.5423 | train 0.871 | val 0.729 | test 0.768
# Epoch 060 | loss 0.5259 | train 0.875 | val 0.723 | test 0.769
# Epoch 065 | loss 0.5010 | train 0.879 | val 0.714 | test 0.768
# Epoch 070 | loss 0.5036 | train 0.879 | val 0.714 | test 0.763
# Epoch 075 | loss 0.4673 | train 0.884 | val 0.711 | test 0.765
# Epoch 080 | loss 0.4666 | train 0.883 | val 0.696 | test 0.762
# Epoch 085 | loss 0.4415 | train 0.884 | val 0.699 | test 0.765
# Epoch 090 | loss 0.4469 | train 0.890 | val 0.696 | test 0.765
# Epoch 095 | loss 0.4299 | train 0.893 | val 0.705 | test 0.754
# Epoch 100 | loss 0.4358 | train 0.897 | val 0.699 | test 0.751
# Epoch 105 | loss 0.4238 | train 0.895 | val 0.708 | test 0.745
# Epoch 110 | loss 0.4132 | train 0.898 | val 0.714 | test 0.756
# Epoch 115 | loss 0.4116 | train 0.901 | val 0.708 | test 0.751
# ✅ Final (best-val) | train 0.848 | val 0.768 | test 0.780
# Epoch 000 | loss 1.7977 | train 0.336 | val 0.271 | test 0.298
# Epoch 005 | loss 1.5911 | train 0.707 | val 0.630 | test 0.642
# Epoch 010 | loss 1.3271 | train 0.773 | val 0.714 | test 0.714
# Epoch 015 | loss 1.0911 | train 0.792 | val 0.729 | test 0.735
# Epoch 020 | loss 0.9391 | train 0.805 | val 0.732 | test 0.750
# Epoch 025 | loss 0.8477 | train 0.820 | val 0.738 | test 0.765
# Epoch 030 | loss 0.7652 | train 0.836 | val 0.735 | test 0.775
# Epoch 035 | loss 0.7208 | train 0.842 | val 0.729 | test 0.777
# Epoch 040 | loss 0.6709 | train 0.853 | val 0.732 | test 0.778
# Epoch 045 | loss 0.6305 | train 0.864 | val 0.729 | test 0.778
# Epoch 050 | loss 0.5817 | train 0.869 | val 0.726 | test 0.777
# Epoch 055 | loss 0.5738 | train 0.875 | val 0.723 | test 0.772
# Epoch 060 | loss 0.5539 | train 0.879 | val 0.714 | test 0.768
# Epoch 065 | loss 0.5373 | train 0.881 | val 0.711 | test 0.771
# Epoch 070 | loss 0.5286 | train 0.880 | val 0.705 | test 0.769
# Epoch 075 | loss 0.5116 | train 0.883 | val 0.711 | test 0.766
# Epoch 080 | loss 0.4907 | train 0.887 | val 0.708 | test 0.766
# Epoch 085 | loss 0.4757 | train 0.886 | val 0.714 | test 0.766
# Epoch 090 | loss 0.4657 | train 0.887 | val 0.714 | test 0.765
# Epoch 095 | loss 0.4542 | train 0.891 | val 0.717 | test 0.757
# Epoch 100 | loss 0.4336 | train 0.893 | val 0.711 | test 0.754
# Epoch 105 | loss 0.4460 | train 0.894 | val 0.705 | test 0.757
# Epoch 110 | loss 0.4145 | train 0.898 | val 0.705 | test 0.756
# Epoch 115 | loss 0.4202 | train 0.899 | val 0.699 | test 0.756
# ✅ Final (best-val) | train 0.829 | val 0.750 | test 0.771
# Epoch 000 | loss 1.7898 | train 0.456 | val 0.389 | test 0.435
# Epoch 005 | loss 1.4799 | train 0.648 | val 0.602 | test 0.573
# Epoch 010 | loss 1.2257 | train 0.746 | val 0.681 | test 0.685
# Epoch 015 | loss 1.0488 | train 0.789 | val 0.723 | test 0.736
# Epoch 020 | loss 0.9427 | train 0.805 | val 0.723 | test 0.744
# Epoch 025 | loss 0.8055 | train 0.824 | val 0.726 | test 0.769
# Epoch 030 | loss 0.7437 | train 0.837 | val 0.744 | test 0.768
# Epoch 035 | loss 0.6942 | train 0.848 | val 0.747 | test 0.772
# Epoch 040 | loss 0.6407 | train 0.852 | val 0.738 | test 0.771
# Epoch 045 | loss 0.5838 | train 0.857 | val 0.741 | test 0.774
# Epoch 050 | loss 0.5844 | train 0.865 | val 0.729 | test 0.775
# Epoch 055 | loss 0.5484 | train 0.866 | val 0.723 | test 0.768
# Epoch 060 | loss 0.5283 | train 0.875 | val 0.717 | test 0.766
# Epoch 065 | loss 0.5012 | train 0.876 | val 0.708 | test 0.766
# Epoch 070 | loss 0.4829 | train 0.877 | val 0.711 | test 0.766
# Epoch 075 | loss 0.4814 | train 0.883 | val 0.708 | test 0.766
# Epoch 080 | loss 0.4681 | train 0.887 | val 0.717 | test 0.762
# Epoch 085 | loss 0.4684 | train 0.889 | val 0.711 | test 0.762
# Epoch 090 | loss 0.4458 | train 0.891 | val 0.711 | test 0.753
# Epoch 095 | loss 0.4530 | train 0.897 | val 0.708 | test 0.748
# Epoch 100 | loss 0.4266 | train 0.890 | val 0.708 | test 0.748
# Epoch 105 | loss 0.4275 | train 0.896 | val 0.708 | test 0.756
# Epoch 110 | loss 0.4253 | train 0.901 | val 0.708 | test 0.751
# Epoch 115 | loss 0.4219 | train 0.905 | val 0.708 | test 0.762
# ✅ Final (best-val) | train 0.845 | val 0.747 | test 0.777
# Epoch 000 | loss 1.7863 | train 0.393 | val 0.349 | test 0.373
# Epoch 005 | loss 1.4842 | train 0.714 | val 0.648 | test 0.682
# Epoch 010 | loss 1.2232 | train 0.776 | val 0.705 | test 0.733
# Epoch 015 | loss 1.0261 | train 0.795 | val 0.717 | test 0.745
# Epoch 020 | loss 0.8914 | train 0.800 | val 0.732 | test 0.748
# Epoch 025 | loss 0.7824 | train 0.812 | val 0.735 | test 0.754
# Epoch 030 | loss 0.7084 | train 0.829 | val 0.729 | test 0.759
# Epoch 035 | loss 0.6559 | train 0.833 | val 0.741 | test 0.765
# Epoch 040 | loss 0.6301 | train 0.845 | val 0.729 | test 0.765
# Epoch 045 | loss 0.5952 | train 0.854 | val 0.729 | test 0.765
# Epoch 050 | loss 0.5701 | train 0.867 | val 0.714 | test 0.769
# Epoch 055 | loss 0.5460 | train 0.872 | val 0.717 | test 0.769
# Epoch 060 | loss 0.5312 | train 0.876 | val 0.708 | test 0.771
# Epoch 065 | loss 0.5239 | train 0.879 | val 0.708 | test 0.760
# Epoch 070 | loss 0.4959 | train 0.881 | val 0.714 | test 0.762
# Epoch 075 | loss 0.4929 | train 0.885 | val 0.711 | test 0.756
# Epoch 080 | loss 0.4680 | train 0.888 | val 0.717 | test 0.753
# Epoch 085 | loss 0.4539 | train 0.887 | val 0.711 | test 0.754
# Epoch 090 | loss 0.4532 | train 0.890 | val 0.711 | test 0.751
# Epoch 095 | loss 0.4703 | train 0.895 | val 0.717 | test 0.747
# Epoch 100 | loss 0.4523 | train 0.896 | val 0.705 | test 0.754
# Epoch 105 | loss 0.4307 | train 0.897 | val 0.708 | test 0.756
# Epoch 110 | loss 0.4362 | train 0.894 | val 0.702 | test 0.757
# Epoch 115 | loss 0.4268 | train 0.903 | val 0.702 | test 0.753
# ✅ Final (best-val) | train 0.833 | val 0.741 | test 0.765
# Epoch 000 | loss 1.7952 | train 0.266 | val 0.235 | test 0.229
# Epoch 005 | loss 1.5979 | train 0.495 | val 0.494 | test 0.453
# Epoch 010 | loss 1.3335 | train 0.748 | val 0.696 | test 0.714
# Epoch 015 | loss 1.1294 | train 0.786 | val 0.732 | test 0.747
# Epoch 020 | loss 0.9631 | train 0.796 | val 0.741 | test 0.754
# Epoch 025 | loss 0.8448 | train 0.806 | val 0.741 | test 0.763
# Epoch 030 | loss 0.7793 | train 0.821 | val 0.750 | test 0.771
# Epoch 035 | loss 0.7163 | train 0.838 | val 0.750 | test 0.781
# Epoch 040 | loss 0.6470 | train 0.848 | val 0.750 | test 0.783
# Epoch 045 | loss 0.6344 | train 0.858 | val 0.735 | test 0.778
# Epoch 050 | loss 0.5819 | train 0.863 | val 0.723 | test 0.777
# Epoch 055 | loss 0.5770 | train 0.867 | val 0.720 | test 0.777
# Epoch 060 | loss 0.5525 | train 0.871 | val 0.708 | test 0.775
# Epoch 065 | loss 0.5334 | train 0.881 | val 0.702 | test 0.768
# Epoch 070 | loss 0.5134 | train 0.880 | val 0.714 | test 0.769
# Epoch 075 | loss 0.4775 | train 0.882 | val 0.717 | test 0.769
# Epoch 080 | loss 0.4813 | train 0.884 | val 0.714 | test 0.759
# Epoch 085 | loss 0.4560 | train 0.885 | val 0.708 | test 0.763
# Epoch 090 | loss 0.4590 | train 0.889 | val 0.717 | test 0.751
# Epoch 095 | loss 0.4397 | train 0.891 | val 0.714 | test 0.756
# Epoch 100 | loss 0.4316 | train 0.896 | val 0.711 | test 0.756
# Epoch 105 | loss 0.4348 | train 0.899 | val 0.708 | test 0.754
# Epoch 110 | loss 0.4257 | train 0.896 | val 0.702 | test 0.759
# Epoch 115 | loss 0.4199 | train 0.900 | val 0.702 | test 0.750
# ✅ Final (best-val) | train 0.836 | val 0.756 | test 0.780
# Epoch 000 | loss 1.7976 | train 0.244 | val 0.214 | test 0.204
# Epoch 005 | loss 1.6059 | train 0.374 | val 0.313 | test 0.340
# Epoch 010 | loss 1.4138 | train 0.610 | val 0.536 | test 0.573
# Epoch 015 | loss 1.2211 | train 0.757 | val 0.666 | test 0.690
# Epoch 020 | loss 1.0554 | train 0.793 | val 0.705 | test 0.720
# Epoch 025 | loss 0.9199 | train 0.813 | val 0.726 | test 0.753
# Epoch 030 | loss 0.8160 | train 0.831 | val 0.735 | test 0.757
# Epoch 035 | loss 0.7506 | train 0.846 | val 0.750 | test 0.756
# Epoch 040 | loss 0.6671 | train 0.854 | val 0.735 | test 0.768
# Epoch 045 | loss 0.6298 | train 0.859 | val 0.738 | test 0.774
# Epoch 050 | loss 0.6030 | train 0.868 | val 0.744 | test 0.777
# Epoch 055 | loss 0.5632 | train 0.866 | val 0.726 | test 0.772
# Epoch 060 | loss 0.5379 | train 0.872 | val 0.714 | test 0.762
# Epoch 065 | loss 0.5144 | train 0.874 | val 0.714 | test 0.760
# Epoch 070 | loss 0.4827 | train 0.881 | val 0.702 | test 0.763
# Epoch 075 | loss 0.4894 | train 0.878 | val 0.711 | test 0.757
# Epoch 080 | loss 0.4724 | train 0.884 | val 0.711 | test 0.759
# Epoch 085 | loss 0.4605 | train 0.883 | val 0.717 | test 0.756
# Epoch 090 | loss 0.4503 | train 0.887 | val 0.705 | test 0.748
# Epoch 095 | loss 0.4531 | train 0.891 | val 0.702 | test 0.744
# Epoch 100 | loss 0.4447 | train 0.897 | val 0.693 | test 0.753
# Epoch 105 | loss 0.4288 | train 0.891 | val 0.714 | test 0.751
# Epoch 110 | loss 0.4196 | train 0.900 | val 0.693 | test 0.744
# Epoch 115 | loss 0.4147 | train 0.893 | val 0.708 | test 0.742
# ✅ Final (best-val) | train 0.846 | val 0.750 | test 0.756
# Epoch 000 | loss 1.7977 | train 0.280 | val 0.244 | test 0.252
# Epoch 005 | loss 1.6124 | train 0.607 | val 0.545 | test 0.600
# Epoch 010 | loss 1.3428 | train 0.699 | val 0.654 | test 0.678
# Epoch 015 | loss 1.1580 | train 0.761 | val 0.708 | test 0.727
# Epoch 020 | loss 0.9942 | train 0.791 | val 0.720 | test 0.751
# Epoch 025 | loss 0.8944 | train 0.805 | val 0.729 | test 0.753
# Epoch 030 | loss 0.8150 | train 0.809 | val 0.729 | test 0.753
# Epoch 035 | loss 0.7627 | train 0.817 | val 0.735 | test 0.754
# Epoch 040 | loss 0.6837 | train 0.831 | val 0.723 | test 0.745
# Epoch 045 | loss 0.6536 | train 0.849 | val 0.729 | test 0.756
# Epoch 050 | loss 0.6128 | train 0.856 | val 0.732 | test 0.763
# Epoch 055 | loss 0.5809 | train 0.867 | val 0.717 | test 0.763
# Epoch 060 | loss 0.5513 | train 0.869 | val 0.717 | test 0.757
# Epoch 065 | loss 0.5383 | train 0.874 | val 0.720 | test 0.756
# Epoch 070 | loss 0.5071 | train 0.878 | val 0.720 | test 0.760
# Epoch 075 | loss 0.4830 | train 0.879 | val 0.717 | test 0.757
# Epoch 080 | loss 0.4758 | train 0.880 | val 0.717 | test 0.751
# Epoch 085 | loss 0.4627 | train 0.883 | val 0.702 | test 0.751
# Epoch 090 | loss 0.4521 | train 0.887 | val 0.708 | test 0.750
# Epoch 095 | loss 0.4451 | train 0.894 | val 0.705 | test 0.747
# Epoch 100 | loss 0.4369 | train 0.896 | val 0.702 | test 0.745
# Epoch 105 | loss 0.4427 | train 0.895 | val 0.705 | test 0.744
# Epoch 110 | loss 0.4330 | train 0.898 | val 0.699 | test 0.744
# Epoch 115 | loss 0.4190 | train 0.896 | val 0.699 | test 0.742
# ✅ Final (best-val) | train 0.813 | val 0.735 | test 0.756
# Epoch 000 | loss 1.8030 | train 0.204 | val 0.172 | test 0.225
# Epoch 005 | loss 1.6575 | train 0.653 | val 0.581 | test 0.634
# Epoch 010 | loss 1.4012 | train 0.722 | val 0.657 | test 0.672
# Epoch 015 | loss 1.1575 | train 0.787 | val 0.732 | test 0.739
# Epoch 020 | loss 0.9742 | train 0.810 | val 0.750 | test 0.745
# Epoch 025 | loss 0.8573 | train 0.825 | val 0.750 | test 0.756
# Epoch 030 | loss 0.7402 | train 0.832 | val 0.750 | test 0.769
# Epoch 035 | loss 0.6880 | train 0.845 | val 0.747 | test 0.766
# Epoch 040 | loss 0.6375 | train 0.853 | val 0.750 | test 0.768
# Epoch 045 | loss 0.6097 | train 0.869 | val 0.747 | test 0.762
# Epoch 050 | loss 0.5770 | train 0.867 | val 0.741 | test 0.771
# Epoch 055 | loss 0.5513 | train 0.869 | val 0.738 | test 0.763
# Epoch 060 | loss 0.5207 | train 0.872 | val 0.735 | test 0.765
# Epoch 065 | loss 0.5075 | train 0.876 | val 0.732 | test 0.763
# Epoch 070 | loss 0.4847 | train 0.878 | val 0.720 | test 0.765
# Epoch 075 | loss 0.4876 | train 0.881 | val 0.714 | test 0.757
# Epoch 080 | loss 0.4587 | train 0.887 | val 0.708 | test 0.754
# Epoch 085 | loss 0.4505 | train 0.886 | val 0.708 | test 0.759
# Epoch 090 | loss 0.4286 | train 0.888 | val 0.708 | test 0.759
# Epoch 095 | loss 0.4274 | train 0.887 | val 0.714 | test 0.756
# Epoch 100 | loss 0.4249 | train 0.894 | val 0.708 | test 0.750
# Epoch 105 | loss 0.4279 | train 0.894 | val 0.708 | test 0.750
# Epoch 110 | loss 0.4245 | train 0.893 | val 0.702 | test 0.762
# Epoch 115 | loss 0.4153 | train 0.894 | val 0.708 | test 0.763
# ✅ Final (best-val) | train 0.826 | val 0.756 | test 0.762
# Epoch 000 | loss 1.8047 | train 0.390 | val 0.380 | test 0.384
# Epoch 005 | loss 1.6215 | train 0.578 | val 0.536 | test 0.562
# Epoch 010 | loss 1.3785 | train 0.619 | val 0.620 | test 0.612
# Epoch 015 | loss 1.1501 | train 0.763 | val 0.732 | test 0.741
# Epoch 020 | loss 0.9855 | train 0.799 | val 0.744 | test 0.751
# Epoch 025 | loss 0.8506 | train 0.813 | val 0.753 | test 0.760
# Epoch 030 | loss 0.7614 | train 0.829 | val 0.747 | test 0.766
# Epoch 035 | loss 0.6907 | train 0.841 | val 0.756 | test 0.772
# Epoch 040 | loss 0.6267 | train 0.854 | val 0.744 | test 0.778
# Epoch 045 | loss 0.5974 | train 0.858 | val 0.738 | test 0.774
# Epoch 050 | loss 0.5607 | train 0.865 | val 0.732 | test 0.771
# Epoch 055 | loss 0.5478 | train 0.872 | val 0.720 | test 0.772
# Epoch 060 | loss 0.5092 | train 0.878 | val 0.714 | test 0.772
# Epoch 065 | loss 0.4880 | train 0.879 | val 0.714 | test 0.769
# Epoch 070 | loss 0.4641 | train 0.879 | val 0.714 | test 0.771
# Epoch 075 | loss 0.4515 | train 0.885 | val 0.699 | test 0.772
# Epoch 080 | loss 0.4392 | train 0.890 | val 0.693 | test 0.768
# Epoch 085 | loss 0.4498 | train 0.892 | val 0.705 | test 0.771
# Epoch 090 | loss 0.4186 | train 0.889 | val 0.705 | test 0.757
# Epoch 095 | loss 0.4302 | train 0.892 | val 0.705 | test 0.757
# Epoch 100 | loss 0.4132 | train 0.892 | val 0.708 | test 0.756
# Epoch 105 | loss 0.4141 | train 0.897 | val 0.702 | test 0.766
# Epoch 110 | loss 0.4076 | train 0.896 | val 0.699 | test 0.762
# Epoch 115 | loss 0.3917 | train 0.896 | val 0.702 | test 0.753
# ✅ Final (best-val) | train 0.841 | val 0.756 | test 0.772
# Epoch 000 | loss 1.7910 | train 0.231 | val 0.196 | test 0.205
# Epoch 005 | loss 1.4899 | train 0.476 | val 0.440 | test 0.459
# Epoch 010 | loss 1.2608 | train 0.601 | val 0.569 | test 0.574
# Epoch 015 | loss 1.0558 | train 0.643 | val 0.590 | test 0.615
# Epoch 020 | loss 0.9448 | train 0.781 | val 0.687 | test 0.730
# Epoch 025 | loss 0.8420 | train 0.829 | val 0.750 | test 0.757
# Epoch 030 | loss 0.7444 | train 0.841 | val 0.753 | test 0.760
# Epoch 035 | loss 0.7137 | train 0.839 | val 0.756 | test 0.765
# Epoch 040 | loss 0.6539 | train 0.849 | val 0.756 | test 0.759
# Epoch 045 | loss 0.6277 | train 0.856 | val 0.765 | test 0.766
# Epoch 050 | loss 0.5926 | train 0.863 | val 0.759 | test 0.766
# Epoch 055 | loss 0.5644 | train 0.865 | val 0.741 | test 0.763
# Epoch 060 | loss 0.5500 | train 0.873 | val 0.738 | test 0.766
# Epoch 065 | loss 0.5183 | train 0.873 | val 0.720 | test 0.759
# Epoch 070 | loss 0.4997 | train 0.877 | val 0.717 | test 0.765
# Epoch 075 | loss 0.5027 | train 0.881 | val 0.714 | test 0.762
# Epoch 080 | loss 0.4752 | train 0.884 | val 0.705 | test 0.762
# Epoch 085 | loss 0.4629 | train 0.890 | val 0.708 | test 0.760
# Epoch 090 | loss 0.4767 | train 0.887 | val 0.717 | test 0.760
# Epoch 095 | loss 0.4607 | train 0.892 | val 0.711 | test 0.762
# Epoch 100 | loss 0.4419 | train 0.890 | val 0.717 | test 0.766
# Epoch 105 | loss 0.4344 | train 0.897 | val 0.711 | test 0.753
# Epoch 110 | loss 0.4326 | train 0.896 | val 0.714 | test 0.753
# Epoch 115 | loss 0.4305 | train 0.897 | val 0.708 | test 0.748
# ✅ Final (best-val) | train 0.857 | val 0.768 | test 0.765
# Epoch 000 | loss 1.7966 | train 0.394 | val 0.386 | test 0.405
# Epoch 005 | loss 1.5388 | train 0.550 | val 0.518 | test 0.532
# Epoch 010 | loss 1.2977 | train 0.676 | val 0.642 | test 0.660
# Epoch 015 | loss 1.1523 | train 0.767 | val 0.717 | test 0.730
# Epoch 020 | loss 1.0088 | train 0.814 | val 0.738 | test 0.753
# Epoch 025 | loss 0.8744 | train 0.832 | val 0.744 | test 0.762
# Epoch 030 | loss 0.8020 | train 0.842 | val 0.747 | test 0.768
# Epoch 035 | loss 0.7293 | train 0.851 | val 0.735 | test 0.771
# Epoch 040 | loss 0.6672 | train 0.856 | val 0.735 | test 0.766
# Epoch 045 | loss 0.6082 | train 0.861 | val 0.738 | test 0.763
# Epoch 050 | loss 0.5683 | train 0.862 | val 0.729 | test 0.766
# Epoch 055 | loss 0.5586 | train 0.869 | val 0.723 | test 0.765
# Epoch 060 | loss 0.5209 | train 0.875 | val 0.714 | test 0.760
# Epoch 065 | loss 0.5074 | train 0.877 | val 0.708 | test 0.760
# Epoch 070 | loss 0.4919 | train 0.880 | val 0.708 | test 0.760
# Epoch 075 | loss 0.4870 | train 0.881 | val 0.720 | test 0.762
# Epoch 080 | loss 0.4668 | train 0.885 | val 0.717 | test 0.760
# Epoch 085 | loss 0.4563 | train 0.885 | val 0.717 | test 0.762
# Epoch 090 | loss 0.4391 | train 0.891 | val 0.711 | test 0.757
# Epoch 095 | loss 0.4494 | train 0.895 | val 0.702 | test 0.754
# Epoch 100 | loss 0.4382 | train 0.898 | val 0.702 | test 0.753
# Epoch 105 | loss 0.4282 | train 0.895 | val 0.705 | test 0.757
# Epoch 110 | loss 0.4246 | train 0.899 | val 0.708 | test 0.762
# Epoch 115 | loss 0.4143 | train 0.902 | val 0.708 | test 0.751
# ✅ Final (best-val) | train 0.845 | val 0.756 | test 0.774
# Epoch 000 | loss 1.7972 | train 0.443 | val 0.443 | test 0.439
# Epoch 005 | loss 1.5803 | train 0.560 | val 0.527 | test 0.523
# Epoch 010 | loss 1.3336 | train 0.741 | val 0.693 | test 0.700
# Epoch 015 | loss 1.1208 | train 0.788 | val 0.741 | test 0.736
# Epoch 020 | loss 0.9782 | train 0.797 | val 0.744 | test 0.747
# Epoch 025 | loss 0.8613 | train 0.803 | val 0.747 | test 0.751
# Epoch 030 | loss 0.7768 | train 0.812 | val 0.750 | test 0.757
# Epoch 035 | loss 0.7287 | train 0.817 | val 0.738 | test 0.754
# Epoch 040 | loss 0.6699 | train 0.827 | val 0.729 | test 0.756
# Epoch 045 | loss 0.6626 | train 0.832 | val 0.726 | test 0.757
# Epoch 050 | loss 0.6272 | train 0.844 | val 0.720 | test 0.763
# Epoch 055 | loss 0.5859 | train 0.853 | val 0.726 | test 0.763
# Epoch 060 | loss 0.5558 | train 0.859 | val 0.732 | test 0.771
# Epoch 065 | loss 0.5488 | train 0.868 | val 0.717 | test 0.774
# Epoch 070 | loss 0.5316 | train 0.870 | val 0.723 | test 0.772
# Epoch 075 | loss 0.5076 | train 0.878 | val 0.708 | test 0.775
# Epoch 080 | loss 0.4767 | train 0.881 | val 0.720 | test 0.765
# Epoch 085 | loss 0.4727 | train 0.883 | val 0.711 | test 0.769
# Epoch 090 | loss 0.4619 | train 0.883 | val 0.714 | test 0.771
# Epoch 095 | loss 0.4494 | train 0.890 | val 0.717 | test 0.768
# Epoch 100 | loss 0.4453 | train 0.893 | val 0.708 | test 0.763
# Epoch 105 | loss 0.4377 | train 0.892 | val 0.714 | test 0.760
# Epoch 110 | loss 0.4393 | train 0.898 | val 0.711 | test 0.757
# Epoch 115 | loss 0.4175 | train 0.896 | val 0.699 | test 0.756
# ✅ Final (best-val) | train 0.800 | val 0.753 | test 0.747
# Epoch 000 | loss 1.8004 | train 0.312 | val 0.307 | test 0.303
# Epoch 005 | loss 1.5712 | train 0.449 | val 0.422 | test 0.423
# Epoch 010 | loss 1.3572 | train 0.657 | val 0.587 | test 0.612
# Epoch 015 | loss 1.1501 | train 0.676 | val 0.602 | test 0.630
# Epoch 020 | loss 1.0415 | train 0.685 | val 0.602 | test 0.640
# Epoch 025 | loss 0.9232 | train 0.703 | val 0.605 | test 0.651
# Epoch 030 | loss 0.8487 | train 0.753 | val 0.669 | test 0.670
# Epoch 035 | loss 0.7772 | train 0.830 | val 0.726 | test 0.739
# Epoch 040 | loss 0.7413 | train 0.844 | val 0.732 | test 0.748
# Epoch 045 | loss 0.6937 | train 0.857 | val 0.726 | test 0.753
# Epoch 050 | loss 0.6688 | train 0.867 | val 0.726 | test 0.756
# Epoch 055 | loss 0.5951 | train 0.872 | val 0.738 | test 0.763
# Epoch 060 | loss 0.5606 | train 0.872 | val 0.732 | test 0.762
# Epoch 065 | loss 0.5394 | train 0.874 | val 0.723 | test 0.762
# Epoch 070 | loss 0.5199 | train 0.874 | val 0.720 | test 0.766
# Epoch 075 | loss 0.4781 | train 0.879 | val 0.726 | test 0.759
# Epoch 080 | loss 0.4906 | train 0.883 | val 0.714 | test 0.757
# Epoch 085 | loss 0.4591 | train 0.887 | val 0.705 | test 0.753
# Epoch 090 | loss 0.4494 | train 0.890 | val 0.711 | test 0.751
# Epoch 095 | loss 0.4374 | train 0.891 | val 0.705 | test 0.747
# Epoch 100 | loss 0.4494 | train 0.890 | val 0.708 | test 0.751
# Epoch 105 | loss 0.4132 | train 0.891 | val 0.711 | test 0.756
# Epoch 110 | loss 0.4247 | train 0.896 | val 0.705 | test 0.750
# Epoch 115 | loss 0.4184 | train 0.899 | val 0.708 | test 0.748
# ✅ Final (best-val) | train 0.868 | val 0.738 | test 0.759
# Epoch 000 | loss 1.7864 | train 0.340 | val 0.322 | test 0.321
# Epoch 005 | loss 1.5119 | train 0.675 | val 0.590 | test 0.630
# Epoch 010 | loss 1.2637 | train 0.761 | val 0.684 | test 0.702
# Epoch 015 | loss 1.0852 | train 0.785 | val 0.717 | test 0.735
# Epoch 020 | loss 0.9278 | train 0.802 | val 0.741 | test 0.750
# Epoch 025 | loss 0.8397 | train 0.822 | val 0.744 | test 0.760
# Epoch 030 | loss 0.7651 | train 0.835 | val 0.756 | test 0.765
# Epoch 035 | loss 0.7083 | train 0.851 | val 0.756 | test 0.772
# Epoch 040 | loss 0.6460 | train 0.856 | val 0.741 | test 0.771
# Epoch 045 | loss 0.6167 | train 0.863 | val 0.729 | test 0.769
# Epoch 050 | loss 0.5803 | train 0.871 | val 0.723 | test 0.756
# Epoch 055 | loss 0.5703 | train 0.871 | val 0.723 | test 0.762
# Epoch 060 | loss 0.5287 | train 0.878 | val 0.711 | test 0.754
# Epoch 065 | loss 0.5058 | train 0.881 | val 0.705 | test 0.760
# Epoch 070 | loss 0.4882 | train 0.883 | val 0.711 | test 0.759
# Epoch 075 | loss 0.4904 | train 0.883 | val 0.708 | test 0.754
# Epoch 080 | loss 0.4669 | train 0.892 | val 0.702 | test 0.757
# Epoch 085 | loss 0.4449 | train 0.890 | val 0.708 | test 0.756
# Epoch 090 | loss 0.4423 | train 0.893 | val 0.702 | test 0.748
# Epoch 095 | loss 0.4322 | train 0.890 | val 0.714 | test 0.750
# Epoch 100 | loss 0.4320 | train 0.894 | val 0.702 | test 0.745
# Epoch 105 | loss 0.4215 | train 0.898 | val 0.708 | test 0.741
# Epoch 110 | loss 0.4258 | train 0.897 | val 0.705 | test 0.748
# Epoch 115 | loss 0.4094 | train 0.898 | val 0.708 | test 0.750
# ✅ Final (best-val) | train 0.846 | val 0.762 | test 0.769
# Epoch 000 | loss 1.7866 | train 0.222 | val 0.205 | test 0.193
# Epoch 005 | loss 1.5193 | train 0.600 | val 0.563 | test 0.541
# Epoch 010 | loss 1.2561 | train 0.671 | val 0.633 | test 0.616
# Epoch 015 | loss 1.0451 | train 0.769 | val 0.699 | test 0.720
# Epoch 020 | loss 0.8915 | train 0.808 | val 0.732 | test 0.753
# Epoch 025 | loss 0.8143 | train 0.826 | val 0.741 | test 0.757
# Epoch 030 | loss 0.7333 | train 0.835 | val 0.738 | test 0.772
# Epoch 035 | loss 0.6748 | train 0.845 | val 0.729 | test 0.771
# Epoch 040 | loss 0.6402 | train 0.857 | val 0.729 | test 0.772
# Epoch 045 | loss 0.6010 | train 0.865 | val 0.726 | test 0.760
# Epoch 050 | loss 0.5644 | train 0.870 | val 0.714 | test 0.769
# Epoch 055 | loss 0.5282 | train 0.875 | val 0.711 | test 0.760
# Epoch 060 | loss 0.5200 | train 0.879 | val 0.699 | test 0.760
# Epoch 065 | loss 0.5183 | train 0.881 | val 0.708 | test 0.760
# Epoch 070 | loss 0.5010 | train 0.885 | val 0.699 | test 0.763
# Epoch 075 | loss 0.4971 | train 0.888 | val 0.702 | test 0.765
# Epoch 080 | loss 0.4782 | train 0.894 | val 0.705 | test 0.759
# Epoch 085 | loss 0.4626 | train 0.891 | val 0.708 | test 0.762
# Epoch 090 | loss 0.4618 | train 0.890 | val 0.702 | test 0.756
# Epoch 095 | loss 0.4314 | train 0.894 | val 0.708 | test 0.757
# Epoch 100 | loss 0.4379 | train 0.899 | val 0.702 | test 0.754
# Epoch 105 | loss 0.4264 | train 0.900 | val 0.708 | test 0.750
# Epoch 110 | loss 0.4224 | train 0.900 | val 0.702 | test 0.750
# Epoch 115 | loss 0.4156 | train 0.902 | val 0.699 | test 0.748
# ✅ Final (best-val) | train 0.816 | val 0.741 | test 0.756
# Epoch 000 | loss 1.7975 | train 0.261 | val 0.226 | test 0.214
# Epoch 005 | loss 1.5915 | train 0.592 | val 0.509 | test 0.565
# Epoch 010 | loss 1.3566 | train 0.747 | val 0.678 | test 0.712
# Epoch 015 | loss 1.1381 | train 0.797 | val 0.738 | test 0.744
# Epoch 020 | loss 0.9808 | train 0.808 | val 0.732 | test 0.763
# Epoch 025 | loss 0.8444 | train 0.822 | val 0.735 | test 0.777
# Epoch 030 | loss 0.7518 | train 0.836 | val 0.732 | test 0.774
# Epoch 035 | loss 0.7102 | train 0.851 | val 0.744 | test 0.774
# Epoch 040 | loss 0.6380 | train 0.855 | val 0.750 | test 0.771
# Epoch 045 | loss 0.6034 | train 0.866 | val 0.726 | test 0.781
# Epoch 050 | loss 0.5738 | train 0.868 | val 0.723 | test 0.774
# Epoch 055 | loss 0.5393 | train 0.872 | val 0.720 | test 0.775
# Epoch 060 | loss 0.5273 | train 0.881 | val 0.723 | test 0.771
# Epoch 065 | loss 0.5020 | train 0.880 | val 0.723 | test 0.766
# Epoch 070 | loss 0.4891 | train 0.883 | val 0.717 | test 0.769
# Epoch 075 | loss 0.4891 | train 0.886 | val 0.708 | test 0.762
# Epoch 080 | loss 0.4620 | train 0.890 | val 0.723 | test 0.762
# Epoch 085 | loss 0.4743 | train 0.889 | val 0.711 | test 0.756
# Epoch 090 | loss 0.4694 | train 0.889 | val 0.702 | test 0.750
# Epoch 095 | loss 0.4360 | train 0.894 | val 0.705 | test 0.762
# Epoch 100 | loss 0.4296 | train 0.894 | val 0.702 | test 0.754
# Epoch 105 | loss 0.4369 | train 0.893 | val 0.702 | test 0.751
# Epoch 110 | loss 0.4239 | train 0.897 | val 0.705 | test 0.751
# Epoch 115 | loss 0.4098 | train 0.899 | val 0.705 | test 0.750
# ✅ Final (best-val) | train 0.855 | val 0.750 | test 0.771
# Epoch 000 | loss 1.7974 | train 0.342 | val 0.355 | test 0.342
# Epoch 005 | loss 1.5963 | train 0.651 | val 0.620 | test 0.636
# Epoch 010 | loss 1.3364 | train 0.755 | val 0.717 | test 0.700
# Epoch 015 | loss 1.1355 | train 0.786 | val 0.744 | test 0.739
# Epoch 020 | loss 0.9277 | train 0.812 | val 0.753 | test 0.759
# Epoch 025 | loss 0.8369 | train 0.831 | val 0.762 | test 0.769
# Epoch 030 | loss 0.7421 | train 0.845 | val 0.759 | test 0.775
# Epoch 035 | loss 0.6785 | train 0.850 | val 0.753 | test 0.768
# Epoch 040 | loss 0.6431 | train 0.861 | val 0.747 | test 0.772
# Epoch 045 | loss 0.6125 | train 0.863 | val 0.741 | test 0.769
# Epoch 050 | loss 0.5723 | train 0.871 | val 0.729 | test 0.775
# Epoch 055 | loss 0.5661 | train 0.873 | val 0.720 | test 0.765
# Epoch 060 | loss 0.5340 | train 0.877 | val 0.720 | test 0.766
# Epoch 065 | loss 0.5016 | train 0.878 | val 0.714 | test 0.765
# Epoch 070 | loss 0.5084 | train 0.883 | val 0.714 | test 0.765
# Epoch 075 | loss 0.4741 | train 0.885 | val 0.717 | test 0.766
# Epoch 080 | loss 0.4766 | train 0.885 | val 0.717 | test 0.760
# Epoch 085 | loss 0.4587 | train 0.888 | val 0.717 | test 0.757
# Epoch 090 | loss 0.4353 | train 0.890 | val 0.705 | test 0.750
# Epoch 095 | loss 0.4380 | train 0.892 | val 0.696 | test 0.747
# Epoch 100 | loss 0.4377 | train 0.896 | val 0.702 | test 0.756
# Epoch 105 | loss 0.4302 | train 0.894 | val 0.711 | test 0.757
# Epoch 110 | loss 0.4218 | train 0.901 | val 0.705 | test 0.762
# Epoch 115 | loss 0.4245 | train 0.900 | val 0.705 | test 0.750
# ✅ Final (best-val) | train 0.831 | val 0.762 | test 0.769
# Epoch 000 | loss 1.7986 | train 0.158 | val 0.166 | test 0.165
# Epoch 005 | loss 1.6162 | train 0.351 | val 0.343 | test 0.339
# Epoch 010 | loss 1.4375 | train 0.580 | val 0.557 | test 0.559
# Epoch 015 | loss 1.2431 | train 0.643 | val 0.602 | test 0.612
# Epoch 020 | loss 1.0516 | train 0.820 | val 0.729 | test 0.754
# Epoch 025 | loss 0.9036 | train 0.833 | val 0.732 | test 0.768
# Epoch 030 | loss 0.8074 | train 0.840 | val 0.732 | test 0.762
# Epoch 035 | loss 0.7298 | train 0.841 | val 0.726 | test 0.762
# Epoch 040 | loss 0.6557 | train 0.850 | val 0.723 | test 0.762
# Epoch 045 | loss 0.5873 | train 0.860 | val 0.717 | test 0.766
# Epoch 050 | loss 0.5728 | train 0.864 | val 0.720 | test 0.763
# Epoch 055 | loss 0.5483 | train 0.873 | val 0.720 | test 0.757
# Epoch 060 | loss 0.5176 | train 0.881 | val 0.720 | test 0.765
# Epoch 065 | loss 0.4938 | train 0.879 | val 0.717 | test 0.765
# Epoch 070 | loss 0.4952 | train 0.884 | val 0.708 | test 0.756
# Epoch 075 | loss 0.4726 | train 0.887 | val 0.708 | test 0.754
# Epoch 080 | loss 0.4463 | train 0.890 | val 0.705 | test 0.754
# Epoch 085 | loss 0.4627 | train 0.893 | val 0.711 | test 0.757
# Epoch 090 | loss 0.4263 | train 0.894 | val 0.711 | test 0.757
# Epoch 095 | loss 0.4420 | train 0.897 | val 0.708 | test 0.756
# Epoch 100 | loss 0.4198 | train 0.898 | val 0.708 | test 0.759
# Epoch 105 | loss 0.4130 | train 0.896 | val 0.708 | test 0.757
# Epoch 110 | loss 0.4227 | train 0.898 | val 0.705 | test 0.747
# Epoch 115 | loss 0.3977 | train 0.899 | val 0.711 | test 0.742
# ✅ Final (best-val) | train 0.834 | val 0.741 | test 0.763
# Epoch 000 | loss 1.7984 | train 0.336 | val 0.364 | test 0.333
# Epoch 005 | loss 1.5708 | train 0.651 | val 0.608 | test 0.630
# Epoch 010 | loss 1.3018 | train 0.774 | val 0.717 | test 0.712
# Epoch 015 | loss 1.0750 | train 0.808 | val 0.735 | test 0.742
# Epoch 020 | loss 0.9069 | train 0.815 | val 0.759 | test 0.748
# Epoch 025 | loss 0.8077 | train 0.832 | val 0.768 | test 0.763
# Epoch 030 | loss 0.7333 | train 0.840 | val 0.741 | test 0.766
# Epoch 035 | loss 0.6634 | train 0.848 | val 0.741 | test 0.771
# Epoch 040 | loss 0.6357 | train 0.856 | val 0.732 | test 0.768
# Epoch 045 | loss 0.5940 | train 0.863 | val 0.732 | test 0.765
# Epoch 050 | loss 0.5611 | train 0.867 | val 0.720 | test 0.765
# Epoch 055 | loss 0.5675 | train 0.873 | val 0.717 | test 0.760
# Epoch 060 | loss 0.5087 | train 0.876 | val 0.708 | test 0.760
# Epoch 065 | loss 0.5077 | train 0.874 | val 0.717 | test 0.756
# ...
# Epoch 110 | loss 0.1102 | train 0.999 | val 0.705 | test 0.760
# Epoch 115 | loss 0.1114 | train 0.998 | val 0.696 | test 0.759
# ✅ Final (best-val) | train 0.848 | val 0.750 | test 0.769
# Epoch 000 | loss 1.7968 | train 0.220 | val 0.184 | test 0.193
# Epoch 005 | loss 1.3532 | train 0.732 | val 0.645 | test 0.672
# Epoch 010 | loss 0.8773 | train 0.800 | val 0.735 | test 0.756
# Epoch 015 | loss 0.6490 | train 0.836 | val 0.756 | test 0.763
# Epoch 020 | loss 0.4966 | train 0.885 | val 0.753 | test 0.771
# Epoch 025 | loss 0.4127 | train 0.910 | val 0.717 | test 0.768
# Epoch 030 | loss 0.3559 | train 0.932 | val 0.708 | test 0.766
# Epoch 035 | loss 0.2999 | train 0.955 | val 0.705 | test 0.754
# Epoch 040 | loss 0.2522 | train 0.962 | val 0.699 | test 0.748
# Epoch 045 | loss 0.2345 | train 0.973 | val 0.705 | test 0.751
# Epoch 050 | loss 0.2120 | train 0.983 | val 0.702 | test 0.745
# Epoch 055 | loss 0.1811 | train 0.987 | val 0.699 | test 0.747
# Epoch 060 | loss 0.1749 | train 0.991 | val 0.696 | test 0.745
# Epoch 065 | loss 0.1577 | train 0.991 | val 0.699 | test 0.745
# Epoch 070 | loss 0.1459 | train 0.996 | val 0.699 | test 0.742
# Epoch 075 | loss 0.1491 | train 0.995 | val 0.699 | test 0.741
# Epoch 080 | loss 0.1350 | train 0.997 | val 0.708 | test 0.745
# Epoch 085 | loss 0.1367 | train 0.997 | val 0.708 | test 0.750
# Epoch 090 | loss 0.1299 | train 0.998 | val 0.708 | test 0.750
# Epoch 095 | loss 0.1220 | train 0.998 | val 0.708 | test 0.741
# Epoch 100 | loss 0.1067 | train 0.999 | val 0.708 | test 0.747
# Epoch 105 | loss 0.1093 | train 0.999 | val 0.708 | test 0.751
# Epoch 110 | loss 0.1233 | train 0.998 | val 0.708 | test 0.757
# Epoch 115 | loss 0.1128 | train 0.998 | val 0.687 | test 0.760
# ✅ Final (best-val) | train 0.849 | val 0.759 | test 0.771
# Epoch 000 | loss 1.7829 | train 0.372 | val 0.334 | test 0.355
# Epoch 005 | loss 1.3680 | train 0.706 | val 0.617 | test 0.606
# Epoch 010 | loss 0.8776 | train 0.833 | val 0.738 | test 0.754
# Epoch 015 | loss 0.6279 | train 0.857 | val 0.759 | test 0.772
# Epoch 020 | loss 0.4709 | train 0.892 | val 0.738 | test 0.775
# Epoch 025 | loss 0.3950 | train 0.919 | val 0.726 | test 0.763
# Epoch 030 | loss 0.3314 | train 0.942 | val 0.699 | test 0.751
# Epoch 035 | loss 0.2894 | train 0.960 | val 0.699 | test 0.756
# Epoch 040 | loss 0.2484 | train 0.970 | val 0.696 | test 0.753
# Epoch 045 | loss 0.2240 | train 0.974 | val 0.699 | test 0.760
# Epoch 050 | loss 0.1982 | train 0.979 | val 0.705 | test 0.760
# Epoch 055 | loss 0.1761 | train 0.987 | val 0.717 | test 0.738
# Epoch 060 | loss 0.1653 | train 0.992 | val 0.708 | test 0.748
# Epoch 065 | loss 0.1429 | train 0.991 | val 0.696 | test 0.738
# Epoch 070 | loss 0.1440 | train 0.994 | val 0.705 | test 0.760
# Epoch 075 | loss 0.1439 | train 0.997 | val 0.714 | test 0.753
# Epoch 080 | loss 0.1418 | train 0.996 | val 0.708 | test 0.747
# Epoch 085 | loss 0.1368 | train 0.997 | val 0.708 | test 0.751
# Epoch 090 | loss 0.1235 | train 0.998 | val 0.705 | test 0.751
# Epoch 095 | loss 0.1104 | train 0.997 | val 0.708 | test 0.754
# Epoch 100 | loss 0.1192 | train 0.997 | val 0.708 | test 0.756
# Epoch 105 | loss 0.1274 | train 0.999 | val 0.705 | test 0.741
# Epoch 110 | loss 0.1093 | train 0.998 | val 0.711 | test 0.744
# Epoch 115 | loss 0.1155 | train 0.999 | val 0.702 | test 0.745
# ✅ Final (best-val) | train 0.839 | val 0.759 | test 0.766
# Epoch 000 | loss 1.7864 | train 0.425 | val 0.349 | test 0.400
# Epoch 005 | loss 1.2804 | train 0.753 | val 0.675 | test 0.675
# Epoch 010 | loss 0.8503 | train 0.812 | val 0.753 | test 0.756
# Epoch 015 | loss 0.6166 | train 0.858 | val 0.759 | test 0.763
# Epoch 020 | loss 0.5168 | train 0.888 | val 0.726 | test 0.762
# Epoch 025 | loss 0.4137 | train 0.916 | val 0.729 | test 0.759
# Epoch 030 | loss 0.3453 | train 0.939 | val 0.708 | test 0.753
# Epoch 035 | loss 0.2831 | train 0.946 | val 0.723 | test 0.759
# Epoch 040 | loss 0.2688 | train 0.968 | val 0.711 | test 0.748
# Epoch 045 | loss 0.2316 | train 0.976 | val 0.702 | test 0.747
# Epoch 050 | loss 0.2115 | train 0.980 | val 0.705 | test 0.747
# Epoch 055 | loss 0.1901 | train 0.982 | val 0.696 | test 0.739
# Epoch 060 | loss 0.1775 | train 0.989 | val 0.702 | test 0.733
# Epoch 065 | loss 0.1654 | train 0.993 | val 0.705 | test 0.732
# Epoch 070 | loss 0.1534 | train 0.992 | val 0.702 | test 0.736
# Epoch 075 | loss 0.1452 | train 0.993 | val 0.711 | test 0.742
# Epoch 080 | loss 0.1449 | train 0.993 | val 0.711 | test 0.736
# Epoch 085 | loss 0.1463 | train 0.997 | val 0.705 | test 0.739
# Epoch 090 | loss 0.1411 | train 0.997 | val 0.708 | test 0.735
# Epoch 095 | loss 0.1314 | train 0.997 | val 0.708 | test 0.730
# Epoch 100 | loss 0.1154 | train 0.997 | val 0.705 | test 0.733
# Epoch 105 | loss 0.1196 | train 0.998 | val 0.705 | test 0.738
# Epoch 110 | loss 0.1160 | train 0.998 | val 0.708 | test 0.744
# Epoch 115 | loss 0.1152 | train 0.997 | val 0.708 | test 0.747
# ✅ Final (best-val) | train 0.833 | val 0.759 | test 0.766
# Epoch 000 | loss 1.7842 | train 0.375 | val 0.316 | test 0.310
# Epoch 005 | loss 1.3273 | train 0.794 | val 0.717 | test 0.721
# Epoch 010 | loss 0.8519 | train 0.803 | val 0.741 | test 0.753
# Epoch 015 | loss 0.6343 | train 0.851 | val 0.759 | test 0.763
# Epoch 020 | loss 0.5249 | train 0.880 | val 0.750 | test 0.768
# Epoch 025 | loss 0.4114 | train 0.917 | val 0.729 | test 0.766
# Epoch 030 | loss 0.3352 | train 0.941 | val 0.711 | test 0.753
# Epoch 035 | loss 0.2802 | train 0.951 | val 0.705 | test 0.753
# Epoch 040 | loss 0.2556 | train 0.971 | val 0.708 | test 0.751
# Epoch 045 | loss 0.2258 | train 0.977 | val 0.702 | test 0.750
# Epoch 050 | loss 0.1941 | train 0.985 | val 0.714 | test 0.759
# Epoch 055 | loss 0.1956 | train 0.991 | val 0.717 | test 0.744
# Epoch 060 | loss 0.1695 | train 0.991 | val 0.717 | test 0.754
# Epoch 065 | loss 0.1490 | train 0.994 | val 0.726 | test 0.753
# Epoch 070 | loss 0.1370 | train 0.995 | val 0.714 | test 0.753
# Epoch 075 | loss 0.1279 | train 0.997 | val 0.711 | test 0.759
# Epoch 080 | loss 0.1189 | train 0.997 | val 0.714 | test 0.756
# Epoch 085 | loss 0.1235 | train 0.997 | val 0.723 | test 0.751
# Epoch 090 | loss 0.1232 | train 0.997 | val 0.735 | test 0.753
# Epoch 095 | loss 0.1126 | train 0.998 | val 0.729 | test 0.757
# Epoch 100 | loss 0.1062 | train 0.998 | val 0.726 | test 0.754
# Epoch 105 | loss 0.1081 | train 0.998 | val 0.729 | test 0.757
# Epoch 110 | loss 0.1071 | train 0.998 | val 0.723 | test 0.751
# Epoch 115 | loss 0.0981 | train 0.998 | val 0.726 | test 0.756
# ✅ Final (best-val) | train 0.875 | val 0.765 | test 0.766
# Epoch 000 | loss 1.8086 | train 0.317 | val 0.271 | test 0.283
# Epoch 005 | loss 1.3599 | train 0.757 | val 0.663 | test 0.696
# Epoch 010 | loss 0.9130 | train 0.799 | val 0.741 | test 0.739
# Epoch 015 | loss 0.6762 | train 0.841 | val 0.747 | test 0.760
# Epoch 020 | loss 0.5554 | train 0.871 | val 0.729 | test 0.760
# Epoch 025 | loss 0.4511 | train 0.899 | val 0.717 | test 0.772
# Epoch 030 | loss 0.3656 | train 0.922 | val 0.714 | test 0.768
# Epoch 035 | loss 0.3272 | train 0.941 | val 0.702 | test 0.768
# Epoch 040 | loss 0.2743 | train 0.960 | val 0.693 | test 0.757
# Epoch 045 | loss 0.2545 | train 0.966 | val 0.696 | test 0.756
# Epoch 050 | loss 0.2145 | train 0.971 | val 0.702 | test 0.757
# Epoch 055 | loss 0.2053 | train 0.979 | val 0.711 | test 0.753
# Epoch 060 | loss 0.1960 | train 0.984 | val 0.711 | test 0.750
# Epoch 065 | loss 0.1782 | train 0.991 | val 0.708 | test 0.745
# Epoch 070 | loss 0.1694 | train 0.992 | val 0.702 | test 0.747
# Epoch 075 | loss 0.1624 | train 0.995 | val 0.711 | test 0.748
# Epoch 080 | loss 0.1317 | train 0.997 | val 0.699 | test 0.751
# Epoch 085 | loss 0.1352 | train 0.996 | val 0.708 | test 0.745
# Epoch 090 | loss 0.1340 | train 0.997 | val 0.711 | test 0.742
# Epoch 095 | loss 0.1368 | train 0.997 | val 0.714 | test 0.750
# Epoch 100 | loss 0.1246 | train 0.998 | val 0.705 | test 0.756
# Epoch 105 | loss 0.1303 | train 0.997 | val 0.711 | test 0.753
# Epoch 110 | loss 0.1382 | train 0.997 | val 0.717 | test 0.754
# Epoch 115 | loss 0.1137 | train 0.998 | val 0.723 | test 0.750
# ✅ Final (best-val) | train 0.841 | val 0.747 | test 0.760
# Epoch 000 | loss 1.7882 | train 0.380 | val 0.352 | test 0.379
# Epoch 005 | loss 1.3163 | train 0.785 | val 0.696 | test 0.714
# Epoch 010 | loss 0.8119 | train 0.817 | val 0.750 | test 0.765
# Epoch 015 | loss 0.6156 | train 0.860 | val 0.753 | test 0.772
# Epoch 020 | loss 0.4751 | train 0.891 | val 0.738 | test 0.775
# Epoch 025 | loss 0.4073 | train 0.922 | val 0.723 | test 0.765
# Epoch 030 | loss 0.3328 | train 0.940 | val 0.705 | test 0.768
# Epoch 035 | loss 0.2819 | train 0.953 | val 0.705 | test 0.766
# Epoch 040 | loss 0.2581 | train 0.969 | val 0.696 | test 0.750
# Epoch 045 | loss 0.2369 | train 0.977 | val 0.693 | test 0.747
# Epoch 050 | loss 0.2022 | train 0.979 | val 0.696 | test 0.744
# Epoch 055 | loss 0.1924 | train 0.988 | val 0.702 | test 0.750
# Epoch 060 | loss 0.1850 | train 0.989 | val 0.708 | test 0.748
# Epoch 065 | loss 0.1661 | train 0.993 | val 0.717 | test 0.748
# Epoch 070 | loss 0.1518 | train 0.991 | val 0.693 | test 0.753
# Epoch 075 | loss 0.1450 | train 0.995 | val 0.699 | test 0.747
# Epoch 080 | loss 0.1421 | train 0.995 | val 0.708 | test 0.748
# Epoch 085 | loss 0.1184 | train 0.997 | val 0.705 | test 0.745
# Epoch 090 | loss 0.1317 | train 0.998 | val 0.717 | test 0.745
# Epoch 095 | loss 0.1167 | train 0.998 | val 0.702 | test 0.751
# Epoch 100 | loss 0.1077 | train 0.998 | val 0.708 | test 0.750
# Epoch 105 | loss 0.1068 | train 0.999 | val 0.708 | test 0.745
# Epoch 110 | loss 0.1028 | train 0.999 | val 0.711 | test 0.748
# Epoch 115 | loss 0.0999 | train 0.998 | val 0.702 | test 0.754
# ✅ Final (best-val) | train 0.852 | val 0.756 | test 0.771
# Epoch 000 | loss 1.8222 | train 0.175 | val 0.178 | test 0.195
# Epoch 005 | loss 1.3471 | train 0.777 | val 0.726 | test 0.718
# Epoch 010 | loss 0.8728 | train 0.800 | val 0.753 | test 0.756
# Epoch 015 | loss 0.6226 | train 0.848 | val 0.765 | test 0.754
# Epoch 020 | loss 0.5132 | train 0.881 | val 0.732 | test 0.771
# Epoch 025 | loss 0.4212 | train 0.903 | val 0.723 | test 0.777
# Epoch 030 | loss 0.3461 | train 0.929 | val 0.723 | test 0.768
# Epoch 035 | loss 0.2959 | train 0.947 | val 0.729 | test 0.760
# Epoch 040 | loss 0.2625 | train 0.957 | val 0.720 | test 0.762
# Epoch 045 | loss 0.2230 | train 0.972 | val 0.714 | test 0.756
# Epoch 050 | loss 0.2092 | train 0.979 | val 0.720 | test 0.747
# Epoch 055 | loss 0.1814 | train 0.983 | val 0.714 | test 0.748
# Epoch 060 | loss 0.1845 | train 0.988 | val 0.711 | test 0.748
# Epoch 065 | loss 0.1612 | train 0.990 | val 0.708 | test 0.751
# Epoch 070 | loss 0.1559 | train 0.994 | val 0.711 | test 0.745
# Epoch 075 | loss 0.1411 | train 0.996 | val 0.711 | test 0.741
# Epoch 080 | loss 0.1383 | train 0.997 | val 0.714 | test 0.742
# Epoch 085 | loss 0.1282 | train 0.996 | val 0.705 | test 0.738
# Epoch 090 | loss 0.1381 | train 0.997 | val 0.711 | test 0.742
# Epoch 095 | loss 0.1307 | train 0.998 | val 0.711 | test 0.744
# Epoch 100 | loss 0.1176 | train 0.998 | val 0.717 | test 0.745
# Epoch 105 | loss 0.1223 | train 0.998 | val 0.717 | test 0.747
# Epoch 110 | loss 0.1076 | train 0.999 | val 0.714 | test 0.745
# Epoch 115 | loss 0.1121 | train 0.998 | val 0.717 | test 0.747
# ✅ Final (best-val) | train 0.848 | val 0.765 | test 0.754
# Epoch 000 | loss 1.7950 | train 0.323 | val 0.295 | test 0.286
# Epoch 005 | loss 1.4381 | train 0.737 | val 0.666 | test 0.643
# Epoch 010 | loss 0.9672 | train 0.819 | val 0.735 | test 0.751
# Epoch 015 | loss 0.6808 | train 0.868 | val 0.753 | test 0.775
# Epoch 020 | loss 0.5412 | train 0.887 | val 0.732 | test 0.757
# Epoch 025 | loss 0.4182 | train 0.918 | val 0.726 | test 0.762
# Epoch 030 | loss 0.3243 | train 0.940 | val 0.708 | test 0.769
# Epoch 035 | loss 0.2825 | train 0.963 | val 0.705 | test 0.766
# Epoch 040 | loss 0.2389 | train 0.977 | val 0.708 | test 0.757
# Epoch 045 | loss 0.2094 | train 0.984 | val 0.717 | test 0.756
# Epoch 050 | loss 0.1957 | train 0.988 | val 0.714 | test 0.744
# Epoch 055 | loss 0.1853 | train 0.992 | val 0.711 | test 0.748
# Epoch 060 | loss 0.1680 | train 0.992 | val 0.699 | test 0.750
# Epoch 065 | loss 0.1585 | train 0.995 | val 0.702 | test 0.750
# Epoch 070 | loss 0.1492 | train 0.996 | val 0.702 | test 0.753
# Epoch 075 | loss 0.1364 | train 0.995 | val 0.699 | test 0.751
# Epoch 080 | loss 0.1233 | train 0.997 | val 0.699 | test 0.747
# Epoch 085 | loss 0.1276 | train 0.998 | val 0.705 | test 0.751
# Epoch 090 | loss 0.1189 | train 0.998 | val 0.711 | test 0.747
# Epoch 095 | loss 0.1254 | train 0.998 | val 0.705 | test 0.756
# Epoch 100 | loss 0.1158 | train 1.000 | val 0.702 | test 0.753
# Epoch 105 | loss 0.1113 | train 0.999 | val 0.711 | test 0.754
# Epoch 110 | loss 0.1159 | train 0.998 | val 0.717 | test 0.748
# Epoch 115 | loss 0.1066 | train 0.999 | val 0.714 | test 0.748
# ✅ Final (best-val) | train 0.868 | val 0.753 | test 0.775
# Epoch 000 | loss 1.8041 | train 0.357 | val 0.295 | test 0.319
# Epoch 005 | loss 1.3154 | train 0.771 | val 0.696 | test 0.715
# Epoch 010 | loss 0.8614 | train 0.800 | val 0.738 | test 0.754
# Epoch 015 | loss 0.6408 | train 0.841 | val 0.741 | test 0.768
# Epoch 020 | loss 0.5210 | train 0.870 | val 0.741 | test 0.777
# Epoch 025 | loss 0.4166 | train 0.905 | val 0.720 | test 0.774
# Epoch 030 | loss 0.3415 | train 0.931 | val 0.705 | test 0.760
# Epoch 035 | loss 0.3019 | train 0.948 | val 0.711 | test 0.766
# Epoch 040 | loss 0.2782 | train 0.966 | val 0.708 | test 0.762
# Epoch 045 | loss 0.2397 | train 0.977 | val 0.711 | test 0.759
# Epoch 050 | loss 0.1932 | train 0.982 | val 0.702 | test 0.759
# Epoch 055 | loss 0.1894 | train 0.988 | val 0.699 | test 0.744
# Epoch 060 | loss 0.1919 | train 0.992 | val 0.699 | test 0.745
# Epoch 065 | loss 0.1647 | train 0.993 | val 0.699 | test 0.750
# Epoch 070 | loss 0.1595 | train 0.996 | val 0.711 | test 0.751
# Epoch 075 | loss 0.1366 | train 0.997 | val 0.702 | test 0.744
# Epoch 080 | loss 0.1448 | train 0.997 | val 0.696 | test 0.748
# Epoch 085 | loss 0.1370 | train 0.998 | val 0.696 | test 0.747
# Epoch 090 | loss 0.1289 | train 0.997 | val 0.705 | test 0.744
# Epoch 095 | loss 0.1199 | train 0.998 | val 0.711 | test 0.747
# Epoch 100 | loss 0.1163 | train 0.999 | val 0.708 | test 0.747
# Epoch 105 | loss 0.1169 | train 0.999 | val 0.708 | test 0.753
# Epoch 110 | loss 0.1237 | train 0.999 | val 0.705 | test 0.750
# Epoch 115 | loss 0.1063 | train 0.998 | val 0.708 | test 0.759
# ✅ Final (best-val) | train 0.821 | val 0.747 | test 0.763
# Epoch 000 | loss 1.8019 | train 0.234 | val 0.223 | test 0.247
# Epoch 005 | loss 1.2720 | train 0.778 | val 0.690 | test 0.711
# Epoch 010 | loss 0.8393 | train 0.803 | val 0.738 | test 0.738
# Epoch 015 | loss 0.6568 | train 0.842 | val 0.753 | test 0.751
# Epoch 020 | loss 0.5257 | train 0.878 | val 0.750 | test 0.763
# Epoch 025 | loss 0.4418 | train 0.903 | val 0.744 | test 0.762
# Epoch 030 | loss 0.3607 | train 0.932 | val 0.714 | test 0.750
# Epoch 035 | loss 0.3038 | train 0.942 | val 0.720 | test 0.754
# Epoch 040 | loss 0.2687 | train 0.959 | val 0.708 | test 0.753
# Epoch 045 | loss 0.2274 | train 0.969 | val 0.711 | test 0.745
# Epoch 050 | loss 0.2249 | train 0.979 | val 0.711 | test 0.739
# Epoch 055 | loss 0.1988 | train 0.980 | val 0.720 | test 0.741
# Epoch 060 | loss 0.2013 | train 0.989 | val 0.717 | test 0.742
# Epoch 065 | loss 0.1879 | train 0.987 | val 0.717 | test 0.748
# Epoch 070 | loss 0.1560 | train 0.992 | val 0.708 | test 0.742
# Epoch 075 | loss 0.1574 | train 0.993 | val 0.699 | test 0.744
# Epoch 080 | loss 0.1401 | train 0.991 | val 0.717 | test 0.756
# Epoch 085 | loss 0.1472 | train 0.997 | val 0.702 | test 0.744
# Epoch 090 | loss 0.1284 | train 0.997 | val 0.717 | test 0.753
# Epoch 095 | loss 0.1273 | train 0.997 | val 0.708 | test 0.748
# Epoch 100 | loss 0.1248 | train 0.996 | val 0.702 | test 0.754
# Epoch 105 | loss 0.1105 | train 0.998 | val 0.696 | test 0.754
# Epoch 110 | loss 0.1096 | train 0.998 | val 0.696 | test 0.751
# Epoch 115 | loss 0.1010 | train 0.999 | val 0.699 | test 0.744
# ✅ Final (best-val) | train 0.827 | val 0.753 | test 0.756
# F+ train/test: 50/50 | F- train/test: 50/50 (totals match budgets)

# %%
# =======================================================
#  Fingerprint set for node-level (P fingerprints)
# =======================================================
class FingerprintGraph(nn.Module):
    def __init__(self, n_nodes, feat_dim, sample_m, edge_init_p=0.05):
        super().__init__()
        self.n = n_nodes
        self.d = feat_dim
        self.m = min(sample_m, n_nodes)

        X = torch.empty(self.n, self.d).uniform_(-0.5, 0.5)
        self.X = nn.Parameter(X.to(device))

        A0 = (torch.rand(self.n, self.n, device=device) < edge_init_p).float()
        A0.fill_diagonal_(0.0)
        A0 = torch.maximum(A0, A0.T)
        self.A_logits = nn.Parameter(torch.logit(torch.clamp(A0, 1e-4, 1-1e-4)))

        self.sample_idx = torch.randperm(self.n, device=device)[:self.m]

    @torch.no_grad()
    def edge_index(self):
        A_prob = torch.sigmoid(self.A_logits)
        A_bin = (A_prob > 0.5).float()
        A_bin.fill_diagonal_(0.0)
        A_bin = torch.maximum(A_bin, A_bin.T)
        idx = A_bin.nonzero(as_tuple=False)
        if idx.numel() == 0:
            return torch.empty(2, 0, dtype=torch.long, device=device)
        return idx.t().contiguous()

    @torch.no_grad()
    def flip_topk_by_grad(self, gradA, topk=64, step=2.5):
        g = gradA.abs()
        triu = torch.triu(torch.ones_like(g), diagonal=1)
        scores = (g * triu).flatten()
        k = min(topk, scores.numel())
        if k == 0: return
        _, idxs = torch.topk(scores, k=k)
        r = self.n
        pairs = torch.stack((idxs // r, idxs % r), dim=1)
        A_prob = torch.sigmoid(self.A_logits).detach()
        for (u, v) in pairs.tolist():
            guv = gradA[u, v].item()
            exist = A_prob[u, v] > 0.5
            if exist and guv <= 0:
                self.A_logits.data[u, v] -= step
                self.A_logits.data[v, u] -= step
            elif (not exist) and guv >= 0:
                self.A_logits.data[u, v] += step
                self.A_logits.data[v, u] += step
        self.A_logits.data.fill_diagonal_(-10.0)

class FingerprintSet(nn.Module):
    def __init__(self, P, n_nodes, feat_dim, sample_m, edge_init_p=0.05, topk_edges=64, edge_step=2.5):
        super().__init__()
        self.P = P
        self.fps = nn.ModuleList([FingerprintGraph(n_nodes, feat_dim, sample_m, edge_init_p) for _ in range(P)]).to(device)
        self.topk_edges = topk_edges
        self.edge_step = edge_step

    def concat_outputs(self, model, *, require_grad: bool = False):
        outs = []
        model.eval()
        ctx = torch.enable_grad() if require_grad else torch.no_grad()
        with ctx:
            for fp in self.fps:
                ei = fp.edge_index()
                logits = model(fp.X, ei)
                probs  = F.softmax(logits, dim=-1)[fp.sample_idx].flatten()
                outs.append(probs)
        return torch.cat(outs, dim=0)

    def flip_adj_by_grad(self, surrogate_grad_list):
        for fp, g in zip(self.fps, surrogate_grad_list):
            fp.flip_topk_by_grad(g, topk=self.topk_edges, step=self.edge_step)

fp_set = FingerprintSet(
    P=CFG["FP_P"],
    n_nodes=CFG["FP_NODES"],
    feat_dim=num_feats,
    sample_m=CFG["FP_SAMPLE_M"],
    edge_init_p=CFG["FP_EDGE_INIT_P"],
    topk_edges=CFG["FP_EDGE_TOPK"],
    edge_step=CFG["EDGE_LOGIT_STEP"],
)

INPUT_DIM = CFG["FP_P"] * min(CFG["FP_SAMPLE_M"], CFG["FP_NODES"]) * num_classes
print("Univerifier input dim =", INPUT_DIM)
# Out:
# Univerifier input dim = 12288

# %%
# ========================================
#  Univerifier (binary classifier)
# ========================================
class Univerifier(nn.Module):
    def __init__(self, input_dim: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 128), nn.LeakyReLU(0.01),
            nn.Linear(128, 64),       nn.LeakyReLU(0.01),
            nn.Linear(64, 32),        nn.LeakyReLU(0.01),
            nn.Linear(32, 2),
        )
    def forward(self, x):
        return self.net(x)

V = Univerifier(INPUT_DIM).to(device)
opt_V = Adam(V.parameters(), lr=CFG["LR_V"])

# %%
# =====================================================
#  Joint learning (Algorithm-1 for node-level)
# =====================================================
models_pos_tr = [model_f.to(device)] + [m.to(device) for m in F_pos_tr]
models_neg_tr = [m.to(device) for m in F_neg_tr]
print(f"Train pools -> Pos: {len(models_pos_tr)} | Neg: {len(models_neg_tr)}")

def batch_from_pool(fp_set, pos_models, neg_models, *, require_grad: bool):
    X = []; y = []
    for m in pos_models:
        X.append(fp_set.concat_outputs(m, require_grad=require_grad)); y.append(1)
    for m in neg_models:
        X.append(fp_set.concat_outputs(m, require_grad=require_grad)); y.append(0)
    return torch.stack(X, dim=0), torch.tensor(y, device=device)

def surrogate_grad_A_for_fp(fp, model):
    # cosine-sim surrogate gradient from target model's first layer
    with torch.no_grad():
        ei = fp.edge_index()
        h  = model.conv1(fp.X, ei)
        h  = F.relu(h)
        hn = F.normalize(h, dim=-1)
        sim = hn @ hn.t()
        gradA = sim - 0.5
        return gradA.detach().cpu()

def update_features(fp_set, V, pos_models, neg_models, steps, lr_x):
    # freeze model params
    for m in pos_models + neg_models:
        for p in m.parameters(): p.requires_grad_(False)
    # turn on grad for X before building batch
    for fp in fp_set.fps:
        fp.X.requires_grad_(True)

    for _ in range(steps):
        Xb, yb = batch_from_pool(fp_set, pos_models, neg_models, require_grad=True)
        V.eval()
        for p in V.parameters(): p.requires_grad_(False)

        logits = V(Xb.to(device))
        loss = F.cross_entropy(logits, yb)

        for fp in fp_set.fps:
            if fp.X.grad is not None: fp.X.grad.zero_()
        loss.backward()

        with torch.no_grad():
            for fp in fp_set.fps:
                fp.X.add_(lr_x * fp.X.grad)
                fp.X.grad.zero_()

        for p in V.parameters(): p.requires_grad_(True)

    grads = [surrogate_grad_A_for_fp(fp, pos_models[0]) for fp in fp_set.fps]
    fp_set.flip_adj_by_grad(grads)

def update_verifier(fp_set, V, pos_models, neg_models, steps):
    for _ in range(steps):
        V.train()
        Xb, yb = batch_from_pool(fp_set, pos_models, neg_models, require_grad=False)
        logits = V(Xb.to(device))
        loss = F.cross_entropy(logits, yb)
        opt_V.zero_grad(); loss.backward(); opt_V.step()

for it in range(1, CFG["OUTER_ITERS"] + 1):
    update_features(fp_set, V, models_pos_tr, models_neg_tr, steps=CFG["FP_STEPS"], lr_x=CFG["LR_X"])
    update_verifier(fp_set, V, models_pos_tr, models_neg_tr, steps=CFG["V_STEPS"])

    V.eval()
    Xb, yb = batch_from_pool(fp_set, models_pos_tr, models_neg_tr, require_grad=False)
    with torch.no_grad():
        pred = V(Xb).argmax(dim=1)
        acc = (pred.cpu() == yb.cpu()).float().mean().item()
        pos_acc = (pred[:len(models_pos_tr)].cpu() == 1).float().mean().item()
        neg_acc = (pred[len(models_pos_tr):].cpu() == 0).float().mean().item()
    print(f"Iter {it:02d}/{CFG['OUTER_ITERS']} | train all {acc:.3f} | pos {pos_acc:.3f} | neg {neg_acc:.3f}")
# Out:
# Train pools -> Pos: 51 | Neg: 50
# Iter 01/20 | train all 0.921 | pos 1.000 | neg 0.840
# Iter 02/20 | train all 0.980 | pos 1.000 | neg 0.960
# Iter 03/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 04/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 05/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 06/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 07/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 08/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 09/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 10/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 11/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 12/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 13/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 14/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 15/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 16/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 17/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 18/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 19/20 | train all 1.000 | pos 1.000 | neg 1.000
# Iter 20/20 | train all 1.000 | pos 1.000 | neg 1.000

# %%
# ==========================================================
#  Held-out verification (Robustness/Uniqueness/ARUC)
# ==========================================================
models_pos_te = [model_f.to(device)] + [m.to(device) for m in F_pos_te]
models_neg_te = [m.to(device) for m in F_neg_te]

@torch.no_grad()
def verify_scores(V, fp_set, models):
    Xs = [fp_set.concat_outputs(m, require_grad=False) for m in models]
    logits = V(torch.stack(Xs, dim=0).to(device))
    probs = F.softmax(logits, dim=-1)[:, 1]  # p(positive)
    return probs.detach().cpu().numpy()

p_pos = verify_scores(V, fp_set, models_pos_te)
p_neg = verify_scores(V, fp_set, models_neg_te)

def sweep_threshold(p_pos, p_neg, num=301):
    ths = np.linspace(0.0, 1.0, num=num)
    R = []; U = []; A = []
    for t in ths:
        tp = (p_pos >= t).mean()    # robustness
        tn = (p_neg <  t).mean()    # uniqueness
        R.append(tp); U.append(tn)
        A.append((tp + tn) / 2.0)   # balanced acc (pos/neg equal)
    return ths, np.array(R), np.array(U), np.array(A)

ths, R, U, A = sweep_threshold(p_pos, p_neg, num=301)
best_idx = A.argmax()
mean_acc = A.mean()

# numpy>=2.0 has trapezoid; fallback to trapz if unavailable
ARUC = np.trapezoid(np.minimum(R, U), ths) if hasattr(np, "trapezoid") else np.trapz(np.minimum(R, U), ths)

print(f"Best @ λ={ths[best_idx]:.3f} | Robustness={R[best_idx]:.3f} | Uniqueness={U[best_idx]:.3f} | MeanAcc*={A[best_idx]:.3f}")
print(f"Mean Test Accuracy (avg over λ): {mean_acc:.3f}")
print(f"ARUC (approx): {ARUC:.3f}")
# Out:
# Best @ λ=0.023 | Robustness=1.000 | Uniqueness=0.980 | MeanAcc*=0.990
# Mean Test Accuracy (avg over λ): 0.986
# ARUC (approx): 0.976

# %%
# ================================
#  ARUC Visualization (Plotting)
# ================================
import matplotlib.pyplot as plt

# Plot ARUC curve
plt.figure(figsize=(4, 3))

# Plot Robustness
plt.plot(ths, R, label="Robustness", color='b', linestyle='-', linewidth=2)

# Plot Uniqueness
plt.plot(ths, U, label="Uniqueness", color='g', linestyle='--', linewidth=2)

# Plot ARUC (area under curve of the minimum of robustness and uniqueness)
plt.plot(ths, np.minimum(R, U), label="ARUC", color='r', linestyle='-.', linewidth=2)

# Plot Formatting
plt.xlabel('Threshold λ', fontsize=12)
plt.ylabel('Metric Value', fontsize=12)
plt.title('ARUC Visualization', fontsize=14)
plt.legend(loc='best')

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# Print ARUC value for reference
print(f"Best @ λ={ths[best_idx]:.3f} | Robustness={R[best_idx]:.3f} | Uniqueness={U[best_idx]:.3f} | MeanAcc*={A[best_idx]:.3f}")
print(f"Mean Test Accuracy (avg over λ): {mean_acc:.3f}")
print(f"ARUC (approx): {ARUC:.3f}")
# Out:
# Best @ λ=0.023 | Robustness=1.000 | Uniqueness=0.980 | MeanAcc*=0.990
# Mean Test Accuracy (avg over λ): 0.986
# ARUC (approx): 0.976

# %%
# ================================
#  Plot All Curves Together
# ================================
plt.figure(figsize=(4, 3))

# Plot Robustness
plt.plot(ths, R, label="Robustness", color='b', linestyle='-', linewidth=2)

# Plot Uniqueness
plt.plot(ths, U, label="Uniqueness", color='g', linestyle='--', linewidth=2)

# Plot ARUC
plt.plot(ths, np.minimum(R, U), label="ARUC", color='r', linestyle='-.', linewidth=2)

# Plot Formatting
plt.xlabel('Threshold λ', fontsize=12)
plt.ylabel('Metric Value', fontsize=12)
plt.title('ARUC Visualization (All Curves)', fontsize=14)
plt.legend(loc='best')

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# Print corresponding values
print(f"Best @ λ={ths[best_idx]:.3f} | Robustness={R[best_idx]:.3f} | Uniqueness={U[best_idx]:.3f} | ARUC={np.minimum(R, U)[best_idx]:.3f}")
# Out:
# Best @ λ=0.023 | Robustness=1.000 | Uniqueness=0.980 | ARUC=0.980

# %%
# ================================
#  Plot Robustness Curve
# ================================
plt.figure(figsize=(4, 3))

# Plot Robustness
plt.plot(ths, R, label="Robustness", color='b', linestyle='-', linewidth=2)

# Plot Formatting
plt.xlabel('Threshold λ', fontsize=12)
plt.ylabel('Robustness', fontsize=12)
plt.title('Robustness Curve', fontsize=14)
plt.legend(loc='best')

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# Print corresponding values
print(f"Best @ λ={ths[best_idx]:.3f} | Robustness={R[best_idx]:.3f}")
# Out:
# Best @ λ=0.023 | Robustness=1.000

# %%
# ================================
#  Plot Uniqueness Curve
# ================================
plt.figure(figsize=(4, 3))

# Plot Uniqueness
plt.plot(ths, U, label="Uniqueness", color='g', linestyle='--', linewidth=2)

# Plot Formatting
plt.xlabel('Threshold λ', fontsize=12)
plt.ylabel('Uniqueness', fontsize=12)
plt.title('Uniqueness Curve', fontsize=14)
plt.legend(loc='best')

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# Print corresponding values
print(f"Best @ λ={ths[best_idx]:.3f} | Uniqueness={U[best_idx]:.3f}")
# Out:
# Best @ λ=0.023 | Uniqueness=0.980

# %%
# ================================
#  Plot ARUC Curve
# ================================
plt.figure(figsize=(4, 3))

# Plot ARUC (minimum of robustness and uniqueness)
plt.plot(ths, np.minimum(R, U), label="ARUC", color='r', linestyle='-.', linewidth=2)

# Plot Formatting
plt.xlabel('Threshold λ', fontsize=12)
plt.ylabel('ARUC', fontsize=12)
plt.title('ARUC Curve', fontsize=14)
plt.legend(loc='best')

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# Print corresponding values
print(f"Best @ λ={ths[best_idx]:.3f} | ARUC={np.minimum(R, U)[best_idx]:.3f}")
# Out:
# Best @ λ=0.023 | ARUC=0.980
